# %%
#!pip install nltk

# %%
#!pip install hazm

# %%
#import nltk
#nltk.download()

# %%
from __future__ import unicode_literals
#from hazm import *

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df=pd.read_excel('data.xlsx')

# %%
df.head()
# Out:
#    شماره درخواست              کد ماشین  تاریخ خرابی        وضعیت نام ماشین  \
# 0       93078329                           14000608  درحال بررسي       NaN
# 1       93078330                           14000608  درحال بررسي       NaN
# 2       93078331                           14000608  درحال بررسي       NaN
# 3       93078474                           14000612  درحال بررسي       NaN
# 4       93078633                           14000616  درحال بررسي       NaN
#
#   نوع درخواست         ق.ص. درخواست علت خرابی  مدت انجام كار  \
# 0        عادي  هيدروليك و روانكاري       NaN              0
# 1        عادي  هيدروليك و روانكاري       NaN              0
# 2        عادي  هيدروليك و روانكاري       NaN              0
# 3        عادي  هيدروليك و روانكاري       NaN              0
# 4        عادي  هيدروليك و روانكاري       NaN              0
#
#                                             شرح مشكل  تاريخ شروع  \
# 0  سيستم گريس بالميل آلارم دارد و اسپري انجام نمي...           0
# 1                    سيستم گريس ديسك يك آلارم دارد .           0
# 2     نشتي روغن  از پمپ مسير شماره يك هيدروليك 610wb           0
# 3                   سيستم گريسكاري بالميل آلارم دارد           0
# 4  دماي بيرينگ سمت موتور 710fn4 بالاست و سطح روغن...           0
#
#   شرح_كد دوره توقف (واقعي ) 2 شرح_محل استقرار
# 0                      نامشخص     930BM1.xxxx
# 1                      نامشخص     610PE1.XXXX
# 2                      نامشخص          610BW8
# 3                      نامشخص     930BM1.xxxx
# 4                      نامشخص     710FN4.xxxx

# %%
import arabic_reshaper
from bidi.algorithm import get_display

# %%
x=[]
for item in df['وضعیت'].values:
    x.append(get_display(arabic_reshaper.reshape(item)))

# %%
print(x[0][::-1])
df['vaziiat']=x
df
# Out:
# ﺩﺭﺣﺎﻝ ﺑﺮﺭﺳﻲ
#       شماره درخواست              کد ماشین  تاریخ خرابی        وضعیت نام ماشین  \
# 0          93078329                           14000608  درحال بررسي       NaN
# 1          93078330                           14000608  درحال بررسي       NaN
# 2          93078331                           14000608  درحال بررسي       NaN
# 3          93078474                           14000612  درحال بررسي       NaN
# 4          93078633                           14000616  درحال بررسي       NaN
# ...             ...                   ...          ...          ...       ...
# 6145       93079110                           14000630  درحال انجام       NaN
# 6146       93079611                           14000715  پايان يافته       NaN
# 6147       93078715                           14000618  پايان يافته       NaN
# 6148       93081354                           14000908  پايان يافته       NaN
# 6149       93082290                           14001008  پايان يافته       NaN
#
#      نوع درخواست         ق.ص. درخواست علت خرابی  مدت انجام كار  \
# 0           عادي  هيدروليك و روانكاري       NaN              0
# 1           عادي  هيدروليك و روانكاري       NaN              0
# 2           عادي  هيدروليك و روانكاري       NaN              0
# 3           عادي  هيدروليك و روانكاري       NaN              0
# 4           عادي  هيدروليك و روانكاري       NaN              0
# ...          ...                  ...       ...            ...
# 6145        عادي            ابزاردقيق       NaN            120
# 6146        عادي  هيدروليك و روانكاري       NaN             60
# 6147        عادي  هيدروليك و روانكاري       NaN             60
# 6148        عادي  هيدروليك و روانكاري       NaN            120
# 6149        عادي  هيدروليك و روانكاري       NaN             60
#
#                                                شرح مشكل  تاريخ شروع  \
# 0     سيستم گريس بالميل آلارم دارد و اسپري انجام نمي...           0
# 1                       سيستم گريس ديسك يك آلارم دارد .           0
# 2        نشتي روغن  از پمپ مسير شماره يك هيدروليك 610wb           0
# 3                      سيستم گريسكاري بالميل آلارم دارد           0
# 4     دماي بيرينگ سمت موتور 710fn4 بالاست و سطح روغن...           0
# ...                                                 ...         ...
# 6145  سنسور نشان گر موقعيت WB بعضي مواقع گير ميكند و...           0
# 6146     لوله گريس پالت 15 از طوقه بيروني كنده شده است:           0
# 6147                  سيستم گريس چندين مرتبه تريپ خورد.           0
# 6148                 لوله گريس بيروني پالت 26 شكسته است           0
# 6149                       گريس دستي ديسك 4 جام ميباشد.           0
#
#      شرح_كد دوره توقف (واقعي ) 2 شرح_محل استقرار      vaziiat
# 0                         نامشخص     930BM1.xxxx  ﻲﺳﺭﺮﺑ ﻝﺎﺣﺭﺩ
# 1                         نامشخص     610PE1.XXXX  ﻲﺳﺭﺮﺑ ﻝﺎﺣﺭﺩ
# 2                         نامشخص          610BW8  ﻲﺳﺭﺮﺑ ﻝﺎﺣﺭﺩ
# 3                         نامشخص     930BM1.xxxx  ﻲﺳﺭﺮﺑ ﻝﺎﺣﺭﺩ
# 4                         نامشخص     710FN4.xxxx  ﻲﺳﺭﺮﺑ ﻝﺎﺣﺭﺩ
# ...                          ...             ...          ...
# 6145                توقف گرم 110     610WB1.xxxx  ﻡﺎﺠﻧﺍ ﻝﺎﺣﺭﺩ
# 6146                      نامشخص     730AN1.XXXX  ﻪﺘﻓﺎﻳ ﻥﺎﻳﺎﭘ
# 6147                      نامشخص     930BM1.xxxx  ﻪﺘﻓﺎﻳ ﻥﺎﻳﺎﭘ
# 6148                      نامشخص     730AN1.XXXX  ﻪﺘﻓﺎﻳ ﻥﺎﻳﺎﭘ
# 6149                      نامشخص     610PE4.XXXX  ﻪﺘﻓﺎﻳ ﻥﺎﻳﺎﭘ
#
# [6150 rows x 14 columns]

# %%
df['vaziiat'].value_counts().plot(kind='pie')
plt.tight_layout()
plt.show()

# %%
import re
#cleaning text
sample_persian = df['شرح مشكل'].values
sentences = sample_persian
corpus = []

for sent in sentences:
    review = re.sub("[^a-zA-Z]", " ", sent)
    review = re.sub("\b[a-zA-Z]\b", " ", review)
    review = review.lower()
    review = review.split()
    review = " ".join(review)
    corpus.append(review)

# %%
corpus
# Out:
# ['',
#  '',
#  'wb',
#  '',
#  'fn',
#  '',
#  '',
#  '',
#  'k',
#  'ep e',
#  '',
#  '',
#  '',
#  '',
#  '',
#  'fn',
#  'fn',
#  'spray off',
#  'spray off',
#  'fn',
#  '',
#  'crm jernkontoret jk jernkontoret jk a dillinger hutte sx',
#  'ccs',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  'tt',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  'spray off',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  'tn pi xv',
#  '',
#  '',
#  'pl',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  'fn',
#  'server',
#  'fn',
#  '',
#  'fs',
#  'bc ls',
#  '',
#  '',
#  'rf me',
#  '',
#  'up',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  'ss',
#  '',
#  '',
#  '',
#  'ls',
#  '',
#  'carbon brush rl bm',
#  '',
#  'xv',
#  'weight feeder',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  'hpgr',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  'pc',
#  'bc',
#  '',
#  '',
#  '',
#  '',
#  'ga',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  'bc',
#  '',
#  '',
#  '',
#  '',
#  'bc',
#  '',
#  '',
#  'hpgr',
#  '',
#  'ga',
#  '',
#  '',
#  '',
#  '',
#  'ep',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  'pc',
#  '',
#  '',
#  '',
#  '',
#  'bc',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  'pc',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  'hpgr',
#  'spare',
#  '',
#  'pm',
#  '',
#  '',
#  '',
#  '',
#  '',
#  'wf',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  'ep',
#  'ep',
#  'bc',
#  '',
#  '',
#  'wf',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  'rs',
#  'rs',
#  '',
#  'me me',
#  'spare',
#  'ft pt xv',
#  '',
#  '',
#  '',
#  '',
#  '',
#  'cone',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  'cone support cone',
#  'cone support cone',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  'pt',
#  '',
#  '',
#  '',
#  'mv',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  'bc an me',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  'abb',
#  'vf',
#  '',
#  '',
#  '',
#  'fn me da at',
#  'fn',
#  '',
#  '',
#  'tare',
#  'tare',
#  'pm',
#  'pm fn fn',
#  'carbon brush cg manufacture mersen',
#  '',
#  'fn',
#  'carbon brush fn mersen',
#  'device cerberus',
#  '',
#  '',
#  '',
#  'mini plc',
#  'mini plc',
#  'ts',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  'carbon brush mersen',
#  '',
#  '',
#  'm',
#  '',
#  '',
#  '',
#  'pt an aa pt an te',
#  '',
#  'upper cover for regulator and filter regulator',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  'bnc transmitter reciever',
#  'hart handheld communicator type dhh g',
#  'kl pt',
#  '',
#  '',
#  '',
#  'synova fcl a',
#  '',
#  '',
#  '',
#  'led',
#  'cerberus siemens lpcb',
#  'tg aa pt',
#  'o',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  'rs',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  'vip',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  'pt',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  'wet scraber',
#  '',
#  '',
#  '',
#  'wet scraber',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  'v belt',
#  '',
#  '',
#  '',
#  '',
#  '',
#  'disconnection xv connection',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  'ps',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  'rcp',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  'cpg',
#  '',
#  '',
#  'y dn dn',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  'ccs',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  'ccs',
#  'set point',
#  '',
#  '',
#  'slow',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  'ls rs',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  'ss',
#  '',
#  '',
#  '',
#  '',
#  '',
#  'over load',
#  '',
#  '',
#  'hpgr',
#  '',
#  'rs',
#  '',
#  'rs',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  'wp',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  'bf',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  'ls',
#  'ls',
#  'over load',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  'ls rs',
#  'ls rs',
#  'ls bc',
#  'ls',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  'e',
#  '',
#  '',
#  '',
#  'fs',
#  'fs',
#  '',
#  '',
#  '',
#  '',
#  '',
#  'tn',
#  '',
#  'cf sp',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  'fs',
#  '',
#  'pt',
#  'zs',
#  '',
#  'spray of',
#  '',
#  'rb',
#  '',
#  '',
#  '',
#  '',
#  'rb',
#  '',
#  '',
#  '',
#  'k',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  'ss',
#  '',
#  '',
#  '',
#  'rpm',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  'bc',
#  '',
#  '',
#  '',
#  '',
#  'bc',
#  '',
#  '',
#  'pc',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  'bc',
#  '',
#  '',
#  '',
#  '',
#  'bc',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  'bc',
#  'cf sp',
#  '',
#  '',
#  '',
#  '',
#  'k',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  'cf',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  'rb',
#  '',
#  '',
#  '',
#  'bc bc',
#  '',
#  '',
#  'bc',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  'tiptop',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  'tiptop',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  'bc',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  'ls bc',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  ...]

# %%
import re
#cleaning text
sentences = sample_persian
corpus = []

for sent in sentences:
    if re.search('[\u0600-\u06FF]',sent):
        corpus.append(sent)

# %%
corpus
# Out:
# ['سيستم گريس بالميل آلارم دارد و اسپري انجام نميشود .',
#  'سيستم گريس ديسك يك آلارم دارد .',
#  'نشتي روغن  از پمپ مسير شماره يك هيدروليك 610wb',
#  'سيستم گريسكاري بالميل آلارم دارد',
#  'دماي بيرينگ سمت موتور 710fn4 بالاست و سطح روغن بيرينگ بطور واضح مشخص نيست',
#  'لوله گريس ياتاقان 38 مسير رفت زنجير تراولينگ ، سمت شمال از محل اتصال جدا شده',
#  'نوار وايد بلت به سمت جنوب انحراف دارد',
#  'نشتي غير نرمال گريس از ياتاقان تل شفت سمت شمال تراولينگ',
#  'نشتي روغن از بيرينگ 4 (k4) كوره بيشتر شده',
#  'نشتي گريس از شافت Ep2e05',
#  'كنترل گيجهاي فشار آكومولاتورهاي سيستم هيدروليك',
#  'بوم استكر با بار در زوايه منفي بالا نميرود',
#  'لوله گريس سر بازوي پالت 21 داخل كولينگ از محل اتصال جدا شده',
#  'سيستم گريس بالميل ( پمپ روي بشكه 2 ) مشكل دارد',
#  'مشاهده نشتي روغن از گيج روي گيربكس ديسك 4',
#  'فشار روغن يونيت  710FN1  حدود سه واحد  كمتر از قبل شده',
#  'فشار روغن سيستم روانكاري 71FN1  تا 2.4  كاهش پيدا كرده',
#  'آلارم spray off   سيستم گريس ديسك يك',
#  'آلارم SPRAY OFF  سيستم گريس كوره',
#  'فشار روغن يونيت 710fn1  روند كاهشي دارد',
#  'مشاهده دفرمگي و قرمز شدن بدنه سمت جنوب پارالل داكت كولينگ',
#  'درخواست مواد مرجع گواهي شده(CRM):\n1)Jernkontoret - JK 28 به مقدار 150 گرم\n2)Jernkontoret - JK 42A به مقدار 100 گرم\n3)DILLINGER HUTTE- SX 11-37 -  به مقدار 100 گرم',
#  'درخواست يك دستگاه ccs اتوماتيك',
#  'درخواست ملاس به مقدار 26870 كيلوگرم',
#  'درخواست بنتونيت آذرماه از يكم تا هفدهم به مقدار 1192520 كيلوگرم',
#  'كنسانتره مصرفي دي ماه به مقدار412246000 كيلوگرم؛(مقادير به تفكيك روز به پيوست مي باشد).',
#  'كنسانتره مصرفي بهمن ماه به مقدار 351618000 كيلوگرم؛(مقادير به تفكيك روز به پيوست مي باشد).',
#  'درخواست 19980 كيلوگرم سود مايع 50 درصد',
#  'سقف پمپ خانه غبارگير ناحيه كولينگ به دليل عبور لوله هاي  اسلاري پمپ ها از سقف ، به طور كامل كنارلوله ها پوشش مناسب را ندارد و در مواقع نشتي هاي سيستم غبارگير يا بارندگي  ، آب به داخل پمپ خانه و روي موتور ها ريزش دارد .',
#  'پارچه سكتور 6 از رديف 9 ، فيلتر ديسك يك سوراخ شده',
#  'گريسكاري دستي چرخ يك بيرون كولينگ با توجه به شدت ضربات آن',
#  'لطفا شوت و داكت هاي جمع اوري غبار كه به تازگي نصب شده است رنگ آميزي شود. (درخواست مربوط به 120TT2 است)',
#  'نصب پنجره  در ديوار ضلع شمالي پولپيت بالينگ',
#  'در ب سرويس بهداشتي طبقه دوم بالينگ ( كه جديدا به سمت بيرون باز شده ) با توجه به اينكه در معرض گرد وخاك زياد مي باشد نياز به جك آرام بند دارد',
#  'نصب آئينه  و جاصابوني',
#  'نصب آئينه سرويس بهداشتي، دو عدد',
#  'درزگيري اتاق هايكول',
#  'درز گيري درب ورودي انبار جديد آزمايشگاه',
#  'خروجي وت اسكرابر كولينگ به داخل سامپ گرفته است',
#  'آبسردكن پولپيت ميكسينگ نشتي آب دارد .',
#  'سيستم اسپري گريس ديسك يك آلارم spray off دارد',
#  'لطفا نسبت به رنگ آميزي شوت هاي جمع آوري كنسانتره تازه نصب شده بر روي ترانسفرتاور اقدام نمائيد. داربست در محل قرار دارد.',
#  'نصب پايه هاي تور واليبال در شمال ساختمان آتشنشاني',
#  'وكيوم پمپ 2  مكش مناسب براي گرفتن كيك ندارد و رطوبت كيك بالاتر از حد نرمال است',
#  'دماي آب مربوط به وكيوم پمپ 2بالاتر از حد نرمال مي باشد .',
#  'گيج مربوط به فشار مكش و وكيوم فيلتر ديسك 2 عدد واقعي را نشان نمي دهد',
#  'رادياتور اتاق پرسنل روانكاري نشتي اب دارد',
#  'تهيه و نصب يك عدد اسپيلت(كولر گازي) جهت اتاق سوپروايزها',
#  'شيربرقي روي TN  خروجي بالميل  (930PI1-XV35)در محل يكسره باز است ( در اتاق كنترل باز و بسته ميشود )',
#  'شيلنگ آب ورودي  شافت اسكرين 2 نشتي دارد',
#  'مسير خروجي فاضلاب  ( خروجي سينك و كف )آبدارخانه طبقه دوم بالينگ گرفتگي دارد',
#  'نشتي باد از اتصالات جك مربوط به 520PL3',
#  'با توجه به گزارش پايش موتورها ، لطفا نسبت به بررسي تسمه و پولي اقدام نماييد',
#  'لاين آب پن كانواير ، بعد از ولو اصلي نشتي دارد',
#  'فن تهويه پولپيت كولينگ روشن نمي شود',
#  'نصب هواكش',
#  'لطفا نسبت به رفع عيب روشنايي اقدام گردد',
#  'نصب هواكش سرويس بهداشتي',
#  'روشنايي پمپ خانه تيكنر معيوب مي باشد',
#  'روشنايي فيلترينگ معيوب مي باشد',
#  'لطفا نسبت ساخت و نصب روبند تابلو اقدام نماييد',
#  'سنسور ويبره سمت موتور اصلي 710FN2  به صورت لحظه اي آلارم مي گيرد .',
#  'باكس SERVER موجود در پولپيت بالينگ با توجه به محدوديت فضاي اتاق در صورت امكان كوچكتر از باكس فعلي تهيه ونصب شود',
#  'دماي ياتاقان سمت موتور اصلي 710FN4  تا 78 درجه بالا رفته ولي در محل چك شد ومشخص شد كه دما پايين تر از آنچه كه مانيتور شده ، ميباشد',
#  'با توجه به شكستگي دامي لودسل نسبت به رفع عيب آن اقدام نماييد',
#  'فلومتر مربوط به fs02  مشكل دارد',
#  'با توجه به خالي بودن شوت 910BC3  ولي LS  تجهيز همچنان آلارم دارد .',
#  'مسير فلوتر نياز به اصلاح دارد',
#  'لطفا با توجه نصب ويبراتور باز شده در محل جديد طبق مذاكرات شفاهي انجام گرفته، تمهيدات لازم جهت تامين برق براي آن نيز صورت پذيرد (درخواست 93080118)',
#  'لقي و حركت زياد موتور گيربكس7610rf me17',
#  'صداي پيجر داخل پولپيت كولينگ وضوح مناسب ندارد',
#  'زاويه ديسك 4 با توجه به برخورد به سنسور up و استراكچر ديسك به نوار ورودي ، از زاويه 47.5 بالاتر نميرود در حاليكه براي كنترل شرايط كيفي و تشكيل گندله خام نياز به تغييرات زاويه ميباشد .',
#  'لطفا نسبت به نصب ترمينال فيوز شيشه اي به جاي ترمينال سر خط كلمپ هاي دامپر اقدام نماييد',
#  'نياز به نصب ماژول ميباشد',
#  'ديسكانكت و كانكشن كابل موتور جهت تعميرات',
#  'لطفا نسبت به تعويض كنترل سنسور باد اقدام نماييد',
#  'بوبين سوخته است',
#  'آژير مربوط به آلارم بادسنج معيوب مي باشد',
#  'سنسور ss شكسته و نياز به تعويض دارد',
#  'زغال مربوط به موتورها معيوب مي باشد',
#  'لطفا نسبت به پايش وضعيت زغالها اقدام نماييد',
#  'لطفا نسبت به پايش زغالها اقدام نماييد',
#  'سنسور ls 52 عملكرد مناسبي ندارد',
#  'قفل تابلوي متال دتكتور معيوب مي باشد و كاور ندارد',
#  'خريد Carbon BRUSH  براي موتورهاي 150RL1و 930BM  جهت موجودي انبار',
#  'دكمه هاي مربوط به پنل پيجر سمت شمال كوره كنار موتور عملكرد مناسب ندارند .',
#  'لطفا نسبت به تعويض بوبين سوخته مربوط به 940XV45 اقدام نماييد ( انجام شده)',
#  'معيوب بودن روليك هاي weight feeder',
#  'لطفا نسبت به اصلاح تعداد زغالهاي موتور اقدام كنيد',
#  'لطفا نسبت به اصلاح تعداد زغالهاي موتور اقدام كنيد',
#  'شوت ورودي باكت تراولينگ سوراخ شده و ريزش زياد دارد',
#  'درخواست متريال جهت موجودي انبار',
#  'پيچ يكي از سايد وال هاي زنجير تراولينگ سمت شمال افتاده .',
#  'بدنه شمالي هاپر بالاي بانچ گريزلي سوراخ شده',
#  'ريزش زياد گندله از دريچه بازديد روي بدنه غربي شوت وردي به باكت تراولينگ كه باعث تجمع زياد مواد در پشت پايل باكت شده است',
#  'رولر پرس hpgr ويبره زياد دارد',
#  'مشاهده نشتي اسلاري از سيلينگ رابر بالميل',
#  'ريزش مواد از محل رابرهاي دهانه خروجي بين بالميل ( روي وي فيدر ) كه موجب انحراف بلت وي فيدر و كثيف شدن درام  مي شود',
#  'درخواست پيچ و مهره براي تفلون',
#  'پيچ و مهره براي نصب تفلون',
#  'كسري متريال خط',
#  'كسري متريال خط 160',
#  'يكي از پيچ هاي نگهدارنده اسپراكت 740PC2 سمت غرب شل شده',
#  'تجمع  بيش از حد مواد داخل واش باكس  520BC5',
#  'نصب داربست در محل برش خورده چكر پليت',
#  'نشتي اسلاري از گلند اجيتيتور  هر دو سمت فيلتر ديسك يك',
#  'نصب داربست جهت تعويض تفلون هاي معيوب هاپر شمالي',
#  'با توجه به تغيير طرح مدنظر واحد توليد، متريال تكميلي درخواست شود.',
#  'زير گيت يك اسكرين (740GA1) سمت شمال سوراخ شده و ريزش مواد دارد .',
#  'لوله ورودي هوا به شافت 16 تراولينگ از محل اتصال خود جدا شده',
#  'تعويض تفلون هاي هاپر شمالي ناحيه 160',
#  'پيچ كوپل شارژر واگن دمپر بريده',
#  'ريزش گندله داغ از دريچه بازديد غربي باكت الواتور  تراولينگ',
#  'پارچه هاي سكتور دوم  مربوط به رديف هاي 1 و2و4 از فيلتر ديسك يك سوراخ شده',
#  'رابر روي سوپر اسكرو نوار وايد بلت ، سمت شمال بلند شده و با اسكراپر درگير مي شود',
#  'جوشكاري روي استاد شكسته قبلي',
#  'پيش بيني تعميرات استاد مطابق با نظر سازنده دستگاه',
#  'نصب گريتينگ در محل برش خورده چكر پليت زير بلت روي برج',
#  'بدنه داكت ورودي به وت اسكرابر تراولينگ ( قسمت زير داكت) سوراخ شده و نشتي زياد آب دارد .',
#  'تناژ گندله نرمال سايز ( 16-9) خروجي از مش اسكرين 2 به خط 910bc1 به ميزان 27تن بر ساعت مي باشد',
#  'نشتي روغن از لوله متصل به پرشر پليت بالاي ياتاقان شماره 10 مسير رفت زنجير تراولينگ ، سمت شمال',
#  'تناژ گندله نرمال سايز خروجي اسكرين 2 (16-9) به ميزان 27درصد ميباشد و ميزان كاركرد آن 124000 تن  و  ساعت كاركرد 280 ساعت بوده است',
#  'درخواست راد برنجي 16',
#  'يكي از نوز كستينگ هاي گريزلي بار اول از سمت شمال  افتاده',
#  'شافت هاي 22 ، 25 ، 26  مسير رفت زنجير تراولينگ چرخش يكنواخت و نرمال ندارند  كه بعضا باعث بلند شدن گريت پليت ها و ريزش به هاپرهاي روي 910bc1 ميشود ( ريزش از هاپر دابل فلپ 18 شمال زياد است )',
#  'مشاهده پنج عدد از باكت هاي مربوط به باكت الواتور كه ترك خوردگي و شكستگي  دارد',
#  'تعويض كله قندي ها',
#  'تعويض قطعات HPGR',
#  'نصب لرزه گيري فنري به جاي لرزه گير لاستيكي زير شوت',
#  'آكاردوني جك گيت هاي 1 و 3 اسكرين ( 740GA1,3) پاره شده وكارايي ندارد .',
#  'نصب كاور محافظت كننده بالاي گيت دستي ( گيت سوزني)مربوط به شوت ورودي باكت الواتور ،جهت ايمني پرسنل درگير در مقابله با نشتي و ريزش هاي احتمالي  گندله داغ از بالا، بخصوص مواقعي كه نياز به باز يا بسته كردن گيت مي باشد .',
#  'بستن پيچ  هاي نگهدارنده شافت ضربه گير شارژر واگن دمپر',
#  'كوتاه كردن بلت',
#  'پله هاي مربوط به گيت ورودي به باكت  تراولينگ( پله آهني پشت پايل باكت ) دفرمه شده و دو پله اول ندارد',
#  'پله هاي جديد نصب شده منتهي به دريچه هاي بازديد  روي داكت ورودي به 710ep1/2 ، گريتينگ ندارند .',
#  'جوشكاري روي استادهاي شكسته',
#  'آچاركشي مهره كوپل شارژر',
#  'پيچ نگهدارنده شافت 87 به بدنه تراولينگ ، مسير رفت زنجير تراولينگ شل شده',
#  'داكت خروجي باكت تراولينگ به كوره سوراخ شده و ريزش دارد',
#  'پيچ زنجير كوپل شارژر شل شده',
#  'مشاهده نشتي اسلاري از پگينگ اجيتيتور فيلتر ديسك 2 ، سمت موتور',
#  'زنجير دابل فلپ 1 تراولينگ ، سمت شمال پاره شده و بازوها حركت ندارند .',
#  'ساخت شوت جهت جمع آوري غبار از طبقات مختلف',
#  'مشاهده گرفتگي مكرر مسير تخليه لوله  خروجي دابل فلپ 11 كولينگ به سمت pc2',
#  'درخواست جهت موجودي انبار',
#  'نصب داربست در محل',
#  'ريزش مواد از ابتداي نوار روي طبقات ترانسفر تاور',
#  'پيچ ياتاقان بازوي بالايي دابل فلپ 9 كولينگ شل شده',
#  'بدنه هاپر زير اسكرين2 ( روي 910BC1)  سمت شمال ، سوراخ شده و ريزش مواد دارد',
#  'فلنج بيرينگ سمت خلاف اسپراكت در رول شماره 8 شكسته است (بنابر گزارش واحد مكانيك)',
#  'كسري متريال درخواست 93078493',
#  'كسري متريال درخواست 93078493',
#  'نصب داربست جهت اجراي ساپورت وتفلون بالاي درام بوم ريكلايمر',
#  'كسري متريال درخواست 93078493',
#  'نصب داربست بيرون و داخل شوت جهت باز كردن تفلون ها و برشكاري و جوشكاري ورق جنوبي شوت در محل ويبراتور',
#  'نصب داربست بيرون و داخل شوت جهت باز كردن تفلون ها و برشكاري و جوشكاري ورق شمالي شوت در محل ويبراتور',
#  'صداي غيرعادي از گيربكس ريكلايمر',
#  'گرفتگي لوله خروجي دابل فلپ 11 كولينگ به سمت pc2  ( در شيفت دو بار گرفتگي دارد )',
#  'سوراخ شدن  پشت بدنه هاپر بانچ گريزلي ( شمال غرب ) وريزش گندله به پايين كولينگ',
#  'يكي از زنجير هاي ضربه گير داخل پايل گريزلي كولينگ  افتاده',
#  'جابجايي پله هاي مجاور اتاق پرسنل سالن واگن دمپر',
#  'شوت خرجي ايرسيل ابتدايي كوره به سمت باكت سوراخ شده و ريزش مواد دارد',
#  'نصب فيد شوت ورودي به بالميل جهت استارت',
#  'مشاهده دفرمگي و بلند شدن برخي نقاط لاينر هاي داخلي مخزن فيلتر ديسك 1',
#  'نصب دريچه بازديد نزديك به روتاري ولو بر روي بدنه بگ فيلتر',
#  'نصب مش در پايين شوت خروجي بگ فيلتر',
#  'تعويض هد شفت زنجير اپرون فيدر',
#  'تعويض تيل شفت زنجير اپرون فيدر',
#  'تعويض هد شفت زنجير اسكراپر',
#  'تعويض تيل شفت زنجير اسكراپر',
#  'نصب جاروبك روي براكت غلطك هاي زير پلت فرم',
#  'برش دادن كامل درب  هاي بشكه هاي بال موجود در قسمت بالميل جهت تخليه كامل هنگام شارژ به داخل بالميل',
#  'نصب ساپورت مناسب جهت جمع كردن و منظم كردن شيلنگ مربوط به تخليه سود از تانكر در ضلع شمالي مخارن سود .',
#  'پيچ شافت كوپلر آرم شارژر واگن دمپر شل شده',
#  'حركت طولي جرثقيل بالميل مختل شده كه نياز به  بررسي دارد',
#  'ضربه  شافت 22 مسير رفت زنجير تراولينگ  بيشتر از قبل شده',
#  'درخواست متريال HPGR',
#  'لطفا نسبت به تعويض موتور با موتور SPARE اقدام نماييد',
#  'پيچ جهت استوپرهاي ست اسكرو هوزينگها',
#  'با توجه به انجام pm لطفا نسبت به رفع عيب ويبره و لاستيك پنجه اي بين موتور و كوپل اقدام نماييد',
#  'سايش و خرابي ريترن ايدلر موقعيت 4 از بالا',
#  'فاصله دريچه روي داكت غبار گير اسكرين ( طبقه بالاي اسكرين ) با بدنه زياد است و باعث مكش زياد هوا به داكت ميشود كه نياز به اصلاح دريچه جهت سيل كردن بهتر آن ميباشد .',
#  'خرابي بيرينگهاي چرخ زنجير تنشنر',
#  'سايش و سوراخ شدگي لوله هاي دمنده به بگها',
#  'بدنه متحرك اسكرين سمت شرق ريزش مواد دارد',
#  'يكي از گريتينگ هاي زير 510WF1 در محل خود نصب نيست',
#  'افتادن تعدادي از كلمپها و پيچهاي ريل در قسمت گريپر',
#  'قسمت پايين درب  اصلي بالميل ( هر دو درب ) از روي ريل در افتاده',
#  'دو عدد از وي بلت هاي اسكرين يك از پولي بيرون افتاده',
#  'خرابي پيچهاي كاور پيوت شفت آرم خروجي',
#  'تهيه و ساخت باكس فلزي مناسب  ( قابل نصب در كنار ستون هاي كنار زنجير كولينگ)جهت روغنكاري زنجير كولينگ',
#  'تهيه و ساخت سكو  يا استراكچر جهت نگهداري بشكه روغن مربوط به روانكاري زنجير كوينگ ( به صورتي كه بشكه  شيردار به صورت افقي روي آن قرار بگيرد )',
#  'شل بودن زنجير گيربكس',
#  'لطفا نسبت به نصب اسكافل جهت تعميرات روشنايي اقدام گردد',
#  'تعبيه حفره در بدنه استك EP جهت اندازه گيري دبي هوا (تصوير لوله پيتوت اندازه گيري دبي به پيوست مي باشد)',
#  'تعبيه محلي در بدنه استك EP جهت اندازه گيري دبي هوا (تصوير لوله پيتوت اندازه گيري دبي به پيوست مي باشد)',
#  'وسط سوپر اسكرو بلت 610bc13  سوراخ شده',
#  'جهت تعميرات روشنايي لطفا نسبت به نصب داربست فلزي در ناحيه فيلترينگ با هماهنگي آقاي ثقفي اقدام نماييد',
#  'جهت تعميرات روشنايي لطفا نسبت به نصب داربست فلزي با هماهنگي آقاي ثقفي اقدام نماييد',
#  'پنج عدد از كرينگ رولر هاي 510wf4 آسيب ديده وباعث توقف تجهيز شده',
#  'هاپر زير اير سيل ابتداي كوره ريزش مواد دارد .',
#  'يكي از تسمه هاي اسكرين 2 شل شده',
#  'يك قسمت از تسمه هاي داخل شوت ثاويه از بدنه جدا شده',
#  'نشتي اسلاري از اجيتيتور سمت موتور فيلتر ديسك 2 كه با توجه به اضافه كردن پكينگ همچنان نشتي دارد و ظاهرا اسليو  نياز به تعويض دارد',
#  'يك تكه از مش مركز ديسك 6  بلند شده و با اسكراپر درگير است',
#  'مشاهده نشتي آب از بدنه وت اسكرابر تراولينگ ، نزديك به ونچوري',
#  'يكي از رول هاي وسط RS2 جام است',
#  'دو عدد رول هاي وسط 610RS2  جام شده',
#  'ديسكانكت و كانكشن موتور جهت تعويض كامل باكت الويتور',
#  'بازكردن اتصالات برق مربوط به 6 عدد دبل فلپ موتوري me08 تا me13 در توقف گرم آتي',
#  'لطفا موتور spare سرويس گردد',
#  'ساخت كاور فلزي جهت FT 05 و PT و XV موجود',
#  'منهول جنب سرويس بهداشتي درب ندارد',
#  'لطفا نسبت به سرويس موتور اقدام نماييد',
#  'كاور موتور لق ميباشد',
#  'فلوتر نياز به ساپورت دارد',
#  'گيربكس صدا مي دهد',
#  'ساخت واشر جهت cone هاي فن هاي پروسه',
#  'يكي از تسمه هاي اسكرين يك برعكس شده',
#  'مقداري از نسوز ديوار ه كولينگ پشت ستون 17 بيروني ريخته',
#  'بدنه شمال فيد اسپوت شوت بالميل سوراخ شده',
#  'جهت موجودي انبار',
#  'پره هاي كولر گازي صدا دارد',
#  'مرمت كاشي ورودي روشوئي',
#  'نصب داربست جهت اصلاح شوت خروجي باكت الواتور',
#  'نصب داربست جهت تعميرات cone و support cone و تعويض پيچ ها',
#  'نصب داربست جهت تعميرات cone و support cone و تعويض پيچ ها',
#  'ديسكانكت و كانكت نمودن موتور اصلي و جهت انجام تعميرات بر روي گيربكس نوار.(توقف گرم)',
#  'خرابي شوت هاي خروجي باكت الواتور',
#  'نصب داربست جهت رفع نشتي آب وت اسكرابر',
#  'روانكاري ياتاقان هاي فن',
#  'تخريب نسوز و نظافت و جرم ريزي و نسوز پس از نصب بريك افتاده پشت ستون 10 بيروني',
#  'ديسكانكت  كردن موتور جهت تعميرات',
#  'ويبره بالاست',
#  'اتصال دمپر بالا سمت شمال فن جدا شده و نياز به نصب مي باشد',
#  'تعمير هواكش',
#  'خرابي دستگيره و درب توالت. نصب آئينه و جاصابوني.',
#  'تعويض سنگ توالت سرويس بهداشتي',
#  'نصب شيرآلات و شيلنگ سرويس بهداشتي',
#  'لطفا نسبت به سرويس موتور اقدام شود .',
#  'لطفاً نسبت به نصب موتور جديد اقدام گردد . در توقف گرم اتي انجام گردد .',
#  'ياتاقان سمت موتور بسيار صدا مي دهد .',
#  'لطفا در توقف گرم آتي موتور از محل باز و موتور جديد نصب گردد .  با توجه به خرابي ياتاقان احتمال خرابي بيرينگ موتور وجود دارد .',
#  'به تعداد ضربه گير جهت موتور گيربكس نيازمنديم .',
#  'لطفاً جهت پايش پيوسته دماي سر جلوي الكتروموتور نسبت به تراشكاري كپ جلوي موتور و نصب PT100 و كشيدن كابل تا كارت آنالوگ در پست 2 و همچنين تعريف در لاجيك اقدام گردد . پس از اتمام كار و حصول نتايج براي الكتروموتورهاي ديگر انجام گيرد .',
#  'خريد الكتروموتور جهت موجودي انبار',
#  'تعويض موتور سمت جنوب تراولينگ با موتور نو در توقف گرم آتي',
#  'به دو عدد گيرموتور جهت موجودي كارگاه برق نيازمنديم . در تاريخ 9 بهمن ماه دو موتور رزرو از داخل پست برداشته و در محل نصب شد . موجودي پست و كارگاه صفر است .',
#  'تهيه بيرينگ موتورهاي MV جهت موجودي انبار پاميدكو',
#  'پيچ كاور فن در كپ بريده و نياز به قلاويز كاري و اصلاح جاي پيچ مي باشد',
#  'لطفاً موتور در توقف گرم سرويس گردد . با توجه به گزارش ترموگرافي شركت پارسي تك كه به اين درخواست پيوست شده ، بيرينگ موتور خراب مي باشد .',
#  'بررسي و در صورت نياز سرويس موتور با توجه به گزارش ترموگرافي 1400/09',
#  'بررسي موتور و در صورت نياز سرويس موتور طبق گزارش ترموگرافي',
#  'جوشكاري و نصب دستك جهت انجام كار تعميراتي روي فلوسوئيچ لود وال . محلي براي ايستادن نفر نياز است .',
#  'لطفاً نسبت به تست بيرينگ و در صورت نياز تعويض آنها اقدام گردد .',
#  'رزوه پيچ و گام روي شافت روتور مربوط به موتور ويبراتور در موقعيت كولينگ معيوب مي باشد . روتور به شهر جهت اصلاح ارسال گردد .',
#  'لنت ترمز موتور ميتسيوبيشي شكسته است .',
#  'لطفاً موتور ويبره زير زمين كولينگ از محل باز و جهت چك و سرويس به كارگاه برق انتقال يابد . پس از سرويس مجددا در محل نصب گردد .',
#  'پروانه موتور سرويس شده در كارگاه برق نياز به تعويض دارد .',
#  'تعويض موتور ويبراتور زير زمين كولينگ  بدليل عدم عملكرد صحيح .',
#  'جهت سرويس موتور ويبره نياز به مهره مي باشد . فوري',
#  'لطفاً در توقف گرم آتي نسبت ديسكانكت و سرويس موتور و كانكشن موتور يدك در محل اقدام گردد . پس از سرويس موتور در انبار پاي كار جهت يدك قرار گيرد . در حال حاضر موتور يدك با پولي در كارگاه برق موجود است .',
#  'نصب موتور يدك 520bc5 جايگزين الكتروموتور 730an1-me06  موتورهاي گريزلي دور شماره 6 .',
#  'لطفاً در توقف گرم نسبت به باز كردن موتور اقدام و جهت سرويس موتور به كارگاه برق تحويل و پس از اتمام كار مجدد در محل نصب گردد .',
#  'پايش ارتعاشات فن .دماي فن تا 100 درجه رسيده است .',
#  'لطفاً نسبت به آناليز ارتعاشات موتور اقدام گردد . سر موتور  100 درجه سانتيگراد بود كه با فن تا 75 درجه كاهش يافت .',
#  'دماي هوزينگ بيرينگ كوپل به الكتروموتور بيشتر از حد مجاز مي باشد . 88 درجه مي باشد .',
#  'تهيه ضربه گير خروجي گيربكس به علت خرابي . عكس پيوست مي باشد .',
#  'باز كردن موتور جهت سرويس و نصب مجدد ان',
#  'لطفاً نسبت به تعويض موتور بدليل خرابي لنت ترمز آن اقدام گردد . موتور ABB بدليل شكستگي فلنج آن تعمير شد و در حال حاضر در كارگاه برق موجود مي باشد . موتور در محل ميتسوبيشي مي باشد كه لنت آن نياز به تعويض دارد . در توقف گرم آتي انجام شود .',
#  'نصب پولي روي موتور تازه سرويس شده 740VF2 جهت استفاده در شرايط اضطراري . موتور در كارگاه برق جهت نصب پولي آماده مي باشد .',
#  'با توجه به گزارش ترموگرافي شركت صنعت آموز نوين پارسي(پيوست اين درخواست مي باشد) با توجه به ارزيابي الگوي حرارتي بيرينگ سر جلو الكتروموتور و كوپلينگ هم محوري در اولين فرصت بررسي گردد .',
#  'لطفاً در توقف گرم نسبت به تعويض موتور و الايمنت ان اقدام گردد .',
#  'ياتاقان فن صدا مي دهد .',
#  'هواي بسيار داغ از داكت مربوط به گريزلي به موقعيت موتور 720FN2-ME01  , 730DA3-AT01 پرتاب مي شود و باعث داغ شدن اين تجهيزات مي شود . با توجه به احتمال آسيب ديدگي موتور و دمپر  نسبت به هدايت اين هوا به بيرون محوطه اقدام گردد .',
#  'لطفاً جهت نصب اكچويتور 210FN3 در محل اقدام گردد . محل نشستن اكچويتور به دمپر نياز به اورينگ دارد . در زمان تحويل تجهيز به واحد كارگاه برق اورينگ موجود نبود .',
#  'پيچ روي بازوي اكسس دور شماره 15 موجود نيست و باعث ورود گرد و غبار داخل جك شده است .',
#  'دماي سر جلو موتور تا 85 درجه . بررسي و ارسال نتيجه ارتعاشات موتور لطفا.',
#  'چك نمودن روليك هاي سيستم توزين و ساعت زدن انها و همچنين تنظيم نمودن روليك ها در محدوده سيستم توزين از نظر مكانيكي و سپس كاليبره و TARE نمودن آن ( توقف سرد )',
#  'چك نمودن روليك هاي سيستم توزين و ساعت زدن انها و همچنين تنظيم نمودن روليك ها در محدوده سيستم توزين از نظر مكانيكي و سپس كاليبره و TARE نمودن آن ( توقف سرد )',
#  'اضافه كردن يك زغال به هر رينگ موتور به دلايل زير : \n1- بالا رفتن نرخ سايش نسبت به موتور قبلي با مشخصات موتوري يكسان . \n2- ايجاد شكستگي در زغال \n3- ورم كردن (انبساط) زغال در زمان انجام pm مشاهده مي شود .\n4- مشاهده جرقه در زمان استارت تجهيز . \n5- با توجه به يكسان بودن موتور قديمي و جديد فن 4 مشاهده مي شود روي موتور قديمي 21 زغال نصب ولي روي موتور جديد 18 زغال با تيپ يكسان وجود دارد . استارت موتور قديمي به راحتي انجام مي شد ولي موتور جديد با اشكال (تريپ در مرتبه اول ) استارت مي شود .',
#  'جهت انجام pm موتورهاي 710FN5/6 , 730FN1 نياز به زغال مي باشد .',
#  'خريد زغال Carbon Brush 2*16*32*63  , CG 665  , Manufacture: MERSEN جهت موجودي انبار',
#  'لطفاً نسبت به مسدود كردن دريچه ورودي لدر برق به اتاق لوبريكيشن كوره اقدام گردد .',
#  'لطفا نسبت به برشكاري محفظه مربوط به لوبريكيشن روغن 710FN2 جهت نصب فن خنك كننده اقدام گردد . برشكاري بشكل دايره با قطر 10  سانتيمتر و در قسمت بالاي محفظه انجام گيرد . جهت قرار گيري فن طوري باشد تا هوا را از داخل محفظه مكيده و به بيرون براند .',
#  'خريد Carbon Brush  مورد نياز موتورهاي 710FN1/2/3/4 جهت موجودي . ساخت MERSEN',
#  'تعويض كليه دتكتورهاي دود ، حرارتي ، شستي و آژير فلاشر در موقعيت سايت صنعتي و نيمه صنعتي و نصب Device هاي جديد شركت زيمنس مدل Cerberus  و آدرس پذير  بجاي آنها',
#  'لطفاً نسبت به نصب طناب راپ سويئچ اقدام گردد .',
#  'نصب پايه 45 درجه ريل ترمينال در موقعيت ليكوئيد استارتر جهت سهولت كانكشن',
#  'جهت انجام يكپارچه سازي سيستم اعلام حريق سايت صنعتي (مرحله اول) نياز به متريال مي باشد . لوپ كردن دو زون سيستم متعارف طبقه اول و دوم بالينگ . اشكال سيستمي در درخواست شماره 93080756 /93081002',
#  'لطفاً  در توقف گرم نسبت به پراگرم كردن و تعويض mini plc  ليكوئيد استارتر و تعويض سيم هاي كوتاه ، زدن شماره و حرف سيم روي ان اقدام گردد .',
#  'لطفاً  در توقف گرم نسبت به پراگرم كردن و تعويض mini plc  ليكوئيد استارتر و تعويض سيم هاي كوتاه ، زدن شماره و حرف سيم روي ان اقدام گردد .',
#  'سر سنسور TS مربوط به تجهيز شكسته است . در صورت نياز تعويض گردد .',
#  'جهت اتصال سيستم اعلام حريق سايت صنعتي به پنل اعلام حريق در موقعيت پست دو نياز به كابل مي باشد . با پس كش كردن كابل ها از طبقه دوم بالينگ به سمت پنل جديد سمت درب ورودي  كابل ها كوتاه آمد .',
#  'جهت انجام يكپارچه سازي سيستم اعلام حريق سايت صنعتي (مرحله اول) نياز به كابل مي باشد . لوپ كردن دو زون سيستم متعارف طبقه اول و دوم بالينگ . اشكال سيستمي در درخواست شماره 93080756',
#  'جهت انجام يكپارچه سازي سيستم اعلام حريق سايت صنعتي (مرحله اول) نياز به كابل مي باشد .',
#  'جهت گرمايش كابين سيستم گريس تراولينگ در طبقه دوم و سمت شمال نياز به ترموستات مي باشد .',
#  'تهيه متريال جهت موجودي انبار',
#  'لطفاً نسبت به فيكس نمودن پندانت ويچ گريزلي دور اقدام گردد . محل پندانت و آژير مربوطه در درخواست ديگر تغيير يافته است .',
#  'جهت تست',
#  'خريد Carbon Brush  ساخت شركت MERSEN جهت موجودي انبار .',
#  'خريد وسايل مورد نياز آزمايشگاه كاليبراسيون',
#  'جهت سيستم تحت فشار نياز به دستگاه هوشمند كنترل پمپ آب مدل هدفيكس ساخت شركت تفسان همراه با سنسور فشار مي باشد . خواهشمند است بجز ست سنسور و كنترلر ، تعداد 3 عدد سنسور فشار  مناسب كنترلر نيز بصورت يدكي تهيه گردد .',
#  'نرخ سايش رينگ M دوبرابر ديگر رينگهاست .',
#  'خريد تجهيزات ابزاردقيق فن هاي پروسه جهت موجودي انبار پاميدكو',
#  'ترانسميتر دما مشكل دارد و نياز به تعويض دارد .',
#  'خريد فلو سوئيچ آب داخل پنل دوربين كوره جهت موجودي انبار پاميدكو',
#  'لطفاً در توقف سرد نسبت به بازديد و اطمينان از سالم بودن كليه غلاف ترموكوپلها ناحيه كولينگ و سالم  و باز بودن مسير هواي نمونه گير PT ها اطمينان حاصل پيدا كنيد . ترموكوپلها در صورت شكستگي يا سايش بيش از حد تعويض و گرفتگي مسير سنسور هاي فشار  رفع گردد .730AN1-AA01\n-PT05/6/07/8/9/10 و 730AN1-TE11,12',
#  'لطفاً در توقف سرد نسبت به بازديد از زون ناحيه 4 تراولينگ و بررسي ترمووال ترموكوپلهاي 28/29/30/31 اقدام و  در صورت سايش نسبت به همكاري با واحد كارگاه برق و باز كردن ترمووال جهت برشكاري و جوشكاري فلنج روي لوله نو و نصب مجدد در محل اقدام گردد .',
#  'جهت پنل دوربين كوره نياز به UPPER COVER FOR REGULATOR AND FILTER REGULATOR  مي باشد .',
#  'تصوير دوربين پن كانواير واضح نيست .',
#  'خريد دو ست كامل تجهيز دوربين كوره شامل : پنل كنترل ، دوربين ، جك و كالسكه .',
#  'سنسور ويبره سمت موتور كمكي خراب است',
#  'طراحي و ساخت تيوپ آبگرد و هوا رو جهت تجهيز پايرومتر .',
#  'خريد ترموكوپل هاي ناحيه تراولينگ جهت موجودي انبار',
#  'خريد ترموكوپل ناحيه كولينگ جهت موجودي انبار',
#  'خريد ترموكوپل هاي ناحيه كوره جهت موجودي انبار',
#  'لطفاً پايرومتر از مدار خارج گردد تا شيلنگ هواي آن تعويض گردد . شيلنگ سوراخ مي باشد .',
#  'نصب دوربين جهت نصب در محل تراولينگ',
#  'جهت رفع عيب دوربين پن كانواير نياز به كانورتر مي باشد .',
#  'جهت دوربين پن كانواير نياز به لنز داريم. قبلا با درخواست 9379736 دوربين پاناسونيك با كد 44002010019 تحويل گرفته شد كه لنز بهمراه نداشت .',
#  'لطفاً جهت موجودي انبار نسبت به خريد دوربين همراه با لنز آن اقدام گردد .',
#  'خريد مبدل نوري به آنالوگ (يك سمت كانكتور فيبر نوري و كابل نوري سينگل مود  و طرف ديگر  كانكتور BNC50 و كابل كواكسيال ) جهت اتصال دوربين هاي سايت به اتاق كنترل . يكي Transmitter و يكي  Reciever  . در صورت امكان دو طرفه بجاي يكطرفه درخواست گردد .',
#  'خريد HART Handheld Communicator , type: DHH805-G جهت كاليبراسيون تجهيزات ابزاردقيق',
#  '720KL1-PT03 زود به زود از كاليبره خارج مي شود . نياز است تعويض گردد .',
#  'سنسور فشار قابل نصب روي دستگاه هوشمند كنترل پمپ آب مدل هدفيكس ساخت شركت تفسان معيوب مي باشد .',
#  'طلق محافظ روي ترانسميتر دماي مربوط به ياتاقان سمت خلاف موتور شكسته است .',
#  'لطفاً نسبت به تعويض پريز معيوب و رفع عيب پرژكتور در موقعيت ديواره شمالي لوبريكيشن كوره سمت كولينگ اقدام گردد . باكس پريز تكفاز و سه فاز نيز در موقعيت كولينگ طبقه كف و سمت پن كانوايرها نيز تميز و روبنده ترمينال ها بسته و درب آن بسته شود . چراغ سيگنال ها در صورت خرابي تعويض گردد .',
#  'جهت تعويض سري synova  با سري جديد 4 كارت مدل FCL 2001-A1نياز مي باشد',
#  'مبدل فيبر نوري و كابل فيبر نوري جهت يكپارچگي سيستم اعلام حريق نياز مي باشد',
#  'جهت يكپارچه كردن سيستم اعلام حريق سايت صنعتي نسبت به لوپ كردن طبقات يك و دو بالينگ و تعويض كليه دتكتورها، آژيرها و شستي هاي سينواي سيستم متعارف و نصب دتكتورها، آژيرها و شستي سربروس (جديد) آدرس پذير بجاي آن اقدام گردد . در حال حاضر طبقه اول و دوم و هر طبقه ضلع شرقي و غربي شامل چهار زون مي باشد كه با اين اقدام ما فقط يك لوپ آدرس پذير خواهيم داشت . لوپ مستقيما به پنل 726 جديد در موقعيت پست دو متصل مي شود .',
#  'جهت راه اندازي پنل  726 مربوط به سيستم اعلام حريق سايت صنعتي داخل پست دو و همچنين لوپ كردن سيستم اعلام حريق سايت نيمه صنعتي اقدامات لازم صورت پذيرد .',
#  'لطفاً نسبت به تعويض پرژكتورهاي سوخته در طبقه همكف كولينگ اقدام گردد . سه پرژكتور مازي نور بخار سديم باز و بجاي آن پرژكتور led 104 وات نصب گردد .',
#  'لطفاً كليه دتكتورهاي متعارف دود ، حرارتي ، شستي و آژير سيستم اعلام حريق در موقعيت رستوران حذف و تجهيزات آدرس پذير جديد زيمنس cerberus siemens در محل نصب گردد . كليه كابلها بايستي شيلددار و مورد تاييد استاندارد LPCB باشد .',
#  'اتصال نمونه گير 710TG1-AA01-PT19 نياز به اصلاح دارد .',
#  'كولر گازي اتاقك O2 (آناليزور اكسيژن واقع در طبقه سوم تراولينگ و سمت شمال ) خراب است . فوري .',
#  'فشار هواي جك هاي دوربين كوره كم است . جك عملكرد صحيح ندارد . بررسي فشار خط هوا در اين محل لطفا',
#  'تهيه ولو يدك جهت نصب روي كنترل ولو 13 بالميل . به علت زمان بر بودن اسيد شويي ولو نياز است ولو جديد بجاي آن نصب گردد . فوري',
#  'قفل درب سنسور اكسيژن در موقعيت طبقه دوم تراولينگ سمت شمال خراب است .',
#  'لطفاً نسبت به مسدود كردن دريچه ورودي لدر برق به اتاق لوبريكيشن كوره اقدام گردد . پيشنهاد مي گردد ورق نصب گردد .',
#  'كر گيري كف بتني پست دو ، سمت درب كوچك رو به آسانسور ، جهت كشيدن كابل هاي اعلام حريق . به تعداد يكي نياز است .',
#  'ديواره كنار منهول برق تجهيز پن كانواير يك تخريب شده است . لطفاً ديواره اصلاح گردد . عكس پيوست درخواست مي باشد .',
#  'پيچ روي بازوي اكسس دور شماره 15 موجود نيست و باعث ورود گرد و غبار داخل جك شده است .',
#  'پينيون جنوبي در سمت غرب درگيري بيشتري نسبت به شرق دارد',
#  'قسمت ابتدايي گيربكس صداي غير عادي دارد',
#  'فيلر بيرينگ هاي سمت شرق زيادتر از حد نرمال مي باشد . ( 0.8 ميليمتر )',
#  'ريترن اول زير بلت سمت جنوب و ريترن انتهاي خط سمت شمال خراب مي باشد . اسكرت برد زير درام انتهاي خط سمت شمال نياز به تنظيم دارد زيرا با بلت درگيري ندارد . رابر وي كلينر نياز به تعويض دارد.',
#  'اسكرت بردهاي ابتداي خط سايش دارد و نياز به تعويض دارد',
#  'دنده هاي پينيون سمت گيربكس سايش دارد . لطفا توسط كارشناس مربوطه بررسي گردد و در صورت نياز براي تعويض اقدام شود .',
#  'اسكرت بردهاي ابتداي خط ساييده شده و نياز به تعويض دارد و همچنين تسمه هاي نگهدارنده سمت جنوب شكسته است .',
#  'سيل هاس كاور دو طرف كوپلينگ خراب شده و باعث نشتي گريس گرديده است و نياز به تعويض دارد',
#  'تمام كاتينگ ليپ هاي باكت ها نياز به تعويض دارند .',
#  'بدنه باكت شماره 4 سوراخ مي باشد',
#  'رينگ فلزي سيل سمت شرق از جاي خود بيرون آمده و روي شفت آزادانه مي چرخد .',
#  'كرينگ آيدلر انتهايي كنار گيربكس خراب مي باشد',
#  'رول شماره 23 مشكل دارد . همچنين فلنچ بيرينگ هاي 6 و 8 و 11 و 14 سمت زنجير خراب مي باشند .',
#  'كاتينگ ليپهاي باكتهاي شماره 1 و 2 و 3 و 4 و 5 سايش داشته و به تعويض نياز دارد . همچنين بدنه باكتهاي شماره 1 و 7 سوراخ مي باشد .',
#  'گريتينگ مربوط به پله شماره 10 دفورمه مي باشد و بايد تعويض گردد .',
#  'تمامي كفشك ها نياز به تعويض دارند .',
#  'جاي جوش قبلي ترك خوردگي دارد',
#  'اسكرت برد در هر دو سمت سايش دارد',
#  'رابر اسكرت برد سمت شمال سايش دارد',
#  'نصب دريچه بر روي منهول روبه روي سرويس بهداشتي واگن دامپر جهت جلوگيري از افتادن افراد به داخل منهول( فايل عكس پيوستي)',
#  'نصب هندريل پشت rs  ديسك 1',
#  'سند بلاست شاهين ساخته شده در زمان تعميات سرد قبل از رنگ آميزي',
#  'نصب هندريل كشويي محل برداشتن پمپ طبقه زير زمين پن كانواير',
#  'بستن و جايگذاري مش گاردهاي پن كانواير 2',
#  'نصب ورق هاي آويزان به ديواره اسانسور ساختمان ميكسينگ ( محل نصب ساپورت اسانسور به ساختمان )',
#  'اصلاح محافظ هاي روي جوي آب پشت ميكسينگ ( هماهنگي با عمراني در زمان اصلاح )',
#  'بازكردن داربست هاي نا ايمن',
#  'اصلاح پله دسترسي به پلت فرم باكت ( پشت پايل امرجنسي )',
#  'ساخت درب منهول فلزي جهت منهول برق نزديكي انبار',
#  'طراحي ايستگاه و محل دسترسي به روي جرثقيل سقفي',
#  'طراحي ايستگاه و محل دستزسي به جرثقيل سقفي ( مطابق با نظريه كارشناسان و بازرسان شركت ذيصلاح صدور گواهينامه سلامت )',
#  'طراحي و نصب ايستگاه و محل دسترسي به جرثقيل سقفي ( مطابق با نظريه كارشناسان و بازرسان شركت هاي ذيصلاح صدور گواهينامه سلامت )',
#  'نصب داربست در اطراف منهول برق در موقعيت ساختمان فيلترينگ ( جهت جلوگيري از سقوط افراد به داخل منهول در زمان برداشتن درب فلزي)',
#  'نصب مش گارد روي هندريل هاي طبقه سوم جهت جلوگيري از ريزش متريال مطابق با سمت جنوب.',
#  'نصب هندريل اطراف حوضچه داخل پمپ خانه فيلترينگ جهت جلوگيري از سقوط به داخل حوضچه ( مطرح شدن در بازديد VIP. ضمنا پايه هندريل ها  ثابت و نصب روي زمين و هندريل هاي متحرك جهت بازشدن جهت تعميرات',
#  'نصب و جوشكاري هندريل راهرو زير شوت هاي انتقال مواد به خطوط ارفع و غدير. بسته شدن مسير و عدم تردد افراد از زير شوت',
#  'تعمير پله اول چهارپايه موجود در موقعيت بالينگ ديسك به علت دفرمگي- ايجاد دستيگره سراسري در دو طرف پله',
#  'در صورت بروز مشكل مكانيكي ، خطاي انساني و باز شدن ناگهاني دمپر و فشار دمش بالا احتمال كشيده شدن به سمت داخل وجود دارد.',
#  'در صورت بروز مشكل مكانيكي ، خطاي انساني و باز شدن ناگهاني دمپر و فشار دمش بالا احتمال كشيده شدن به سمت داخل وجود دارد.',
#  'در صورت بروز مشكل مكانيكي ، خطاي انساني و باز شدن ناگهاني دمپر و فشار دمش بالا احتمال كشيده شدن به سمت داخل وجود دارد.',
#  'در صورت بروز مشكل مكانيكي ، خطاي انساني و باز شدن ناگهاني دمپر و فشار دمش بالا احتمال كشيده شدن به سمت داخل وجود دارد.',
#  'در صورت بروز مشكل مكانيكي ، خطاي انساني و باز شدن ناگهاني دمپر و فشار دمش بالا احتمال كشيده شدن به سمت داخل وجود دارد.',
#  'در صورت بروز مشكل مكانيكي ، خطاي انساني و باز شدن ناگهاني دمپر و فشار دمش بالا احتمال كشيده شدن به سمت داخل وجود دارد.',
#  'جهت مشخص شدن ارتفاع نصب و نوع ساخت ميله بارفيكس با اقاي حيدري هماهنگ گردد.',
#  'باتوجه به قطعي برق و امكان ايجاد شرايط اضطراي و اورژانسي، تجهيزات برقي بهداري نيازمند برق اضطراري ميباشد',
#  'بازكردن كمدهاي داخل اتاق رخكتن و انتقال به اتاق اموزش طبقه بالينگ',
#  'رنگ آميزي هندريل هاي طبقه 4 بالينگ به رنگ سبز و تا انتهاي مسير بازديد . فلوچارت مسير بازديد به پيوست ارسال ميگردد.',
#  'چسباندن چسب سبز از اسانسور طبقه 2 به اتاق كنترل و نوشته مسير بازديد در طول مسير',
#  'كندن سنگ جدول جهت ساخت و ايجاد پاركينگ واحد. ضمنا نامه به مدير سايت گندله سازي ارجاع شده و تاييديه محل گرفته شده است.',
#  'نصب هندريل هاي زميني و چرخ دار زير جرثقيل سقفي 30تن در ناحيه بالينگ',
#  'رنگ آميزي شاهين ساخته شده در زمان تعميرات سرد ( قبل از رنگ اميزي سندبلاست ، تست PT ، مرحه اخر رنگ ميزي با پيستوله - رنگ با پوشش قوي و ضد زنگ نارنجي )',
#  'ايمن سازي و محك كردن هندريل هاي بالاي پن كانواير روي روي بتن با رول بلت',
#  'ايمن سازي و محكم كردن هندريل بالاي پن كانواير بر روي بتن با رول بلت',
#  'اصلاح موزاييك سرويس بهداشتي جداسازي جهت جلوگيري از تجمع آب',
#  'خراب بودن شيرهاي رادياتورهاي اتاق سرپرستان . كارشناسان و ريزش و نشتي اب',
#  'اصلاح روشنايي طبقات ترانس تاور 120',
#  'اصلاح روشنايي طبقه سوم تراولينگ سمت جنوب',
#  'عدم روشنايي كامل خط و نوارنقاله به علت سوختگي مهتابي ها',
#  'باسلام : تعمير وتعويض وشستشوي پرده وميل پرده اتاق كنترل ، ابدارخانه ، اتاق ورزش آتش نشاني',
#  'درخواست دريجه كولر اتاف كارشناسان واتاق كنترل پيرو درخواسهاي شماره 93075200و93075794 كه انجام نشد مجدا درخواست نصب مي شود',
#  'ساخت مبل بارفيكس جهت آزمون آتش نشانان مجتمع',
#  'جهت تعويض قطعات بر روي شوت (44001020027)نياز به متريال مذكور مي باشد',
#  'خار رولر 26تجهيز مذكور نياز به جوشكاري دارد',
#  'تعمير واصلاح لقي پينيون گيربكس',
#  'تعويض كامل لاينرهاي كف وي اف در توقف اينده به دليل  خرابي وفرسودگي',
#  'سيل هاي مربوط به بيرينگ هوزينگ هد شفت باكت الويتور نياز به تعويض دارد',
#  'اصلاح شوت ذوزنقه اي زير ايرسيل كوره',
#  'خرابي و تابيدگي دريچه بازديد شمالي وجنوبي گريزلي ثانويه كه باعث ريزش گندله مي شود',
#  'جدا شدن اتصالات لوله مسي مربوط به گريس خور سر شفت پالت 15 بيروني',
#  'دمونتاژ يك عدد ساپورت رولر داخلي شماره3(44001010188)',
#  'دمونتاژ 4عدد آرم رولر (پالت هاي13/14/16/36)جهت تعيين تكليف',
#  'فرم ايرسيل پشت چرخ  1بيروني سوراخ شده وباعث ريزش گندله مي شود',
#  'باز بودن دور تا دور هود مكش wet scraber',
#  'با تجه به خرابي لينك وپين و...نياز به تعويض كامل باكت الويتور مي باشد',
#  'جدا شدن كاور (سايه بان )جرثقيل مربوط به تجهيز اسكرين',
#  'جدا شدن كاور (سايه بان)جرثقيل مربوط به تجهيز اسكرين',
#  'باز بودن دور تادور هود مكش wet scraber ابتداي خط',
#  'دمونتاژ 4عدد ازآرم رولر هاي پالت توسط مكانيك',
#  'نظر به آنكه لوله هاي ويبراتوري زير دبل فلپ ها به دفعات مكرر شكسته وخرابي دارد وهمچنين مواد داخل ان انباشته وباعث گرفتگي آن مي شود درخواست مي شود به طرح اوليه خود برگشته وكليه لوله هاي ويبراتوري حذف گردد.',
#  'باتوجه به خرابي پليت لاينرها ي كف تجهيز نياز به اصلاح وتعمير ودر صورت نياز تعويض دارد',
#  'لطفا جهت تامين متريال و آماده سازي ومونتاژ زنجير تجهيز مذكور براي توقفات اينده اقدام گردد.',
#  'احتراما،موارد ذيل تجهيز مربوطه نياز به اصلاح وتعويض دارد\n1-بليت هاي شوت ورودي مواد\n2-پليت هاي ديواره شرقي تجهيز\n3-ورق هاردوكس كور كننده گريزلي\n4-اسكريت رابر هاي معيوب',
#  'لطفا نسبت به دمونتاژ تيل شفت باكت الويتور اقدام گردد.',
#  'لطفا نسبت به دمونتاژ (پن وچرخ وپين وبوش و...)تجهيز مذكور اقدا م گردد',
#  '2عدد شلنگ سرويس بهداشتي ساختمان تعميرات نياز به تعويض دارد',
#  'v-belt فرسوده است',
#  'خط لوله آب كولينگ واتر مربوط به سيل واتر شكسته است',
#  'ابگرمكن دفتر مخازن 5000 مخزن سايت چندين مخزن آن سوراخ شده و صرفه تعمير مجدد ندارد',
#  'لازم است براي انتقال آب باران  سقف پمپ خانه ، لوله اب باران نصب شود',
#  'پينچ ولو خروجي سوراخ است',
#  'لوله مربوط به فلاشينگ شيربرقي نشتي دارد',
#  'disconnection  شيربرقي940xv45 جهت انجام تعميرات ولو آن و connection مجددا پس از نصب ولو',
#  'اسپول تبديل 3*6 خط ساكشن سوراخ شده است',
#  'پمپ روشن نمي شود',
#  'پمپ آب كولر ابي 5000مربوط به ساختمان كارت زني سوخته است',
#  'سقف آبدارخانه تاسيسات صنعتي آب مي دهد',
#  'يكي از توالت هاي سرويس بهداشتي رختكن قديم مسير فلاشتانك به كاسه توالت مسدود است و لازم است اطراف كاسه توالت كاشي هاي آن برداشته شود(هماهنگي با تاسيسات نيمه صنعتي)',
#  'پرده عمودي هاي ساختمان چاه ابشور معيوب است',
#  'ميزان 60ليتر ضد يخ جهت مخزن آب تبخيركننده گاز نياز است(فوري)',
#  'خط فلاشينگ مربوط به سيستم سود زني نياز به چك ولو دارد(جهت جلوگيري از ورود سود به خط آب فلاشينگ در زمان توقف پمپ آب)',
#  'جهت جلوگيري از شكستگي قسمت ورودي و خروجي دوزينگ پمپ هاي سود نياز است كه شيلنگها بصورت يكسر هرزگرد باشد',
#  'ولو مربوط به منهول مخازن خليل آباد سوراخ شده است',
#  'نصب داربست اطراف پمپ جهت تعويض اسپول خروجي پمپ950ps3',
#  'پمپ اب نمك سختيگير روشن نمي شود',
#  'پمپ روشن نمي شود',
#  'زماني كه بويلر آلارم دارد و روشن نمي شود هيچگونه هشدار بصري و  شنيداري جهت فهميدن بهره بردار وجود ندارد',
#  'زماني كه بويلر آلارم دارد و روشن نمي شود هيچگونه هشدار بصري و  شنيداري جهت فهميدن بهره بردار وجود ندارد',
#  'زماني كه بويلر آلارم دارد و روشن نمي شود هيچگونه هشدار بصري و  شنيداري جهت فهميدن بهره بردار وجود ندارد',
#  'نصب داربست جهت تعويض لوله هاي شاهد خط پروسه (هماهنگي با تاسيسات)',
#  'الكتروموتور صداي غيرعادي دارد',
#  'هر سه شيلنگ سرويس بهداشتي با نگهدارنده سر شيلنگ مناسب نيستن ونياز به تعويض دارد.',
#  'طراحي مداري جهت دادن آلارم در زمان خاموشي بويلر طبق پيشنهاد پيوست',
#  'خرابي ليتيوم برومايد براي چيلر جذبي ابارا RCP007',
#  'قطعات براي نصب كنتور اب سرد',
#  'درخواست كالا جهت ساخت پايه همزن',
#  'خرابي گيربكس ولو كنترولي',
#  'لرزه گير ترك دارد',
#  'لاستيك لرزه گير "6 داراي ترك ميباشد.',
#  'شير فشاري "1/2 براي گيج ها',
#  'گسكيت "6 جهت اببندي فلنج تعويض گردد.',
#  'خرابي شير وكيوم طبق عكس پيوست',
#  'دماسنج غلاف دار طبق شكل پيوست.',
#  'درموتورخانه بالينگ جهت انجام لوله كشي براي چيلر جذبي به برج خنك كن نياز به قسمتي از ديواره آجري حدود 50.50 سانتيمتر تخريب و پس از لوله كشي تعمير شود.',
#  'لرزه گير خراب است',
#  'نصب دالهاي بتوني  كانال اب گرم مابين ساختمان اتش نشاني و ساختمان cpg وايزوگام كردن كانالهي نزديك قسمتهاي  درختكاري شده',
#  'تهيه و نصب سيم برق با كليد برق مناسب براي راه اندازي همزن نمك سختي گير',
#  'لرزه گير ترك دارد',
#  'پمپ هاي خط نياز به تعويض y فيلتر dn80  ,dn100 دارند',
#  'جابجايي  يك لوله جهت نصب ولوكنترولي  بين دولوله خروجي  ورودي از موتورخانه مركزي به كولينگ تاور',
#  'نياز به داربست براي موتورخانه بالينگ',
#  'گرفتگي مسير اب باران سالن اماده سازي',
#  'هرز شدن شير اب حوضچه شستشوي دوغاب سالن اماده سازي ازمايشگاه',
#  'نصب  شيلنگ براي تي شويي',
#  'فن آون كوچك كار نميكند',
#  'قطع و وصل  شدن صفحه نمايش اعداد دستگاه ccs',
#  'خرابي كليد صفر كردن ترازوي مخصوص پروسيتي',
#  'فن هواساز مرتب تريپ خورده و خاموش ميشود لطفا بررسي شود',
#  'درب برقي ازمايشگاه بالا و پايين نميرود',
#  'لوله فاضلاب ظرفشويي فيزيكال گرفته است و اب كف سالن پخش ميشود',
#  'خرابي قفل و دستگيره درب سرويس بهداشتي اقايان',
#  'خرابي درب برقي آزمايشگاه',
#  'گرفتگي سيفون ظرفشويي سالن فيزيكال',
#  'ايجاد پله و مسير ايمن و راحت به محل نمونه گيري اسلاري چون مسير فعلي غير ايمن و سخت ميباشد',
#  'دستگاه قرص سازي روشن نميشود(برق ندارد)',
#  'دستگاه ccs صداي غيرعادي دارد',
#  'كاهش ويبره ويبراتور داخل شوت طبق فرم set point',
#  'فاصله بين رول هاي ثابت ومتحرك چك شود',
#  'بيرينگ رول شماره 27 خسمت خلاف زنجير مشكل دارد',
#  'موتور SLOW شماره يك كاور كوپلينگ گيربكس ندارد',
#  'ساخت لوله ضربه به بدنه شوت با سر تفلوني',
#  'از داكت خط نشتي آب زياد داريم',
#  'انحراف بلت سمت جنوب',
#  'گيت حركت ندارد',
#  'خرابي تعدادي از ريترن آيدلر و روليك خط',
#  'صداي غير عادي از زنجير گيربكس خط',
#  'انحراف خط',
#  'اسكراپر داخل شوت عملكرد مناسبي ندارد',
#  'ورق هاي دور هاپر گيت بريده شود',
#  'ياتاقان رول شماره 3 سمت غرب مشكل دارد',
#  'بيرون آمدن پين جك كلمپ شماره 3',
#  'نشتي روغن از گيربكس خط',
#  'مش درشت دانه نياز به برشكاري دارد (بزرگ كردن روزنه ها )گندله به سمت چانك هدايت مي شود',
#  'مش ريز دانه مشكل دارد گندله سمت پايل ريز دانه مي رود',
#  'باكس LS زير شوت RS سمت جنوب خوردگي دارد',
#  'گيربكس باكت ويل ويبره دارد',
#  'انحراف بلت',
#  'استفاده كردن موتور كمكي در تعميرات جهت چرخاندن رول ثابت وجود ندارد',
#  'پيچ هاي مربوط به قفل ست اسكرو رولپرس سمت غرب به علت ويبره شديد شل شده است',
#  'بادبندهاي سمت شمال شرقي ديواره وسقف نياز به جوشكاري دارد(سوله واگن دامپر)',
#  'نشتي روغن از كاسه نمد گيربكس',
#  'تسمه هاي فن ترك خورده است',
#  'فن استارت نمي شود به علت آلارم ssمربوط به تسمه مي باشد',
#  'برزنت داكت بعد ايمپلر فن 3 پاره مي باشد',
#  'خرابي پين آرم شارژر واگن دامپر',
#  'تسمه هاي فن صداي غير عادي دارند نياز به ريگلاژ دارند',
#  'پين هاي كوپل آرم شارژر بريده شده است',
#  'ياتاقان رول شماره 15 سمت غرب خراب شده است',
#  'OVER LOAD شدن گيت (ميكروسوييچي مي باشد)',
#  'ميكروسوييچ هاي گيت بايد تنظيم شود',
#  'تغيير زمان عملكرد شير تخليه مخزن رطوبت گير بك فيلتر به علت وجود رطوبت زياد هوا فشرده داخل مخزن (از دو ساعت 20 ثانيه به 1 ساعت 60 ثانيه تغيير يابد )',
#  'خاموش بودن تمامي مهتابي هاي راه پله HPGR',
#  'قطعي كابل دريفت سوئيچ بوم استكر سمت غرب',
#  'نصب شب بند براي بستن دريچه شوت زير rs',
#  'شكستگي استاد رول ثابت',
#  'تسمه زير ساپورت ويبراتور شوت زير rs در سه نقطه شكسته است',
#  'درزگيرهاي دريچه هاي بازديد رول هاي ثابت ومتحرك نصب نمي باشد (در صورت امكان پيچ شود به بدنه )',
#  'خرابي روكش رول شماره 37 سمت شرق',
#  'يكي ديگر از تفلون هاي بين 150 كنده شده است',
#  'ريزش از كنار اسكريت بورد سمت شرق پايين هاپر در موقعيت بالاي خط  نياز به نصب يك پليت مي باشد',
#  'نشتي آب از زير پمپ',
#  'بك فيلتر عمليات پلاس زني را انجام نمي دهد',
#  'ولو ورودي به 150WP2 جام مي باشد',
#  'نصب پرده اتاق كنترل',
#  'دستگيره درب اتاق كابين ريكلايمر مشكل دارد',
#  'رنگ آميزي اتاق واگن دامپر و نبشي سقف آبدارخانه واگن دامپر',
#  'شكسته شدن تعدادي از سنگ جدول باسكول ورودي',
#  'قفل درب كانكس طبقه خراب مي باشد',
#  'ييرون امدن پين جك كلمپ شماره 3',
#  'رنگ آميزي سازه هاي پله جديد اتاق كنترل واگن دامپر',
#  'نصب ستون پله جديد اتاق كنترل به كف بتن',
#  'رنگ آميزي ايستگاه بالاي بك فيلتر در قسمت شير برقي ها',
#  'ايستگاه جديد مربوط به شير برقي هاي بك فيلتر820BF3نياز رنگ آميزي دارد (رنگ سبز)',
#  'نشتي ازشير تنظيم جك آرم شارژر',
#  'آلارم فيلتر برگشتي (اتاق هيدروليك)',
#  'آبگرمكن سرويس بهداشتي باسكول مشكل دارد (به گفته پرسنل تاسيسات مشكل المنت دارد)',
#  'آبگرمكن مربوط به سرويس بهداشتي باسكول مشكل دارد (المنت خراب است)',
#  'المنت آبگرمكن ديواري سرويس بهداشتي باسكول خراب است',
#  'عملكرد شاستي استارت استپ مشكل دارد',
#  'شكستگي نازل گراندمانيتور',
#  'نشتي مابين دو فيلتر كمپرسور داخل اتاقك',
#  'گرفتگي لوله تخليه آب سرد كن داخل اتاق جداسازي',
#  'خرابي دكمه هاي بلت اسكل موقعيت بوم ريكلايمر امكان ريست كردن وجود ندارد',
#  'LS شوت مكرر آلارم كاذب دارد باعث توقف مجموعه مي شود',
#  'آلارم LS  داريم (كار انجام شده است)',
#  'امكان جابجاي گيت نمي باشد OVER LOAD مي شود',
#  'موتور اسكرو صدا ميدهد مربوط پروانه آن مي باشد',
#  'شير يكي از سرويس بهداشتي لودينگ خراب است',
#  'برق آبگرمكن خورشيدي سرويس بهداشتي واگن دامپر بدليل نصب شدن آبگرمكن ديواري قطع شود',
#  'شير آب روشويي اتاق جداسازي صافي آن گرفته است',
#  'كانال مربوط پشت سرويس بهداشتي انباشت وبرداشت كنده شده است',
#  'شيلنگ سرويس بهداشتي و فلاش تانك جداسازي خراب است',
#  'اتصال ورودي هوا به بك فيلتر 3 از ناحيه زانوي قطع مي باشد',
#  'شير آب ظرفشويي خراب است',
#  'عدم پالس زني بك فيلتر 3',
#  'نشتي ازكوپلينگ مشاهده شد',
#  'فيلتر قبل شير برقي مربوط مخزن رطوبت گير نياز به سرويس دارد',
#  'تعويض سنسوركابل جمع كن پاور',
#  'سرويس باكس lsبالا و پايين Rs',
#  'آلارم ls شوت زير Rs(انجام شد)',
#  'سرويس باكس LSشوت خطهاي 150BC1,2,3 و سورس گاما',
#  'نظافت LS (انجام شده)',
#  'خرابي سنسور وسطي كابل پاور و عدم تراول دستگاه',
#  'آلارم سيستم گريس . بشكه گريس خالي بود(انجام شد)',
#  'شارژ مخزن روغن دامپر',
#  'بيرون اوردن تفلون از داخل شوت زير ويفيدر 150',
#  'برطرف كردن الارم متال دتكتور',
#  'بوم استكر استارت نمي شود',
#  'بوم استكر استارت نمي شود',
#  'لطفا ترمز موتور كابل جمع كن پاور بررسي شود',
#  'پروانه خنك كننده موتور شكسته است',
#  'جهت روشنايي كمپ e2',
#  'لطفا نسبت به تعويض فن سرويس بهداشتي اقدام شود',
#  'لطفا نواقص برقي رستوران برطرف گردد',
#  'جهت اتمام پروژه نياز به كابل مي باشد',
#  'مرتب آلارم fs دارد.',
#  'مرتب آلارم fs دارد.',
#  'ديافراگم ها خراب است.',
#  'نشتي هوا دارد.',
#  'نشتي آب دارد.',
#  'باز كزدن اتصالات آب ورودي به تجهيز براي باز كردن كاور توسط مكانيك و بستن مجدد پس از اتمام كار مكانيك',
#  'نشتي از مسير آب كولينگ واتر كنار تابلو دوربين و پايرومتر كوره داريم.',
#  'نشتي آب از شير برقي مربوط به 940TN4',
#  'مسير آب كولينگ تجهيزات ابزار دقيق كوره كنار تابلو پايرومتر نشتي دارد.\nبا تشكر',
#  'لوله خروجي CF2 به طرف 940SP6 سوراخ ميباشد.',
#  'با سلام يكي از لوله هاي آب كولينگ اگزولاري استك روي ستون شرقي استك نشتي آب دارد.',
#  'مدت زيادي عدد 36 درصد نشان ميدهد در حالي كه هيچ گرفتگي در بانچ گريزلي نداريم.',
#  'تميز كردن فلوسوييچ',
#  'روشنايي موقعيت گيت بالميل مناسب نميباشد لطفا يك پرژكتور روي سر شوت نصب گردد.\nجهت بازديد هماهنگ كنيد.',
#  'فلو ولو 9 و 10 مربوط به ميكسر يك در زمان بسته بودن تا 2.3 متر مكعب نشتي دارد و در زمان باز شدن نوسان زياد دارد.',
#  'لطفا در توقف گرم صحت عملكرد بلت اسكيل بررسي شود.',
#  'آلارم fs براي لودوال فعال ميباشد.',
#  'روشنايي خطوط 740 و اسكرين نسبت به ساير مناطق با فاصله تقريبا 20 دقيقه روشن ميشود.',
#  'سنسور فشار زون 4 تراولينگ PT19 مشكل دارد',
#  'zs56 به درستي عمل نميكند و نياز به تنظيم دارد.',
#  'نشتي روغن از گيربكس',
#  'آلارم spray of كه توسط روانكار شيفت شب برطرف شد.',
#  'از دريچه روي كاور چرخ دنده اصلي كوره بالاي باكس گريسكاري طرف جنوب نشت گريس دارد كه روي باكس نازل هاي گريس ميريزد.',
#  'نشتي روغن جك جلو RB زياد شده است.',
#  'اسپري روغن روي چرخ دنده هر دو سمت به خوبي كار نميكند.',
#  'گيج روغن ياتاقان طرف موتور كمكي قابل رويت نميباشد و سطح روغن را نميتوان چك كرد.',
#  'گيج روغن ياتاقان طرف موتور كمكي قابل رويت نميباشد و نميتوان سطح روغن را چك كرد.',
#  'گيج روغن ياتاقان طرف غير موتور قابل رويت نميباشد.',
#  'پيچ هاي اتصال جك شمالي rb به كالسكه شل شده و يك پيچ بريده است.',
#  'لوله گريس پالت شماره 3 كنده شده است.',
#  'نشست روغن از سيل گيربكس اصلي',
#  'انتهاي جك جنوبي نشتي روغن دارد.',
#  'اختلاف فشار قبل و بعد از فيلتر روغن خنك كننده k1,2,3,4 زياد شده است.',
#  'نشتي روغن از شافت پولي ديسك 4 زياد شده است.',
#  'آلارم اسپري آف داشت كه توسط رونكار شيفت برطرف شد.',
#  'لوله گريس چرخ سر بازو پالت هاي 5و7و21 خم شده و درست گريسكاري نميشود',
#  'ساپورت ويل هاي شماره 9و13و17 لوله گريس خم شده و درست گريس كاري نميشود.',
#  'از محل سيل جك جوبي تجهيز نشت روغن بيشتر شده است.',
#  'يكي از شلنگ هاي گريس مربوط به ياتاقان طرف جنوب كنده شده است.',
#  'لوله گريس پالت شماره 14 داخلي كولينگ كنده شده است',
#  'الرم اسپري اف دارد',
#  'سيستم لوبريكيشن الارم دارد',
#  'از ترمينال كنار بازوي پالت 5 و 10 نشت گريس داريم.',
#  'كاور زنجير هر دو طرف نياز به روغن دارد.',
#  'گيج روغن گيربكس جنوبي تراولينگ بالا ميباشد.',
#  'نشتي روغن دارد.',
#  'گيج روغن گير بكس موجود نميباشد و سطح روغن قابل چك و كنترل نميباشد ، لطفا گيج نصب شود.',
#  'نشتي اسلاري از پكينگ پمپ',
#  'دو طرف نازل سوراخ شده و نشتي آب ذارد.',
#  'عملكرد كنترل ولو از 10 درصد تا 77 درصد خوب است و مصرف گاز پله پله افزايش ميابد ولي از 77 به بعد مصرف گاز افزايش خيلي زيادي دارد و چندان قابل كنترل نيست.',
#  'شيربرقي در زمان بسته بودن نشتي زياد دارد.',
#  'در زمان راه اندازي آلارم ss ميدهد.',
#  'درام تيل نوار ساييده و نازك شده است.',
#  'دوتا از تسمه ها شل ميباشد.',
#  'تسمه ديسك شل ميباشد و در زمان راه اندازي ديسك صدا ميدهد.',
#  'با توجه به شرايط ديسك و در مقايسه با ساير ديسك ها به نظر ميرسد سرعت ديسك به درستي نشان داده نميشود ، سرعت نشان داده شده براي اين ديسك همواره 0.7 دور بر دقيقه پايين تر از بقيه ديسك ها ميباشد ، لطفا صحت محاسبه و نمايش سرعت بررسي شود.\nتوضيح : زاويه ديسك 6 تفاوتي با زاويه ديسك 5 و 3 و1 ندارد ولي سرعت آن 1rpm پايين تر است.',
#  'دريچه بازديد روي داكت ورودي به غبارگير سيل نيست و مكش هوا دارد.',
#  'چرخ سر بازو پالت هاي 21و25 لق ميباشد:',
#  'ساپورت ويل شماره 8 و 18 كولينگ جام شده است:',
#  'شوت باكت قسمت بالا و در  محل اتصال شوت مثلثي در حال سوراخ شدن ميباشد.',
#  'پارچه فيلتر 1 رديف 1 سكتورهاي 8و9 سوراخ شده و نياز به تعويض دارد.',
#  'نوار انحراف دارد.',
#  'ساپورت رولر هاي شافت هاي 14 و 18 و 26 دز مسير رفت زنجير تراولينگ افتاده است.',
#  'بعضي مواقع صداي غيرعادي دارد كه توسط مكانيك شيفت چك شد.',
#  'يكي از وي بلت ها پاره شده است كه توسط مكانيك شيفت تعويض شد.',
#  'سوپر اسكرو 620BC1 در دو طرف نوار به دليل سايش با رابرها ساييده شده است:',
#  'نشتي اسلاري از سيلينگ رابر بال ميل زياد شده است:',
#  'قسمتي از جوش بدنه فيداندهاپر در محل اتصال به كوره و در محل اتصال پايه ورق هاي سيل كننده طرف جنوب كوره شكسته و نسوز آن ريخته است:',
#  'بلبرينگ سمت جنوب وايدبلت و ناوداني نشيمن گاه آن ساييده شده و خراب شده است',
#  'ميله سنسور جك وايد بلت ساييد هشده است',
#  'روليك روبروي 610BC8 صداي غير عادي دارد.',
#  'اهرم كوپل موتور كمكي بال ميل شكسته است.',
#  'زنجير شل است.',
#  'در زمان استارت به طرف PC1 ريزش دارد.\nعلت ريزش نياز به بررسي كارشناسي بيشتر دارد.',
#  'سمت خلاف موتور ويبره دارد.',
#  'تسمه هاي تجهيز شل ميباشد.',
#  'چكش ثابت اولي از طرف كوره پايپ ها از جاي خود در رفته است.',
#  'چكش ثابت تراولينگ دومي از طرف كوره چهارتا از پايپ ها افتاده است.',
#  'دماي ياتاقان در محل بالا ميباشد.',
#  'ويبره دارد.',
#  'ورق سند سيل ستون 14 بيرون كولينگ دفرمه شده',
#  'صداي غير عادي در طرف موتور اصلي',
#  'صداي غير عادي مخصوصا در زماني كه كالسكه به طرف عقب حركت ميكند.',
#  'بستر ديسك در هر شيفت چند مرتبه ميريزد\nلطفا در توقف گرم پيش رو مش بستر بررسي و ترميم شود.\nبا تشكر',
#  'نياز به تعويض مش ميباشد.',
#  'تراست پايين كاملا درگير شده است.',
#  'تنظيم زنجير كوپل شارژر\nبا سلام در تاريخ درخواست ، تنظيم زنجير توسط مكانيك شيفت انجام شد و به درخواست مكانيك شيفت درخواست كار صادر شده است.',
#  'موقعيت راد شماره 15 تراولينگ طرف جنوب دوتا از پيچ هاي ويرپليت افتاده است.',
#  'دو تا از تسمه ها شل ميباشد.',
#  'با سلام ، اسكراپر داخل شوت نياز به تنظيم دارد.',
#  'صداي غير عادي از يكي از روليك دارد.',
#  'اهرم اتصال فلپ هاي دمپر فن افتاده است.',
#  'مش خروجي بال ميل پاره شده و بايد تعويض شود.',
#  'گيربكس 740bc1 ويبره و نشتي روغن دارد',
#  'طرف شمال سوراخ شده است.',
#  'يكي از تفلون هاي رابرشوت شكسته است ، از پشت رابرشوت مشاهده ميشود.',
#  'زنجير دابل فلاپ 10 طرف جنوب پاره شده است.',
#  'شافت شماره 1 و 98 از طرف كوره در مسير رفت زنجير جام ميباشد.',
#  'رابر طرف شرق bc2 خراب است و ريزش گندله دارد.',
#  'شوت به طرف اسكرين يك سوراخ ميباشد.',
#  'در هر دور كوره در يك نقطه ويبره ايجاد ميشود كه در محل دريچه هاي كوچك بازديد زون 4 تراولينگ كاملا احساس ميشود.',
#  'شوت بالا و ورودي به كوره سورخ ميباشد.',
#  'رابر طرف غرب ريزش گندله دارد.',
#  'گيت 920 تنظيم نيست و زماني كه به طرف كچ باكس ميچرخد نيمه باز ميشود.',
#  'بدنه بانچ گريزلي طرف شمال سوراخ شده است ، از كنار پليت هايي ك هقبلا جوش داده شده است.',
#  'بلبرينگ بازوي بالا دابل فلاپ موتوري كولينگ شماره 9و11و12 خراب است',
#  'ورق سند سيل بيروني كولينگ در محل ستون 14 كولينگ كنده شد و گير ميكند.',
#  'وي بلت ها شل ميباشد.',
#  'كوپل موتور كمكي صداي غير عادي دارد.',
#  'اند كلوزينگ رابر نوار نياز به تنظيم دارد.',
#  'لطفا براي تعويض مش اقدام شود.\nبا تشكر',
#  'ريزش گندله دارد.',
#  'پارچه سوراخ ميباشد',
#  'پالت هاي كولينگ نياز به تنظيم دارد.\nمخصوصا پالت هاي 1و2و11و12',
#  'در زمان استارت موتور تكان زياد دارد و ضربه ميزند.',
#  'اسكرو لبه دارد.',
#  'كپ ياتاقان شمالي شافت شماره 26 بيرون آمده است.',
#  'شافت شماره 22 تراولينگ در مسير رفت ضربه ميزند.\nبا سلام به درخواست مكانيك شيفت درحواست كار مجدد صادر شد.',
#  'صداي غيرعادي از گيربكس',
#  'روتاري ولو خروجي بگ فيلتر گير مكانيكي دارد.',
#  'شافت روتاري ولو جام ميباشد.',
#  'از گلداني 520BC3 نشتي روغن داريم.',
#  'لوله خروجي CF2 به طرف 940SP6 سوراخ شده است',
#  'شافت شماره 12 تراولينگ جام ميباشد.',
#  'اهرم اتصال فلاپ هاي دمپر افتاده است.',
#  'درگيري چرخ دنده با پينيون جنوبي كولينگ نياز به تنظيم دارد ، روي قسمت پايين چرخ دنده خط افتاده است.',
#  'گيربكس اصلي شمالي كولينگ ويبره دارد.',
#  'روي رول شماره 4 كوره مربوط به K7,8 كوره خط افتاده است.',
#  'طرف غرب باكت دو تا از باكت ها كج شده است.',
#  'در طول شيفت موتور اصلي جريان كشيد كه با مكانيك شيفت براي بررسي هماهنگ شد ولي موردي مشاهده نشد.',
#  'بيشتر تيغه هاي گرافيتي ساپورت ويل هاي كولينگ خراب ميباشد.',
#  'طرف شرق گيت سوراخ ميباشد.',
#  'كاور پروانه موتورهاي 7 و 13 و 15 لق ميزند.',
#  'بيرون آوردن يك قطعه فلزي از داخل پاگميل',
#  'همچنان گير دارد و اورلود ميشود.',
#  'شدت ضربات چرخ شماره يك بيروني كولينگ بيشتر شده است.',
#  'شوت باكت قسمت مثلثي بالا طرف شمال سوراخ شده است.',
#  'موتور و گيربكس ويبره دارد.',
#  'مش خورشيدي سوراخ شده است.',
#  'وي بلت ها شل ميباشد.',
#  'وي بلتها نياز به تعويض دارد.',
#  'بدنه طرف شرقي ريزش گندله دارد.',
#  'شوت ورودي به CF طرف شرق سوراخ شده است.',
#  'دو تا از تسمه ها شل شده است.',
#  'جنت ورودي هواي خنك كننده شافت شماره 9 بيرون زده است.',
#  'وي بلت ها شل ميباشد.',
#  'نشتي اسلاري از پكينگ اجيتيتور دارد.',
#  'لوله گريس داخلي پالت 6 كولينگ كنده شده است:',
#  'شافت ضربه گير شارژر خراب ميباشد.',
#  'لوله گريس خارجي پالت 20 و 21 كولينگ كنده شده است.',
#  'پالت 10 ريزش دارد.',
#  'بدنه تجهيز قسمت بالاي نازل ها سوراخ شده است.',
#  'قسمتي از اسپلايس بلند شده است.',
#  'يكي از پين هاي طرف غرب افتاده است.',
#  'از زير دريچه بازديد شوت نشتي گندله دارد.',
#  'طرف شمال شوت مثلثي سوراخ شده است.',
#  'راد 14و15 تراولينگ كج شده است.',
#  'كلمپ گريت پليت هاي رديف ششم از طرف شمال تراولينگ به نظر ميرسد كه باز شده است ، لطفا بررسي شود.',
#  'شوت ريز اسكرين مربوط به ريز دانه سوراخ ميباشد.',
#  'داكت مكش غبار گير در چند نقطه كاملا خورده شده است كه علاوه بر كاهش راندمان غبار گير احتمال كنده شدن و افتادن داكت و وقوع حادثه دارد.',
#  'تفلوت كناره وايد بلت طرف جنوب و در محل ريز از RB سوراخ شده است و نياز به تعويض دارد.',
#  'بدنه داكت بعد از محل اسپري آب سوراخ شده و نشتي زياد آب دارد.',
#  'دو تا از رول ها جام ميباشد.',
#  'اسكراپر لاستيكي داخل شوت خرده شده و عملكرد مناسبي دارد.',
#  'صداي غيرعادي ايمپكت آيدلر خط 620BC3 زير شوت 620BC2',
#  'صداي غير عادي از كاور موتور كه به نظر ميرسد شكسته باشد.',
#  'نشتي اسلاري از پكينگ اجيتيتور طرف موتور دارد.',
#  'اندكلوزينگ رابر مربوط به شوت 920BC3 خراب است.',
#  'فرسودگي سنتر رولر جنوبي سلف آلاين 4',
#  'فرسودگي ريترن 104 و كرينگ 210 جنوب',
#  'دفورمگي و حالت گرفتگي تفلون بدنه جنوبي شوت خروجي',
#  'فرسودگي رول برگشتي 19-كرينگ 220 جنوب و 295 شمال',
#  'خرابي يك عدد چرخ سمت غرب',
#  'فرسودگي سنتر رولر غربي موقعيت 81',
#  'فرسودگي كرينگ 210 جنوب و فرسودگي رابر اسكراپر موقعيت 175',
#  'شل شدن پيچ هاي اسپراكت هاي هد شفت',
#  'فرسودگي رابر اسكيرتبرد جنوب گيت 35',
#  'سايش و سوراخ شدگي ديواره شمالي گيت 40',
#  'فرسودگي ريترن 49-55-77-92-95-104-125-251-رول برگشتي 124',
#  'فرسودگي ريترن 3-22',
#  'فرسودگي ريترن 10-23',
#  'فرسودگي ايمپكت 2 شمال و2 جنوب',
#  'خرابي چرخ 778 جنوب 16 جنوب',
#  'فرسودگي ريترن سلف 10 و ريترن 11 شمال',
#  'فرسودگي كرينگ 108جنوب 14 جنوب 39 شمال \nفرسودگي رابر اسكيرتبرد سمت شمال',
#  'فرسودگي كرينگ 76 غرب',
#  'دبل فلپ سوراخ مي باشد تعويض كامل بلوك',
#  'نياز به تعويض بلت به علت سايش زياد محل برخورد رابر هاي اسكيرتبرد و سايش زود هنگام سوپر اسكرو و فرسودگي و پارگي برزنت داخل بلت به صورت ترك هاي عرضي بيشمار و عميق',
#  'دفورمگي اندكاور ياتاقان شمالي درام ابتداي خط',
#  'فرسودگي رابر وي كلينر ابتداي خط و فرسودگي رولر هاي زير وي كلينر',
#  'فرسودگي رابر اسكيرتبرد سمت غرب',
#  'فرسودگي ريترن 22-251 و كرينگ 218 وسط',
#  'سايش بيش از حد چرخ هاي كالسكه كانترويت كه باعث انحراف شديد شده و نياز به ساخت چرخ جديد مي باشد',
#  'خرابي كاسه نمد شفت ورودي گيربكس كه نياز به تعويض دارد',
#  'فرسودگي ايمپكت 7 شمال',
#  'فرسودگي سنتر رولر شمالي سلف اول خط و رول برگشتي 26 كرينگ وسطي 41 و70',
#  'فرسودگي ريترن 203-385-395-443-446و ريترن سلف 98-320-407 و كرينگ وسطي 129و271و71 جنوب كرينگ 187جنوب و57 شمال - ريترن 332-235-338',
#  'فرسودگي ريترن سلف اول خط موقعيت 4 و كرينگ 20 و 39 وسط',
#  'فرسودي سنتر رولر شمالي سلف 179',
#  'فرسودگي ريترن 113',
#  'خرابي چرخ 90 جنوب -54 جنوب و شكستگي لبه كاسه چرخ 69و71',
#  'فرسودگي ريترن 13 و 70 رول برگشتي 71',
#  'فرسودگي ريترن 85-406',
#  'نياز به ترميم روي كپي جوينت اسپلايس با چسب(TIPTOP)',
#  'فرسودگي رول برگشتي 10- كرينگ 309و316 جنوب سنتر موقعيت 100 جنوب',
#  'فرسودگي رابر اسكيرتبرد سمت جنوب',
#  'فرسودگي يك عدد چرخ سمت شرق',
#  'فرسودگي كرينگ 112 شمال',
#  'فرسودگي كرينگ 5 جنوب روي تريپر',
#  'نياز به ترميم سوپر اسكرو',
#  'نياز به ترميم سوپر اسكرو',
#  'فرسودگي چرخ 86-90جنوب و79 شمال با شكستگي شفت آن',
#  'فرسودگي ريترن برگشتي 123-ريترن 330 سنتر 43 جنوب',
#  'فرسودگي كرينگ 325شمال -ايمپكت 15و16 وسط و ريترن 217-355-85-95-165',
#  'فرسودگي كرينگ 132 وسط',
#  'فرسودگي پارگي رابر دفلكتور شوت خروجي',
#  'فرسودگي رابر اسكيرتبرد جنوبي گيت 35',
#  'خرابي يك عدد چرخ سمت شرق',
#  'فرسودگي ريترن 4-84-121-400-403-219و كرينگ179وسط-176و256 شمال278و193 جنوب',
#  'نشتي روغن از كاسه نمد هالوشفت سمت شفت خروجي',
#  'فرسودگي كرينگ 7 جنوب -7وسط- 54 جنوب',
#  'فرسودگي سنتر رولر شمالي سلف 65',
#  'فرسودگي ريترن 487 - سوراخ شدگي ديواره جنوبي گيت 11',
#  'فرسودگي ريترن 149',
#  'خرابي چرخ 84-83-90-74',
#  'سايش و سوراخ شدگي ديواره شمالي گيت40',
#  'فرسودگي كرينگ 12 غرب',
#  'فرسودگي ريترن 20',
#  'فرسودگي كرينگ 50 وسط',
#  'فرسودگي ريترن 10 و كرينگ 10 شرق',
#  'نياز به ترميم سوپر اسكرو با خميره',
#  'خرابي جاي پيچ هاي اسپراكتهاي شرقي هد شفت كه نياز به تعويض دارند',
#  'نياز به نصب هاردوكس واستون باكس بدنه جنوبي شوت خروجي',
#  'فرسودگي كرينگ 31 وسط',
#  'فرسودگي كرينگ 10وسط',
#  'نياز به ترميم سوپر اسكرو (با خميره )',
#  'فرسودگي ريترن 96-182',
#  'فرسودگي كرينگ 1 جنوب',
#  'فرسودگي رول برگشتي 25-كرينگ 99 جنوب\nفرسودگي رابر اسكيرتبرد سمت جنوب',
#  'پاشش روغن از كاسه نمد پولي چسبيده به هيدرو كوپلينگ',
#  'لهيدگي و سايش اسپراكت هد شفت',
#  'فرسودگي كرينگ 40 وسط - سنتر رولر شمالي سلف 97',
#  'نياز به ترميم محل اسپلايس',
#  'فرسودگي ريرتن 96-كرينگ 229وسط -64 جنوب',
#  'فرسودگي رابر اسكيرتبرد سمت جنوب موقعيت 24 الي 32\nفرسودگي ريترن 98',
#  'خرابي چرخ 84 جنوب -77 جنوب',
#  'در يك نقطه روي بلت پارگي زياد دارد كه فعلا به صورت موقت ترميم شده و نياز به نصب سوپر اسكرو در موقعيت دارد',
#  'فرسودگي ايمپكت 18 غرب',
#  'فرسودگي رابر سمت شرق و سمت غرب\nفرسودگي كرينگ 17 غرب 56 شرق',
#  'فرسودگي كرينگ 1 شمال',
#  'فرسودگي كرينگ 21 شرق و 21 وسط',
#  'فرسودگي كرينگ 18 وسط',
#  'سايش اسپراكت شرقي تيل شفت',
#  'فرسودگي ريترن 43-22و رول برگشتي 47-ايمپكت 4 شرق',
#  'شوت خروجي بدنه سمت غرب سايش و سوراخ شدگي دارد',
#  'شوت خروجي سمت شرق سايش و سوراخ شدگي دارد',
#  'ضربه و صداي غير عادي ياتاقان سمت گيربكس',
#  'فرسودگي ريترن 17- 135',
#  'لقي سلف آلاين 54(خرابي بيرينگها)',
#  'نياز به ترميم سوپر اسكرو (باخميره)',
#  'فرسودگي كرينگ 261وسط 196 شرق و ريترن 126و179',
#  'فرسودگي ريترن 6شمال 18 جنوب',
#  'فرسودگي ريترن قبل از واش باكس',
#  'فرسودگي و سايش تفلون بدنه غربي شوت خروجي',
#  'فرسودگي رابر دفلكتور شوت خروجي',
#  'عدم موجودي واشر خورشيدي جهت آچاركشي هاي روزانه كه تعداد زيادي از مهره ها مثل هم مي باشند و واشر ندارن',
#  'نشتي روغن از سيل ورودي به گيربكس',
#  'فرسودگي ريترن آخري سر بوم وريترن 4و5',
#  'فرسودگي ريترن 42-كرينگ54 شمال',
#  'فرسودگي ريترن هاي 43-137-221',
#  'فرسودگي ريترن هاي 10-32و كرينگ 60شمال',
#  'فرسودگي ريترن 25',
#  'فرسودگي كرينگ 35 جنوب',
#  'گايد پليت هاي باكس كانترويت نياز به تعمير دارد \nنياز به تعويض تفلون هاي روي باكس كانترويت',
#  'فرسودگي كرينگ 165 جنوب\nترك خوردگي كپي جوينت يكي از اسپلايس ها نياز به ترميم دارد',
#  'فرسودگي رول برگشتي 48',
#  'فرسودگي ريترن هاي 87-96-و كرينگ 185وسط و 259 شمال و259جنوب',
#  'فرسودگي كرينگ 90 جنوب',
#  'سايش تيغه اسكراپر طرح جديد شوت خروجي',
#  'نياز به ترميم سوپر اسكرو با خميره',
#  'فرسودگي كرينگ 206شمال-207شمال-28وسط و ريترن313-رول برگشتي 61-كرينگ8 شمال اسكيرتبرد متحرك',
#  'نياز به ترميم روي سوپر اسكرو و بلت با چسب (tiptop)',
#  'فرسودگي ريترن اول خط',
#  'فرسودگي ايمپكت هاي 27-26-24وسط و ريترن 35',
#  'فرسودگي كرينگ 36 وسط',
#  'فرسودگي كرينگ 188 شمال -118 جنوب',
#  'فرسودگي كرينگ 55 شمال  60 شمال و ريترن 21 شمال',
#  'لبه شمالي بلت در يك نقطه نياز به ترميم دارد با خميره',
#  'سايش درام غربي بالاي كانترويت كه روكش آن به سطح فلزي رسيده',
#  'فرسودگي ريترن 3',
#  'سيل ياتاقان جنوب گيت خراب',
#  'سايش تفلون بدنه شرقي شوت خروجي',
#  'فرسودگي ريترن 128-فرسودگي رابر دفلكتور اسكيرتبرد سمت غرب موقعيت 76\nلقي سلف آلاين 155 خرابي بيرينگ هاي آن',
#  'فرسودگي ايمپكت 28 وسط',
#  'فرسودگي رول برگشتي 392',
#  'نياز به تعويض هر 2 سوپر اسكرو روي نوار',
#  'فرسودگي بلت نياز به تعويض كه از قبل درخواست دارد',
#  'فرسودگي ريترن 17 و كرينگ 204 وسط',
#  'نياز به كرينگ كردن لبه سوپر اسكرو كه زخمي شده (انجا شد )',
#  'سوختگي روي يكي از سوپر اسكرو ها',
#  'فرسودگي هاردوكس هاي بدنه شوت ورودي اول از 3 طرف',
#  'ضربه ياتاقان غربي درام اول خط',
#  'با توجه به دفورمگي و خرابي قطعات دبل فلپ هاي موتوري كولينگ كليه ي دبل فلپ ها نياز به تعويض دارد',
#  'نياز به ساخت اسكراپر آب گير بلت در هنگام بارندگي با متريال نبشي 5و تسمه 5 مي باشد',
#  'فرسودگي كرينگ 138شمال-1وسط-118 شمال و ريترن 192-سنتررولر شمالي سلف 351',
#  'سايش و سوراخ شدگي ديواره جنوبي و شمالي گيت 37و ديواره شمال گيت 39',
#  'فرسودگي كرينگ 434وسط',
#  'دماي غير عادي از ياتاقان درام اول خط سمت شمال',
#  'خرابي يك عدد چرخ سمت غرب',
#  'فرسودگي ايمپكت 5وسط 166شمال و كرينگ 251 وسط  ريترن 7-16-220-253',
#  'فرسودگي ريترن سلف آلاين اول خط',
#  'فرسودگي كرينگ 7 وسط',
#  'نياز به ساخت مانع جهت جلوگيري از سقوط كانترويت در هنگام پارگي بلت و سوپر اسكرو با ناوداني 10',
#  'نياز به ساخت مانع جهت جلوگيري از سقوط كانترويت در هنگام پارگي بلت و سوپر اسكرو با ناوداني 10',
#  'نياز به ساخت مانع جهت جلوگيري از سقوط كانترويت در هنگام پارگي بلت و سوپر اسكرو با ناوداني 10',
#  'فرسودگي كامل بوش لينكها كه سايش زياد و شكستگي در آنها مشاهده مي شود',
#  'فرسودگي رابر اسكيرتبرد جنوب',
#  'فرسودگي كرينگ 60وسط',
#  'فرسودگي ريترن 100',
#  'فرسودگي كرينگ وسطي سلف آلاين 80و كرينگ 36و80وسط ريترن سلف 250-155-149و ايمپكت 167و6شمال و6 جنوب \nفرسودگي سنتر رولر سلف 250سمت شمال',
#  'فرسودگي ريترن 71-كرينگ15 شرق',
#  'فرسودگي ايمپكت 25و2و17شرق و22 غرب',
#  'فرسودگي كرينگ 54و40شمال\nسايش درام شرقي بالاي كانترويت',
#  'دبل فلپ به علت ساييدگي زيادسوراخ شده است',
#  'سايش درام ابتداي خط',
#  'پيچ ته شفت مخالف گير بكس شكسته (انجام شد)',
#  'فرسودگي ريترن سلف 10',
#  'فرسودگي هاردوكس هاي شوت خروجي به 820BC6',
#  'فرسودگي ريترن روي واش باكس',
#  'سيل ياتاقان سمت گيربكس خراب\nفرسودگي ايمپكت 23وسط 26 وسط 44وسط',
#  'نياز به ترميم سوپر اسكرو',
#  'فرسودگي ريترن 47 شمال',
#  'فرسودگي ريترن سلف 7',
#  'نياز به ترميم هر 2 سوپر اسكرو  با خميره',
#  'ريترن سر بوم فرسوده',
#  'شل شدن پيچ هاي اسپراكت هد شفت',
#  'فرسودگي ايمپكت 56غرب و ريترن 104-131-259',
#  'فرسودگي ديواره گيت 7 كه از 3طرف شمال جنوب و غرب سوراخ شدگي دارد\nسوراخ شدگي گيت 5و6از سمت جنوب',
#  'فرسودگي ريترن سلف اول خط -ريترن 61-كرينگ 76وسط',
#  'فرسودگي كرينگ18شمال-76وسط-200جنوب و ريترن155و ريترن سلف362',
#  'فرسودگي كرينگ 18غرب 29 وسط و ايمپكت 24شرق',
#  'فرسودگي ايمپكت 4شمال-كرينگ17وسط-217شمال-48وسط و ريترن 40-172-92',
#  'ضربه ياتاقان مخالف گيربكس',
#  'فرسودگي و پارگي تفلون بدنه شمالي شوت خروجي',
#  'فرسودگي ريترن 10',
#  'پارگي سوپر اسكرو و سقوط كانترويت (انجام شده)',
#  'سوپر اسكرو نياز به ترميم با خميده',
#  'عدم موجودي چرخ براي تعويض چرخ هاي خراب',
#  'حركت درام هد به سمت گيربكس كه فعلا اصلاح شده كه در صورت حركت دوباره نياز به تعيض درام و كنترل هالوشفت گيربكس مي باشد',
#  'فرسودگي ريترن سلف 98',
#  'فرسودگي رول تكي زير نوار برگشتي',
#  'فرسودگي ايمپكت 6غرب\nفرسودگي رابر اسكيرتبرد سمت غرب',
#  'سايش هاردوكس هاي شوت خروجي نياز به تعميير دارد',
#  'بند پولي پايين تجهيز ياتاقان جنوبي بيرينگ آن ضربه و صداي غير عادي دارد',
#  'ساپورت ريترن 51 از سمت شمال شكسته\nفرسودگي ريترن 337و31و كرينگ 470جنوب 603وسط',
#  'ديواره سمت شرق يكي از پن ها خيلي دفورمه شده و باعث ريزش مواد مي شود \nخرابي 2عدد چرخ سمت شرق و1عدد سمت غرب',
#  'فرسودگي كرينگ 13شمال و ريترن 403و406',
#  'فرسودگي كرينگ 26وسط و ريترن 43',
#  'لقي سلف 82كه نياز به تعمير دارد \nفرسودگي كرينگ 186و316جنوب 209شمال',
#  'پارگي 40سانتي در طول بلت',
#  'فرسودگي رابر اسكيرتبرد سمت جنوب موقعيت 45 تا52',
#  'فرسودگي ريترن 98-107',
#  'فرسودگي سنتر رولر 119 سمت جنوب',
#  'نشتي روغن از كاسه نمد هالو شفت زير شرينگ ديسك',
#  'فرسودگي هاردوكس هاي بدنه داخل اسكيرتبرد كه نياز به هاردوكس  فابريكي سوراخ كاري شده مي باشد هر دو سمت',
#  'نشتي روغن از كاسه نمد هالو شفت (زير شيرينگ ديسك)',
#  'فرسودگي كرينگ 8 جنوب',
#  'فرسودگي رابر اسكيرتبرد سمت غرب اول خط و سمت غرب \nاسكيرتبرد موقعيت 60',
#  'پارگي رابر وي كلينر',
#  'سايش روكش درام جنوبي بالاي كانترويت',
#  'پوسيدگي و خورده شدن باكس ls شوت خروجي روي اسكيرتبرد 120bc5',
#  'فرسودگي 2 عدد از رولر هاي جام شدن',
#  'سايش هاردوكس هاي شوت خروجي',
#  'فرسودگي كرينگ 62 جنوب',
#  'پارگي روي كپي جوينت نياز به ترميم دارد',
#  'فلپ هاي داخلي سوراخ و نياز به تعويض بلوك كابل دارد',
#  'ترك پشت اسپلايس كه نياز به ترميم دارد',
#  'رابر اسكيرتبرد سمت شرق سايش زياد دارد نياز به تعويض دارد\nپارگي لبه غربي سوپر اسكرو نياز به تعويض دارد',
#  'فرسودگي ريترن 21و47 جنوب',
#  'فرسودگي كرينگ وسطي موقعيت 30و ريترن 39 سمت جنوب',
#  'حركت دارم تيل به سمت شرق كه نياز به تعمير دارد',
#  'نياز به اضافه كردن 1 متر اسكيرتبرد در انتهاي اسكيرتبرد فعلي',
#  'سايش هاردوكس هاي شوت خروجي',
#  'خرابي فلنج بيرينگ شرقي درام تيل نياز به تعويض دارد',
#  'سايش روكش درام شرقي بالاي كانترويت كه به سطح فلزي رسيده',
#  'پارگي محل برخورد يك تسمه فلزي كه نياز به ترميم دارد',
#  'فرسودگي رول برگشتي 104-سنتر رولر جنوبي سلف 171و سنتر شمالي سلف 250-ريترن 189-193-216-231-240',
#  'خرابي و سايش اسليو ياتاقان غربي هد شفت',
#  'خرابي يك عدد چرخ سمت غرب',
#  'پارگي بلت نياز به تعويض دارد',
#  'پارگي 3 تا از پن هاكه نياز به تعمير دارد از زير ديواره شرقي',
#  'فرسودگي ريترن سلف اول خط',
#  'فرسودگي سيل جنوبي درام اول خط',
#  'فرسودگي رابر اسكيرتبرد سمت جنوب (انجام شده)',
#  'فرسودگي كرينگ 76-168وسطو326شنال (انجام شد)',
#  'فرسودگي كرينگ 1سمت شرق و 1 غرب',
#  'فرسودگي كرينگ 16 شرق',
#  'سايش درام غرب بالاي كانترويت',
#  'فرسودگي رابر هاي پارويي روي بلت',
#  'برخورد سيني ها بابلت',
#  'سايش  بوش لينكها',
#  'فرسودگي ريترن 10',
#  'جهت انجام تعميرات اضطراري نياز به مونتاژ كردن هد شفت و تيل شفت مي باشد',
#  'جهت انجام تعميرات اضطراري نياز به مونتاژ كردن هد شفت و تيل شفت مي باشد',
#  'سايش هاردوكس هاي شوت خروجي',
#  'ضربه ياتاقان هاي درام تيل',
#  'فرسودگي ايمپكت 3 شمال- 4 وسط -و ريترن 37 شمال -37 جنوب \nفرسودگي سيل ياتاقان مخالف گيربكس',
#  'دفورمگي سيل ياتاقان جنوب درام ابتداي خط',
#  'فرسودگي ريترن 6',
#  'فرسودگي كرينگ 27-275-346 جنوب و ريترن 246-324-330-348-391-385-403',
#  'فرسودگي ايمپكت وسطي سلف آلاين 407',
#  'فرسودگي كرينگ وسطي سلف آلاين 115',
#  'سايش اسپراكت هد شفت (حاد)',
#  ...]

# %%
words =word_tokenize(sample_persian)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# C:\Users\H03C7~1.ALA\AppData\Local\Temp/ipykernel_15968/4127785055.py in <module>
# ----> 1 words =word_tokenize(sample_persian)
#
# NameError: name 'word_tokenize' is not defined

# %%
type(words)

# %%
words

# %%
import re
#cleaning text
normalizer = Normalizer()
corpus = []

for word in words:
    if re.search('[\u0600-\u06FF]',word):
        corpus.append(normalizer.normalize(word))

# %%
corpus

# %%
from nltk.corpus import stopwords
from nltk.tokenize import wordpunct_tokenize

stop_words = set(stopwords.words('arabic'))
# Out:
# ---------------------------------------------------------------------------
# LookupError                               Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\nltk\corpus\util.py in __load(self)
#      83                 try:
# ---> 84                     root = nltk.data.find(f"{self.subdir}/{zip_name}")
#      85                 except LookupError:
#
# ~\Anaconda3\lib\site-packages\nltk\data.py in find(resource_name, paths)
#     582     resource_not_found = f"\n{sep}\n{msg}\n{sep}\n"
# --> 583     raise LookupError(resource_not_found)
#     584
#
# LookupError:
# **********************************************************************
#   Resource stopwords not found.
#   Please use the NLTK Downloader to obtain the resource:
#
#   >>> import nltk
#   >>> nltk.download('stopwords')
#
#   For more information see: https://www.nltk.org/data.html
#
#   Attempted to load corpora/stopwords.zip/stopwords/
#
#   Searched in:
#     - 'C:\\Users\\h.alavi/nltk_data'
#     - 'C:\\Users\\h.alavi\\Anaconda3\\nltk_data'
#     - 'C:\\Users\\h.alavi\\Anaconda3\\share\\nltk_data'
#     - 'C:\\Users\\h.alavi\\Anaconda3\\lib\\nltk_data'
#     - 'C:\\Users\\h.alavi\\AppData\\Roaming\\nltk_data'
#     - 'C:\\nltk_data'
#     - 'D:\\nltk_data'
#     - 'E:\\nltk_data'
# **********************************************************************
#
#
# During handling of the above exception, another exception occurred:
#
# LookupError                               Traceback (most recent call last)
# C:\Users\H03C7~1.ALA\AppData\Local\Temp/ipykernel_15968/3869705942.py in <module>
#       2 from nltk.tokenize import wordpunct_tokenize
#       3
# ----> 4 stop_words = set(stopwords.words('arabic'))
#
# ~\Anaconda3\lib\site-packages\nltk\corpus\util.py in __getattr__(self, attr)
#     119             raise AttributeError("LazyCorpusLoader object has no attribute '__bases__'")
#     120
# --> 121         self.__load()
#     122         # This looks circular, but its not, since __load() changes our
#     123         # __class__ to something new:
#
# ~\Anaconda3\lib\site-packages\nltk\corpus\util.py in __load(self)
#      84                     root = nltk.data.find(f"{self.subdir}/{zip_name}")
#      85                 except LookupError:
# ---> 86                     raise e
#      87
#      88         # Load the corpus.
#
# ~\Anaconda3\lib\site-packages\nltk\corpus\util.py in __load(self)
#      79         else:
#      80             try:
# ---> 81                 root = nltk.data.find(f"{self.subdir}/{self.__name}")
#      82             except LookupError as e:
#      83                 try:
#
# ~\Anaconda3\lib\site-packages\nltk\data.py in find(resource_name, paths)
#     581     sep = "*" * 70
#     582     resource_not_found = f"\n{sep}\n{msg}\n{sep}\n"
# --> 583     raise LookupError(resource_not_found)
#     584
#     585
#
# LookupError:
# **********************************************************************
#   Resource stopwords not found.
#   Please use the NLTK Downloader to obtain the resource:
#
#   >>> import nltk
#   >>> nltk.download('stopwords')
#
#   For more information see: https://www.nltk.org/data.html
#
#   Attempted to load corpora/stopwords
#
#   Searched in:
#     - 'C:\\Users\\h.alavi/nltk_data'
#     - 'C:\\Users\\h.alavi\\Anaconda3\\nltk_data'
#     - 'C:\\Users\\h.alavi\\Anaconda3\\share\\nltk_data'
#     - 'C:\\Users\\h.alavi\\Anaconda3\\lib\\nltk_data'
#     - 'C:\\Users\\h.alavi\\AppData\\Roaming\\nltk_data'
#     - 'C:\\nltk_data'
#     - 'D:\\nltk_data'
#     - 'E:\\nltk_data'
# **********************************************************************

# %%
#url='https://raw.githubusercontent.com/sobhe/hazm/master/hazm/data/stopwords.dat'

# %%
df=pd.read_csv('stopwords.dat',header=None, encoding='utf-8',)

# %%
df
# Out:
#            0
# 0          و
# 1         در
# 2         به
# 3         از
# 4         که
# ..       ...
# 384  می‌یابد
# 385      لذا
# 386     زاده
# 387     گردد
# 388    اینجا
#
# [389 rows x 1 columns]

# %%
st_word=df.iloc[:,0].tolist()

# %%
st_word

# %%
stop_words.update(st_word)

# %%
stop_words

# %%
filtered_words=[]
for word in corpus:
    if word not in stop_words:
        filtered_words.append(word)

# %%
filtered_words

# %%
stemmer = Stemmer()
lemmatizer = Lemmatizer()
normalizer = Normalizer()

# %%
for token in words:
    token = normalizer.normalize(token)
    print("stem" + "-> "+ stemmer.stem(token))
    print("lemma" + "-> "+lemmatizer.lemmatize(token))
    print("\n")

# %%
import nltk
from nltk.corpus import stopwords

# %%
print(stopwords.fileids())

# %%
corpus = []
for c in sample_persian:
    if (ord(c) >600) or (ord(c) == 32)  :
        corpus.append(c)

# %%
sample_persian

# %%
corpus

# %%
# -*- coding: utf-8 -*-
a='ب به با باب'
b= arabic_reshaper.reshape(a)
print(b.encode())


#print(unicode_string)
fig,ax = plt.subplots()
ax.set_title(b[::-1],fontsize=25)
plt.show()
# Out:
# b'\xef\xba\x8f \xef\xba\x91\xef\xbb\xaa \xef\xba\x91\xef\xba\x8e \xef\xba\x91\xef\xba\x8e\xef\xba\x8f'
