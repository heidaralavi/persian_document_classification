# %%
#!pip install nltk

# %%
#!pip install hazm

# %%
#import nltk
#nltk.download()

# %%
from __future__ import unicode_literals
from hazm import *

# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_excel('data.xlsx',dtype='str')

# %%
df.head()
# Out:
#   شماره درخواست              کد ماشین تاریخ خرابی        وضعیت نام ماشین  \
# 0      93078329                          14000608  درحال بررسي       NaN
# 1      93078330                          14000608  درحال بررسي       NaN
# 2      93078331                          14000608  درحال بررسي       NaN
# 3      93078474                          14000612  درحال بررسي       NaN
# 4      93078633                          14000616  درحال بررسي       NaN
#
#   نوع درخواست         ق.ص. درخواست علت خرابی مدت انجام كار  \
# 0        عادي  هيدروليك و روانكاري       NaN             0
# 1        عادي  هيدروليك و روانكاري       NaN             0
# 2        عادي  هيدروليك و روانكاري       NaN             0
# 3        عادي  هيدروليك و روانكاري       NaN             0
# 4        عادي  هيدروليك و روانكاري       NaN             0
#
#                                             شرح مشكل تاريخ شروع  \
# 0  سيستم گريس بالميل آلارم دارد و اسپري انجام نمي...          0
# 1                    سيستم گريس ديسك يك آلارم دارد .          0
# 2     نشتي روغن  از پمپ مسير شماره يك هيدروليك 610wb          0
# 3                   سيستم گريسكاري بالميل آلارم دارد          0
# 4  دماي بيرينگ سمت موتور 710fn4 بالاست و سطح روغن...          0
#
#   شرح_كد دوره توقف (واقعي ) 2 شرح_محل استقرار
# 0                      نامشخص     930BM1.xxxx
# 1                      نامشخص     610PE1.XXXX
# 2                      نامشخص          610BW8
# 3                      نامشخص     930BM1.xxxx
# 4                      نامشخص     710FN4.xxxx

# %%
import arabic_reshaper
from bidi.algorithm import get_display

# %%
reshaped_text = arabic_reshaper.reshape(df['وضعیت'].apply(str)) # correct its shape
bidi_text = get_display(reshaped_text) # correct its direction
bidi_text
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# C:\Users\H03C7~1.ALA\AppData\Local\Temp/ipykernel_14148/2653631697.py in <module>
# ----> 1 reshaped_text = arabic_reshaper.reshape(df['وضعیت'].apply(str)) # correct its shape
#       2 bidi_text = get_display(reshaped_text) # correct its direction
#       3 bidi_text
#
# ~\Anaconda3\lib\site-packages\arabic_reshaper\arabic_reshaper.py in reshape(self, text)
#      99
#     100     def reshape(self, text):
# --> 101         if not text:
#     102             return ''
#     103
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in __nonzero__(self)
#    1535     @final
#    1536     def __nonzero__(self):
# -> 1537         raise ValueError(
#    1538             f"The truth value of a {type(self).__name__} is ambiguous. "
#    1539             "Use a.empty, a.bool(), a.item(), a.any() or a.all()."
#
# ValueError: The truth value of a Series is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().

# %%
df['وضعیت'].str

# %%
df['وضعیت'].value_counts().plot(kind='pie')
# Out:
# <AxesSubplot:ylabel='وضعیت'>

# %%
sample_persian= data['شرح'][0]

# %%
type(sample_persian)
# Out:
# str

# %%
import re
#cleaning text
sentences = sample_persian
corpus = []

for sent in sentences:
    review = re.sub("[^a-zA-Z]", " ", sent)
    review = re.sub("\b[a-zA-Z]\b", " ", review)
    review = review.lower()
    review = review.split()
    review = " ".join(review)
    corpus.append(review)

# %%
corpus
# Out:
# ['',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  'm',
#  'l',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  'm',
#  'a',
#  'c',
#  'h',
#  'i',
#  'n',
#  'e',
#  '',
#  'l',
#  'e',
#  'a',
#  'r',
#  'n',
#  'i',
#  'n',
#  'g',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '']

# %%
import re
#cleaning text
sentences = sample_persian
corpus = []

for sent in sentences:
    if re.search('[\u0600-\u06FF]',sent):
        corpus.append(sent)

# %%
corpus
# Out:
# ['ی',
#  'ا',
#  'د',
#  'گ',
#  'ی',
#  'ر',
#  'ی',
#  'م',
#  'ا',
#  'ش',
#  'ی',
#  'ن',
#  'ی',
#  'ب',
#  'ه',
#  'ا',
#  'ن',
#  'گ',
#  'ل',
#  'ی',
#  'س',
#  'ی',
#  'م',
#  'ط',
#  'ا',
#  'ل',
#  'ع',
#  'ه',
#  'ی',
#  'ع',
#  'ل',
#  'م',
#  'ی',
#  'ا',
#  'ل',
#  'گ',
#  'و',
#  'ر',
#  'ی',
#  'ت',
#  'م',
#  'ه',
#  'ا',
#  'و',
#  'م',
#  'د',
#  'ل',
#  'ه',
#  'ا',
#  'ی',
#  'آ',
#  'م',
#  'ا',
#  'ر',
#  'ی',
#  'م',
#  'و',
#  'ر',
#  'د',
#  'ا',
#  'س',
#  'ت',
#  'ف',
#  'ا',
#  'د',
#  'ه',
#  'ی',
#  'س',
#  'ی',
#  'س',
#  'ت',
#  'م',
#  'ه',
#  'ا',
#  'ی',
#  'ک',
#  'ا',
#  'م',
#  'پ',
#  'ی',
#  'و',
#  'ت',
#  'ر',
#  'ی',
#  'ا',
#  'س',
#  'ت',
#  'ک',
#  'ه',
#  'ب',
#  'ه',
#  'ج',
#  'ا',
#  'ی',
#  'ا',
#  'س',
#  'ت',
#  'ف',
#  'ا',
#  'د',
#  'ه',
#  'ا',
#  'ز',
#  'د',
#  'س',
#  'ت',
#  'و',
#  'ر',
#  'ا',
#  'ل',
#  'ع',
#  'م',
#  'ل',
#  'ه',
#  'ا',
#  'ی',
#  'و',
#  'ا',
#  'ض',
#  'ح',
#  '،',
#  'ا',
#  'ز',
#  'ا',
#  'ل',
#  'گ',
#  'و',
#  'ه',
#  'ا',
#  'و',
#  'ا',
#  'س',
#  'ت',
#  'ن',
#  'ب',
#  'ا',
#  'ط',
#  'ب',
#  'ر',
#  'ا',
#  'ی',
#  'ا',
#  'ن',
#  'ج',
#  'ا',
#  'م',
#  'و',
#  'ظ',
#  'ا',
#  'ی',
#  'ف',
#  'س',
#  'و',
#  'د',
#  'م',
#  'ی',
#  'ب',
#  'ر',
#  'ن',
#  'د',
#  '۱',
#  'ی',
#  'ا',
#  'د',
#  'گ',
#  'ی',
#  'ر',
#  'ی',
#  'م',
#  'ا',
#  'ش',
#  'ی',
#  'ن',
#  'ی',
#  'ع',
#  'ل',
#  'م',
#  'ی',
#  'ا',
#  'س',
#  'ت',
#  'ک',
#  'ه',
#  'ب',
#  'ا',
#  'ع',
#  'ث',
#  'م',
#  'ی',
#  'ش',
#  'و',
#  'د',
#  'ر',
#  'ا',
#  'ی',
#  'ا',
#  'ن',
#  'ه',
#  'ه',
#  'ا',
#  'ب',
#  'د',
#  'و',
#  'ن',
#  'ن',
#  'ی',
#  'ا',
#  'ز',
#  'ب',
#  'ه',
#  'ی',
#  'ک',
#  'ب',
#  'ر',
#  'ن',
#  'ا',
#  'م',
#  'ه',
#  'ص',
#  'ر',
#  'ی',
#  'ح',
#  'د',
#  'ر',
#  'م',
#  'و',
#  'ر',
#  'د',
#  'ی',
#  'ک',
#  'م',
#  'و',
#  'ض',
#  'و',
#  'ع',
#  'خ',
#  'ا',
#  'ص',
#  'ی',
#  'ا',
#  'د',
#  'ب',
#  'گ',
#  'ی',
#  'ر',
#  'ن',
#  'د',
#  'ب',
#  'ه',
#  'ع',
#  'ن',
#  'و',
#  'ا',
#  'ن',
#  'ز',
#  'ی',
#  'ر',
#  'م',
#  'ج',
#  'م',
#  'و',
#  'ع',
#  'ه',
#  'ا',
#  'ی',
#  'ا',
#  'ز',
#  'ه',
#  'و',
#  'ش',
#  'م',
#  'ص',
#  'ن',
#  'و',
#  'ع',
#  'ی',
#  '،',
#  'ا',
#  'ل',
#  'گ',
#  'و',
#  'ر',
#  'ی',
#  'ت',
#  'م',
#  'ه',
#  'ا',
#  'ی',
#  'ی',
#  'ا',
#  'د',
#  'گ',
#  'ی',
#  'ر',
#  'ی',
#  'م',
#  'ا',
#  'ش',
#  'ی',
#  'ن',
#  'ی',
#  'ی',
#  'ک',
#  'م',
#  'د',
#  'ل',
#  'ر',
#  'ی',
#  'ا',
#  'ض',
#  'ی',
#  'ب',
#  'ر',
#  'ا',
#  'س',
#  'ا',
#  'س',
#  'د',
#  'ا',
#  'د',
#  'ه',
#  'ه',
#  'ا',
#  'ی',
#  'ن',
#  'م',
#  'و',
#  'ن',
#  'ه',
#  'ی',
#  'ا',
#  'د',
#  'ا',
#  'د',
#  'ه',
#  'ه',
#  'ا',
#  'ی',
#  'آ',
#  'م',
#  'و',
#  'ز',
#  'ش',
#  'ب',
#  'ه',
#  'م',
#  'ن',
#  'ظ',
#  'و',
#  'ر',
#  'پ',
#  'ی',
#  'ش',
#  'ب',
#  'ی',
#  'ن',
#  'ی',
#  'ی',
#  'ا',
#  'ت',
#  'ص',
#  'م',
#  'ی',
#  'م',
#  'گ',
#  'ی',
#  'ر',
#  'ی',
#  'ب',
#  'د',
#  'و',
#  'ن',
#  'ب',
#  'ر',
#  'ن',
#  'ا',
#  'م',
#  'ه',
#  'ر',
#  'ی',
#  'ز',
#  'ی',
#  'آ',
#  'ش',
#  'ک',
#  'ا',
#  'ر',
#  '،',
#  'ا',
#  'ی',
#  'ج',
#  'ا',
#  'د',
#  'م',
#  'ی',
#  'ک',
#  'ن',
#  'ن',
#  'د']

# %%
words =word_tokenize(sample_persian)

# %%
type(words)
# Out:
# list

# %%
words
# Out:
# ['یادگیری',
#  'ماشینی',
#  '(',
#  'ML',
#  ')',
#  '\xa0',
#  '(',
#  'به\xa0انگلیسی',
#  ':',
#  '\xa0Machine',
#  'learning',
#  ')',
#  'مطالعه\u200cی',
#  'علمی',
#  'الگوریتم\u200cها',
#  'و',
#  'مدل\u200cهای',
#  'آماری',
#  'مورد',
#  'استفاده\u200cی',
#  'سیستم\u200cهای',
#  'کامپیوتری',
#  'است',
#  'که',
#  'به\u200cجای',
#  'استفاده',
#  'از',
#  'دستورالعمل\u200cهای',
#  'واضح',
#  '،',
#  'از',
#  'الگوها',
#  'و',
#  'استنباط',
#  'برای',
#  'انجام',
#  'وظایف',
#  'سود',
#  'می\u200cبرند',
#  '.',
#  '[',
#  '۱',
#  ']',
#  '\xa0یادگیری',
#  'ماشینی',
#  'علمی',
#  'است',
#  'که',
#  'باعث',
#  'می\u200cشود',
#  'رایانه\u200cها',
#  'بدون',
#  'نیاز',
#  'به',
#  'یک',
#  'برنامه',
#  'صریح',
#  'در',
#  'مورد',
#  'یک',
#  'موضوع',
#  'خاص',
#  'یاد',
#  'بگیرند',
#  '.',
#  'به',
#  'عنوان',
#  'زیر',
#  'مجموعه\u200cای',
#  'از',
#  'هوش',
#  'مصنوعی',
#  '،',
#  'الگوریتم\u200cهای',
#  'یادگیری',
#  'ماشینی',
#  'یک',
#  'مدل',
#  'ریاضی',
#  'بر',
#  'اساس',
#  'داده\u200cهای',
#  'نمونه',
#  'یا',
#  '"',
#  'داده\u200cهای',
#  'آموزش',
#  '"',
#  'به',
#  'منظور',
#  'پیش\u200cبینی',
#  'یا',
#  'تصمیم\u200cگیری',
#  'بدون',
#  'برنامه\u200cریزی',
#  'آشکار',
#  '،',
#  'ایجاد',
#  'می\u200cکنند',
#  '.']

# %%
import re
#cleaning text
normalizer = Normalizer()
corpus = []

for word in words:
    if re.search('[\u0600-\u06FF]',word):
        corpus.append(normalizer.normalize(word))

# %%
corpus
# Out:
# ['یادگیری',
#  'ماشینی',
#  'به انگلیسی',
#  'مطالعه\u200cی',
#  'علمی',
#  'الگوریتم\u200cها',
#  'و',
#  'مدل\u200cهای',
#  'آماری',
#  'مورد',
#  'استفاده\u200cی',
#  'سیستم\u200cهای',
#  'کامپیوتری',
#  'است',
#  'که',
#  'به\u200cجای',
#  'استفاده',
#  'از',
#  'دستورالعمل\u200cهای',
#  'واضح',
#  '،',
#  'از',
#  'الگوها',
#  'و',
#  'استنباط',
#  'برای',
#  'انجام',
#  'وظایف',
#  'سود',
#  'می\u200cبرند',
#  '۱',
#  ' یادگیری',
#  'ماشینی',
#  'علمی',
#  'است',
#  'که',
#  'باعث',
#  'می\u200cشود',
#  'رایانه\u200cها',
#  'بدون',
#  'نیاز',
#  'به',
#  'یک',
#  'برنامه',
#  'صریح',
#  'در',
#  'مورد',
#  'یک',
#  'موضوع',
#  'خاص',
#  'یاد',
#  'بگیرند',
#  'به',
#  'عنوان',
#  'زیر',
#  'مجموعه\u200cای',
#  'از',
#  'هوش',
#  'مصنوعی',
#  '،',
#  'الگوریتم\u200cهای',
#  'یادگیری',
#  'ماشینی',
#  'یک',
#  'مدل',
#  'ریاضی',
#  'بر',
#  'اساس',
#  'داده\u200cهای',
#  'نمونه',
#  'یا',
#  'داده\u200cهای',
#  'آموزش',
#  'به',
#  'منظور',
#  'پیش\u200cبینی',
#  'یا',
#  'تصمیم\u200cگیری',
#  'بدون',
#  'برنامه\u200cریزی',
#  'آشکار',
#  '،',
#  'ایجاد',
#  'می\u200cکنند']

# %%
from nltk.corpus import stopwords
from nltk.tokenize import wordpunct_tokenize

stop_words = set(stopwords.words('arabic'))

# %%
#url='https://raw.githubusercontent.com/sobhe/hazm/master/hazm/data/stopwords.dat'

# %%
df=pd.read_csv('stopwords.dat',header=None, encoding='utf-8',)

# %%
df
# Out:
#            0
# 0          و
# 1         در
# 2         به
# 3         از
# 4         که
# ..       ...
# 384  می‌یابد
# 385      لذا
# 386     زاده
# 387     گردد
# 388    اینجا
#
# [389 rows x 1 columns]

# %%
st_word=df.iloc[:,0].tolist()

# %%
st_word
# Out:
# ['و',
#  'در',
#  'به',
#  'از',
#  'که',
#  'این',
#  'را',
#  'با',
#  'است',
#  'برای',
#  'آن',
#  'یک',
#  'خود',
#  'تا',
#  'کرد',
#  'بر',
#  'هم',
#  'نیز',
#  'گفت',
#  'می\u200cشود',
#  'وی',
#  'شد',
#  'دارد',
#  'ما',
#  'اما',
#  'یا',
#  'شده',
#  'باید',
#  'هر',
#  'آنها',
#  'بود',
#  'او',
#  'دیگر',
#  'دو',
#  'مورد',
#  'می\u200cکند',
#  'شود',
#  'کند',
#  'وجود',
#  'بین',
#  'پیش',
#  'شده_است',
#  'پس',
#  'نظر',
#  'اگر',
#  'همه',
#  'یکی',
#  'حال',
#  'هستند',
#  'من',
#  'کنند',
#  'نیست',
#  'باشد',
#  'چه',
#  'بی',
#  'می',
#  'بخش',
#  'می\u200cکنند',
#  'همین',
#  'افزود',
#  'هایی',
#  'دارند',
#  'راه',
#  'همچنین',
#  'روی',
#  'داد',
#  'بیشتر',
#  'بسیار',
#  'سه',
#  'داشت',
#  'چند',
#  'سوی',
#  'تنها',
#  'هیچ',
#  'میان',
#  'اینکه',
#  'شدن',
#  'بعد',
#  'جدید',
#  'ولی',
#  'حتی',
#  'کردن',
#  'برخی',
#  'کردند',
#  'می\u200cدهد',
#  'اول',
#  'نه',
#  'کرده_است',
#  'نسبت',
#  'بیش',
#  'شما',
#  'چنین',
#  'طور',
#  'افراد',
#  'تمام',
#  'درباره',
#  'بار',
#  'بسیاری',
#  'می\u200cتواند',
#  'کرده',
#  'چون',
#  'ندارد',
#  'دوم',
#  'بزرگ',
#  'طی',
#  'حدود',
#  'همان',
#  'بدون',
#  'البته',
#  'آنان',
#  'می\u200cگوید',
#  'دیگری',
#  'خواهد_شد',
#  'کنیم',
#  'قابل',
#  'یعنی',
#  'رشد',
#  'می\u200cتوان',
#  'وارد',
#  'کل',
#  'ویژه',
#  'قبل',
#  'براساس',
#  'نیاز',
#  'گذاری',
#  'هنوز',
#  'لازم',
#  'سازی',
#  'بوده_است',
#  'چرا',
#  'می\u200cشوند',
#  'وقتی',
#  'گرفت',
#  'کم',
#  'جای',
#  'حالی',
#  'تغییر',
#  'پیدا',
#  'اکنون',
#  'تحت',
#  'باعث',
#  'مدت',
#  'فقط',
#  'زیادی',
#  'تعداد',
#  'آیا',
#  'بیان',
#  'رو',
#  'شدند',
#  'عدم',
#  'کرده_اند',
#  'بودن',
#  'نوع',
#  'بلکه',
#  'جاری',
#  'دهد',
#  'برابر',
#  'مهم',
#  'بوده',
#  'اخیر',
#  'مربوط',
#  'امر',
#  'زیر',
#  'گیری',
#  'شاید',
#  'خصوص',
#  'آقای',
#  'اثر',
#  'کننده',
#  'بودند',
#  'فکر',
#  'کنار',
#  'اولین',
#  'سوم',
#  'سایر',
#  'کنید',
#  'ضمن',
#  'مانند',
#  'باز',
#  'می\u200cگیرد',
#  'ممکن',
#  'حل',
#  'دارای',
#  'پی',
#  'مثل',
#  'می\u200cرسد',
#  'اجرا',
#  'دور',
#  'منظور',
#  'کسی',
#  'موجب',
#  'طول',
#  'امکان',
#  'آنچه',
#  'تعیین',
#  'گفته',
#  'شوند',
#  'جمع',
#  'خیلی',
#  'علاوه',
#  'گونه',
#  'تاکنون',
#  'رسید',
#  'ساله',
#  'گرفته',
#  'شده_اند',
#  'علت',
#  'چهار',
#  'داشته_باشد',
#  'خواهد_بود',
#  'طرف',
#  'تهیه',
#  'تبدیل',
#  'مناسب',
#  'زیرا',
#  'مشخص',
#  'می\u200cتوانند',
#  'نزدیک',
#  'جریان',
#  'روند',
#  'بنابراین',
#  'می\u200cدهند',
#  'یافت',
#  'نخستین',
#  'بالا',
#  'پنج',
#  'ریزی',
#  'عالی',
#  'چیزی',
#  'نخست',
#  'بیشتری',
#  'ترتیب',
#  'شده_بود',
#  'خاص',
#  'خوبی',
#  'خوب',
#  'شروع',
#  'فرد',
#  'کامل',
#  'غیر',
#  'می\u200cرود',
#  'دهند',
#  'آخرین',
#  'دادن',
#  'جدی',
#  'بهترین',
#  'شامل',
#  'گیرد',
#  'بخشی',
#  'باشند',
#  'تمامی',
#  'بهتر',
#  'داده_است',
#  'حد',
#  'نبود',
#  'کسانی',
#  'می\u200cکرد',
#  'داریم',
#  'علیه',
#  'می\u200cباشد',
#  'دانست',
#  'ناشی',
#  'داشتند',
#  'دهه',
#  'می\u200cشد',
#  'ایشان',
#  'آنجا',
#  'گرفته_است',
#  'دچار',
#  'می\u200cآید',
#  'لحاظ',
#  'آنکه',
#  'داده',
#  'بعضی',
#  'هستیم',
#  'اند',
#  'برداری',
#  'نباید',
#  'می\u200cکنیم',
#  'نشست',
#  'سهم',
#  'همیشه',
#  'آمد',
#  'اش',
#  'وگو',
#  'می\u200cکنم',
#  'حداقل',
#  'طبق',
#  'جا',
#  'خواهد_کرد',
#  'نوعی',
#  'چگونه',
#  'رفت',
#  'هنگام',
#  'فوق',
#  'روش',
#  'ندارند',
#  'سعی',
#  'بندی',
#  'شمار',
#  'کلی',
#  'کافی',
#  'مواجه',
#  'همچنان',
#  'زیاد',
#  'سمت',
#  'کوچک',
#  'داشته_است',
#  'چیز',
#  'پشت',
#  'آورد',
#  'حالا',
#  'روبه',
#  'سال\u200cهای',
#  'دادند',
#  'می\u200cکردند',
#  'عهده',
#  'نیمه',
#  'جایی',
#  'دیگران',
#  'سی',
#  'بروز',
#  'یکدیگر',
#  'آمده_است',
#  'جز',
#  'کنم',
#  'سپس',
#  'کنندگان',
#  'خودش',
#  'همواره',
#  'یافته',
#  'شان',
#  'صرف',
#  'نمی\u200cشود',
#  'رسیدن',
#  'چهارم',
#  'یابد',
#  'متر',
#  'ساز',
#  'داشته',
#  'کرده_بود',
#  'باره',
#  'نحوه',
#  'کردم',
#  'تو',
#  'شخصی',
#  'داشته_باشند',
#  'محسوب',
#  'پخش',
#  'کمی',
#  'متفاوت',
#  'سراسر',
#  'کاملا',
#  'داشتن',
#  'نظیر',
#  'آمده',
#  'گروهی',
#  'فردی',
#  'ع',
#  'همچون',
#  'خطر',
#  'خویش',
#  'کدام',
#  'دسته',
#  'سبب',
#  'عین',
#  'آوری',
#  'متاسفانه',
#  'بیرون',
#  'دار',
#  'ابتدا',
#  'شش',
#  'افرادی',
#  'می\u200cگویند',
#  'سالهای',
#  'درون',
#  'نیستند',
#  'یافته_است',
#  'پر',
#  'خاطرنشان',
#  'گاه',
#  'جمعی',
#  'اغلب',
#  'دوباره',
#  'می\u200cیابد',
#  'لذا',
#  'زاده',
#  'گردد',
#  'اینجا']

# %%
stop_words.update(st_word)

# %%
stop_words
# Out:
# {'دواليك',
#  'عَدَسْ',
#  'هَذِه',
#  'نعم',
#  'خمس',
#  'می\u200cکنم',
#  'إمّا',
#  'أكتوبر',
#  'أجمع',
#  'ذي',
#  'اغلب',
#  'ديسمبر',
#  'إليكن',
#  'که',
#  'رجع',
#  'خامس',
#  'بيد',
#  'ت',
#  'ليسا',
#  'ما أفعله',
#  'إنا',
#  'ذلكن',
#  'وجد',
#  'وارد',
#  'عوض',
#  'سقى',
#  'زیادی',
#  'فکر',
#  'یافته_است',
#  'بهن',
#  'سوی',
#  'هلّا',
#  'وما',
#  'مساء',
#  'بسّ',
#  'قلما',
#  'خاصة',
#  'حالی',
#  'بهتر',
#  'دادن',
#  'آمده_است',
#  'هكذا',
#  'بودند',
#  'تعداد',
#  'ذو',
#  'افرادی',
#  'ستمئة',
#  'ص',
#  'چ',
#  'مهما',
#  'أيا',
#  'می',
#  'واحد',
#  'چیزی',
#  'خلا',
#  'جریان',
#  'محسوب',
#  'فو',
#  'آنچه',
#  'سبحان',
#  'ثلاثمئة',
#  'تفعلان',
#  'شاید',
#  'مشخص',
#  'زود',
#  'تاکنون',
#  'حرى',
#  'ترك',
#  'طاق',
#  'ویژه',
#  'بالا',
#  'اجرا',
#  'رابع',
#  'روند',
#  'حيثما',
#  'الذي',
#  'مادام',
#  'بمن',
#  'خواهد_بود',
#  'تحوّل',
#  'کنندگان',
#  'لي',
#  'ذوا',
#  'سی',
#  'لئن',
#  'کند',
#  'أمد',
#  'نظر',
#  'تسع',
#  'دهه',
#  'أيّ',
#  'آي',
#  'مربوط',
#  'تاسع',
#  'شخصی',
#  'بكم',
#  'إليكما',
#  'می\u200cدهند',
#  'كذلك',
#  'راء',
#  'مدت',
#  'مكانكم',
#  'اربعون',
#  'مه',
#  'سبعين',
#  'ب',
#  'ستين',
#  'ذواتا',
#  'گذاری',
#  'اثنين',
#  'تلكما',
#  'عاشر',
#  'بهما',
#  'آض',
#  'أن',
#  'أل',
#  'ألفى',
#  'ذيت',
#  'صراحة',
#  'دیگری',
#  'أنبأ',
#  'بك',
#  'جلل',
#  'أوه',
#  'جمعة',
#  'ستمائة',
#  'إذما',
#  'بین',
#  'شده_بود',
#  'إنَّ',
#  'جيم',
#  'آخرین',
#  'رُبَّ',
#  'أيها',
#  'يونيو',
#  'ة',
#  'همه',
#  'فإذا',
#  'لكي',
#  'نه',
#  'اللذان',
#  'اثني',
#  'لولا',
#  'تمام',
#  'شوند',
#  'صار',
#  'سمت',
#  'فلا',
#  'كيفما',
#  'وگو',
#  'إياكما',
#  'إذن',
#  'لكنَّ',
#  'ظاء',
#  'أخو',
#  'وإذ',
#  'افزود',
#  'برابر',
#  'إذ',
#  'نَخْ',
#  'أسكن',
#  'این',
#  'جنيه',
#  'غداة',
#  'جای',
#  'حل',
#  'تفعلون',
#  'آنکه',
#  'لذا',
#  'كأنما',
#  'ثاء',
#  'تخذ',
#  'سبعة',
#  'إلّا',
#  'ما برح',
#  'می\u200cیابد',
#  'عالی',
#  'هَذِي',
#  'بخشی',
#  'بس',
#  'خواهد_شد',
#  'حار',
#  'طبق',
#  'ذين',
#  'لستم',
#  'پس',
#  'گفته',
#  'وهو',
#  'هایی',
#  'اینجا',
#  'درباره',
#  'إياهم',
#  'هاتان',
#  'تغییر',
#  'أخٌ',
#  'اگر',
#  'سنتيم',
#  'مارس',
#  'متى',
#  'دیگر',
#  'نخستین',
#  'جانفي',
#  'أخذ',
#  'مرّة',
#  'به',
#  'طاء',
#  'آن',
#  'بل',
#  'أقل',
#  'قاف',
#  'هَذانِ',
#  'تلقاء',
#  'کنید',
#  'گیرد',
#  'نسبت',
#  'مايو',
#  'ثمّة',
#  'ليست',
#  'حاي',
#  'استحال',
#  'كلّما',
#  'كان',
#  'كي',
#  'هي',
#  'عین',
#  'خميس',
#  'كأن',
#  'قطّ',
#  'ليسوا',
#  'دسته',
#  'كانون',
#  'أضحى',
#  'كلما',
#  'ذَيْنِ',
#  'لنا',
#  'اربعين',
#  'لعل',
#  'هنا',
#  'غين',
#  'أيضا',
#  'از',
#  'می\u200cکند',
#  'شما',
#  'طرف',
#  'خاص',
#  'جعل',
#  'عشرين',
#  'عل',
#  'أمامك',
#  'رشد',
#  'درى',
#  'عدم',
#  'داشتن',
#  'ثمانين',
#  'أنًّ',
#  'هلم',
#  'سوى',
#  'براساس',
#  'نوعی',
#  'سهم',
#  'نيسان',
#  'بیرون',
#  'س',
#  'في',
#  'صدقا',
#  'طی',
#  'أمامكَ',
#  'تانِ',
#  'هَذَيْنِ',
#  'يمين',
#  'سوم',
#  'یافته',
#  'والذين',
#  'ثمَّ',
#  'اللتان',
#  'فيها',
#  'اخلولق',
#  'ترتیب',
#  'صرف',
#  'عسى',
#  'ز',
#  'أوّهْ',
#  'فيم',
#  'أولالك',
#  'أنتم',
#  'می\u200cشود',
#  'كما',
#  'رويدك',
#  'عليك',
#  'مكانكما',
#  'باشد',
#  'ج',
#  'طفق',
#  'كاف',
#  'هَاتِه',
#  'بی',
#  'ولی',
#  'خمسون',
#  'كأيّ',
#  'افراد',
#  'امر',
#  'علاوه',
#  'چهار',
#  'دانست',
#  'وی',
#  'آنها',
#  'طول',
#  'حد',
#  'أنشأ',
#  'کسی',
#  'أعطى',
#  'می\u200cباشد',
#  'کردم',
#  'داده_است',
#  'أوت',
#  'روش',
#  'هر',
#  'بخٍ',
#  'شد',
#  'سبعمئة',
#  'بنا',
#  'آه',
#  'حدَث',
#  'أمّا',
#  'سمعا',
#  'اللائي',
#  'باشند',
#  'علیه',
#  'كسا',
#  'كن',
#  'می\u200cکنیم',
#  'بسیار',
#  'لما',
#  'لكيلا',
#  'وهب',
#  'آنجا',
#  'أم',
#  'هم',
#  'شيكل',
#  'بئس',
#  'أولاء',
#  'می\u200cکردند',
#  'زاده',
#  'حتى',
#  'لسن',
#  'هاكَ',
#  'ماذا',
#  'فضلا',
#  'دينار',
#  'غ',
#  'ماي',
#  'هذي',
#  'بعضی',
#  'كلتا',
#  'هذه',
#  'صهٍ',
#  'أيّان',
#  'مناسب',
#  'چون',
#  'لوما',
#  'لك',
#  'سایر',
#  'إلا',
#  'برداری',
#  'ا',
#  'همواره',
#  'می\u200cکنند',
#  'اما',
#  'همین',
#  'دوباره',
#  'ع',
#  'نیز',
#  'عهده',
#  'أنت',
#  'نيف',
#  'عشرة',
#  'ضمن',
#  'تاء',
#  'شده_اند',
#  'ثمان',
#  'بنابراین',
#  'بَلْهَ',
#  'می\u200cشد',
#  'یکی',
#  'بسیاری',
#  'امکان',
#  'دو',
#  'اللتيا',
#  'آذار',
#  'می\u200cگویند',
#  'می\u200cتوان',
#  'لاسيما',
#  'آناء',
#  'ذاك',
#  'من',
#  'کننده',
#  'مهم',
#  'نیستند',
#  'لم',
#  'هما',
#  'شتان',
#  'جويلية',
#  'أوشك',
#  'طالما',
#  'لهما',
#  'مورد',
#  'تي',
#  'هنگام',
#  'خال',
#  'أصلا',
#  'كِخ',
#  'ذلكما',
#  'گونه',
#  'سازی',
#  'دون',
#  'هل',
#  'لازم',
#  'ذه',
#  'آهِ',
#  'مافتئ',
#  'حين',
#  'علًّ',
#  'هَاتِي',
#  'انقلب',
#  'عند',
#  'را',
#  'ما انفك',
#  'داشته_باشند',
#  'می\u200cرسد',
#  'واهاً',
#  'ذا',
#  'سبع',
#  'ريث',
#  'اولین',
#  'أمس',
#  'متفاوت',
#  'إما',
#  'ثم',
#  'لو',
#  'لعلَّ',
#  'عيانا',
#  'گرفت',
#  'ثمنمئة',
#  'ذواتي',
#  'یافت',
#  'تعلَّم',
#  'خلف',
#  'قابل',
#  'منه',
#  'ندارند',
#  'تسعة',
#  'متر',
#  'خود',
#  'روبه',
#  'أربعاء',
#  'له',
#  'دور',
#  'ذلك',
#  'ى',
#  'إزاء',
#  'گرفته_است',
#  'ريال',
#  'ابتدأ',
#  'جایی',
#  'إذا',
#  'اثنا',
#  'أنتن',
#  'الألى',
#  'إيهٍ',
#  'یکدیگر',
#  'می\u200cآید',
#  'آب',
#  'شده',
#  'ثان',
#  'لها',
#  'خبَّر',
#  'او',
#  'پی',
#  'ذان',
#  'تِه',
#  'آنفا',
#  'بیش',
#  'بعدا',
#  'كلاهما',
#  'سابع',
#  'اخیر',
#  'هستیم',
#  'همچون',
#  'خاطرنشان',
#  'ذِه',
#  'ثلاث',
#  'كأين',
#  'آمد',
#  'اثر',
#  'إياكن',
#  'همچنین',
#  'أى',
#  'ستة',
#  'منها',
#  'يا',
#  'ميم',
#  'لبيك',
#  'رو',
#  'داشتند',
#  'ابتدا',
#  'می\u200cدهد',
#  'خویش',
#  'تهیه',
#  'دوم',
#  'تسعمئة',
#  'وا',
#  'دولار',
#  'می\u200cتواند',
#  'أجل',
#  'أنتما',
#  'داده',
#  'لكم',
#  'خلافا',
#  'شود',
#  'حتی',
#  'هاء',
#  'رسید',
#  'تانِك',
#  'هاتي',
#  'شروع',
#  'والذي',
#  'شده_است',
#  'بخش',
#  'إياكم',
#  'صبر',
#  'سراسر',
#  'كذا',
#  'لهن',
#  'سالهای',
#  'ضاد',
#  'نا',
#  'دونك',
#  'كليهما',
#  'شمار',
#  'ثمّ',
#  'دارند',
#  'داشته',
#  'إيانا',
#  'اتخذ',
#  'هللة',
#  'پیدا',
#  'شتانَ',
#  'ءَ',
#  'خمسين',
#  'نوفمبر',
#  'عدا',
#  'فمن',
#  'ظ',
#  'ظلّ',
#  'آوری',
#  'جدی',
#  'فاء',
#  'إليكَ',
#  'سبعمائة',
#  'حاء',
#  'هناك',
#  'مذ',
#  'دار',
#  'هذين',
#  'باز',
#  'هَذا',
#  'ض',
#  'قاطبة',
#  'حبذا',
#  'کرده',
#  'چهارم',
#  'کرده_اند',
#  'علم',
#  'پیش',
#  'همیشه',
#  'کرده_بود',
#  'ل',
#  'درهم',
#  'درون',
#  'بار',
#  'تحت',
#  'إحدى',
#  'أكثر',
#  'إى',
#  'لمّا',
#  'گفت',
#  'أما',
#  'جميع',
#  'إياهن',
#  'آمينَ',
#  'بوده_است',
#  'أين',
#  'ولا',
#  'لا',
#  'إليكنّ',
#  'گرفته',
#  'لهم',
#  'الألاء',
#  'اول',
#  'خوبی',
#  'کمی',
#  'عين',
#  'فبراير',
#  'إياها',
#  'رأى',
#  'حقا',
#  'دادند',
#  'ثماني',
#  'یابد',
#  'حمو',
#  'کردن',
#  'خیلی',
#  'التي',
#  'خ',
#  'علت',
#  'پخش',
#  'ي',
#  'هبّ',
#  'سرا',
#  'نیاز',
#  'بزرگ',
#  'دال',
#  'بماذا',
#  'بَسْ',
#  'چه',
#  'کرد',
#  'بلکه',
#  'زیاد',
#  'رزق',
#  'يوليو',
#  'كى',
#  'ثلاثاء',
#  'ئ',
#  'صبرا',
#  'باء',
#  'شان',
#  'شدن',
#  'كيف',
#  'تَيْنِ',
#  'تعسا',
#  'بكن',
#  'كلَّا',
#  'فوق',
#  'حيث',
#  'و',
#  'فرادى',
#  'رفت',
#  'فردی',
#  'ارتدّ',
#  'با',
#  'أخبر',
#  'اینکه',
#  'إلَيْكَ',
#  'طور',
#  'ليت',
#  'ومن',
#  'نباید',
#  'كثيرا',
#  'إذاً',
#  'أنى',
#  'بود',
#  'ستون',
#  'می\u200cگیرد',
#  'ما',
#  'وإن',
#  'تعیین',
#  'تمامی',
#  'همان',
#  'کلی',
#  'داد',
#  'جا',
#  'عشرون',
#  'چرا',
#  'الذين',
#  'جمع',
#  'أيلول',
#  'أفعل به',
#  'تسعمائة',
#  'هيهات',
#  'نفس',
#  'باید',
#  'بعد',
#  'إي',
#  'جدید',
#  'حداقل',
#  'نحو',
#  'كأيّن',
#  'تسعين',
#  'کنم',
#  'سرعان',
#  'آمده',
#  'دهد',
#  'نخست',
#  'كأي',
#  'موجب',
#  'شمال',
#  'دچار',
#  'سوف',
#  'أربعمائة',
#  'تبدّل',
#  'لستن',
#  'ذلكم',
#  'ته',
#  'هن',
#  'تموز',
#  'کل',
#  'بر',
#  'ریزی',
#  'ليرة',
#  'إياك',
#  'یعنی',
#  'ح',
#  'كم',
#  'ألا',
#  'نیست',
#  'وُشْكَانَ',
#  'ؤ',
#  'پشت',
#  'غير',
#  'میان',
#  'ساز',
#  'شين',
#  'أفٍّ',
#  'ذ',
#  'ط',
#  'ساء',
#  'بعض',
#  'لام',
#  'سحقا',
#  'حالا',
#  'برخی',
#  'ثالث',
#  'أطعم',
#  'ممکن',
#  'تسعون',
#  'لات',
#  'برای',
#  'هاك',
#  'هيت',
#  'حبيب',
#  'بیشتر',
#  'هذا',
#  'ساله',
#  'أغسطس',
#  'منذ',
#  'بلى',
#  'نون',
#  'هنالك',
#  'ها',
#  'كيت',
#  'بين',
#  'أمسى',
#  'زیر',
#  'هو',
#  'ألف',
#  'بخ',
#  'ورد',
#  'دیگران',
#  'لكن',
#  'لدى',
#  'لسنا',
#  'لعمر',
#  'مئتان',
#  'مازال',
#  'تلك',
#  'لستما',
#  'مائة',
#  'كليكما',
#  'ياء',
#  'کدام',
#  'م',
#  'چنین',
#  'ش',
#  'زاي',
#  'هَاتانِ',
#  'بهترین',
#  'أينما',
#  'ثاني',
#  'ذِي',
#  'هنوز',
#  'قد',
#  'است',
#  'بروز',
#  'طَق',
#  'حمٌ',
#  'خودش',
#  'كلا',
#  'غیر',
#  'ثامن',
#  'أولئك',
#  'تبدیل',
#  'غالبا',
#  'مكانكنّ',
#  'حسب',
#  'ذينك',
#  'أعلم',
#  'روی',
#  'لكما',
#  'أ',
#  'هيا',
#  'أول',
#  'خوب',
#  'نظیر',
#  'أحد',
#  'نمی\u200cشود',
#  'سه',
#  'بات',
#  'فلس',
#  'ثمانمئة',
#  'هاتين',
#  'متاسفانه',
#  'إلى',
#  'حجا',
#  'أربعة',
#  'ثمانون',
#  'هستند',
#  'ق',
#  'ه',
#  'بما',
#  'وقتی',
#  'ء',
#  'عما',
#  'دارد',
#  'کردند',
#  'منظور',
#  'همزة',
#  'آنان',
#  'تنها',
#  'ایشان',
#  'چیز',
#  'هیچ',
#  'نشست',
#  'خصوص',
#  'ذهب',
#  'أنتِ',
#  'جير',
#  'فرد',
#  'فقط',
#  'هَاتَيْنِ',
#  'رسیدن',
#  'شبه',
#  'نَّ',
#  'کنار',
#  'ليستا',
#  'حدود',
#  'يفعلون',
#  'آها',
#  'عاد',
#  'أو',
#  'أنا',
#  'عشر',
#  'ضحوة',
#  'کنیم',
#  'زعم',
#  'اکنون',
#  'همچنان',
#  'أبو',
#  'أف',
#  'بندی',
#  'هذان',
#  'بیشتری',
#  'تجاه',
#  'هاهنا',
#  'در',
#  'سعی',
#  'خواهد_کرد',
#  'تو',
#  'کافی',
#  'ذانك',
#  'فيه',
#  'شدند',
#  'آورد',
#  'چند',
#  'بهم',
#  'تشرين',
#  'د',
#  'ثلاثة',
#  'غدا',
#  'حال',
#  'کرده_است',
#  'أهلا',
#  'تين',
#  'پر',
#  'ك',
#  'بي',
#  'لست',
#  'ثلاثين',
#  'نحن',
#  'يناير',
#  'فلان',
#  'أبٌ',
#  'باره',
#  'داشته_است',
#  'يورو',
#  'أبدا',
#  'فيفري',
#  'جاری',
#  'الآن',
#  'می\u200cکرد',
#  'إنه',
#  'فإن',
#  'داریم',
#  'هؤلاء',
#  'نیمه',
#  'ليس',
#  'خمسمائة',
#  'گیری',
#  'لحاظ',
#  'أيار',
#  'تِي',
#  'أمام',
#  'أصبح',
#  'ين',
#  'أفريل',
#  'گردد',
#  'إن',
#  'يوان',
#  'قبل',
#  'شش',
#  'نوع',
#  'ثلاثمائة',
#  'إياه',
#  'بیان',
#  'البته',
#  'ولو',
#  'نزدیک',
#  'بكما',
#  'سبت',
#  'سادس',
#  'عن',
#  'أبريل',
#  'شرع',
#  'دارای',
#  'خطر',
#  'جمعی',
#  'یا',
#  'آهاً',
#  'اثنان',
#  'عدَّ',
#  'اش',
#  'چگونه',
#  'آیا',
#  'أُفٍّ',
#  'سپس',
#  'وَيْ',
#  'هَؤلاء',
#  'جوان',
#  'تفعلين',
#  'ن',
#  'مانند',
#  'مع',
#  'بودن',
#  'شامل',
#  'کوچک',
#  'إيه',
#  'باعث',
#  'سبتمبر',
#  'لكنما',
#  'آقای',
#  'شَتَّانَ',
#  'اللتين',
#  'أقبل',
#  'ست',
#  'پنج',
#  'صباح',
#  'حزيران',
#  'ثمة',
#  'می\u200cرود',
#  'إياهما',
#  'لا سيما',
#  'بغتة',
#  'اللذين',
#  'على',
#  'صهْ',
#  'کنند',
#  'نحوه',
#  'تينك',
#  'ف',
#  'ثلاثون',
#  'قام',
#  'تارة',
#  'ناشی',
#  'انبرى',
#  'آ',
#  'کامل',
#  'ذات',
#  'إليكم',
#  'حادي',
#  'صاد',
#  'كأنّ',
#  'مثل',
#  'ولكن',
#  'أربعمئة',
#  'علق',
#  'كاد',
#  'وجود',
#  'زیرا',
#  'گاه',
#  'لن',
#  'می\u200cگوید',
#  ...}

# %%
filtered_words=[]
for word in corpus:
    if word not in stop_words:
        filtered_words.append(word)

# %%
filtered_words
# Out:
# ['یادگیری',
#  'ماشینی',
#  'به انگلیسی',
#  'مطالعه\u200cی',
#  'علمی',
#  'الگوریتم\u200cها',
#  'مدل\u200cهای',
#  'آماری',
#  'استفاده\u200cی',
#  'سیستم\u200cهای',
#  'کامپیوتری',
#  'به\u200cجای',
#  'استفاده',
#  'دستورالعمل\u200cهای',
#  'واضح',
#  '،',
#  'الگوها',
#  'استنباط',
#  'انجام',
#  'وظایف',
#  'سود',
#  'می\u200cبرند',
#  '۱',
#  ' یادگیری',
#  'ماشینی',
#  'علمی',
#  'رایانه\u200cها',
#  'برنامه',
#  'صریح',
#  'موضوع',
#  'یاد',
#  'بگیرند',
#  'عنوان',
#  'مجموعه\u200cای',
#  'هوش',
#  'مصنوعی',
#  '،',
#  'الگوریتم\u200cهای',
#  'یادگیری',
#  'ماشینی',
#  'مدل',
#  'ریاضی',
#  'اساس',
#  'داده\u200cهای',
#  'نمونه',
#  'داده\u200cهای',
#  'آموزش',
#  'پیش\u200cبینی',
#  'تصمیم\u200cگیری',
#  'برنامه\u200cریزی',
#  'آشکار',
#  '،',
#  'ایجاد']

# %%
stemmer = Stemmer()
lemmatizer = Lemmatizer()
normalizer = Normalizer()

# %%
for token in words:
    token = normalizer.normalize(token)
    print("stem" + "-> "+ stemmer.stem(token))
    print("lemma" + "-> "+lemmatizer.lemmatize(token))
    print("\n")
# Out:
# stem-> یادگیر
# lemma-> یادگیری
#
#
# stem-> ماشین
# lemma-> ماشینی
#
#
# stem-> (
# lemma-> (
#
#
# stem-> ML
# lemma-> ML
#
#
# stem-> )
# lemma-> )
#
#
# stem->
# lemma->
#
#
# stem-> (
# lemma-> (
#
#
# stem-> به انگلیس
# lemma-> به انگلیسی
#
#
# stem-> :
# lemma-> :
#
#
# stem->  Machine
# lemma->  Machine
#
#
# stem-> learning
# lemma-> learning
#
#
# stem-> )
# lemma-> )
#
#
# stem-> مطالعه
# lemma-> مطالعه
#
#
# stem-> علم
# lemma-> علم
#
#
# stem-> الگوریتم
# lemma-> الگوریتم
#
#
# stem-> و
# lemma-> و
#
#
# stem-> مدل
# lemma-> مدل‌های
#
#
# stem-> آمار
# lemma-> آمار
#
#
# stem-> مورد
# lemma-> مورد
#
#
# stem-> استفاده
# lemma-> استفاده
#
#
# stem-> سیستم
# lemma-> سیستم‌های
#
#
# stem-> کامپیوتر
# lemma-> کامپیوتری
#
#
# stem-> اس
# lemma-> #است
#
#
# stem-> که
# lemma-> که
#
#
# stem-> به‌جا
# lemma-> به‌جای
#
#
# stem-> استفاده
# lemma-> استفاده
#
#
# stem-> از
# lemma-> از
#
#
# stem-> دستورالعمل
# lemma-> دستورالعمل
#
#
# stem-> واضح
# lemma-> واضح
#
#
# stem-> ،
# lemma-> ،
#
#
# stem-> از
# lemma-> از
#
#
# stem-> الگو
# lemma-> الگو
#
#
# stem-> و
# lemma-> و
#
#
# stem-> استنباط
# lemma-> استنباط
#
#
# stem-> برا
# lemma-> برای
#
#
# stem-> انجا
# lemma-> انجام
#
#
# stem-> وظایف
# lemma-> وظایف
#
#
# stem-> سود
# lemma-> سود
#
#
# stem-> می‌برند
# lemma-> برد#بر
#
#
# stem-> .
# lemma-> .
#
#
# stem-> [
# lemma-> [
#
#
# stem-> ۱
# lemma-> ۱
#
#
# stem-> ]
# lemma-> ]
#
#
# stem->  یادگیر
# lemma->  یادگیری
#
#
# stem-> ماشین
# lemma-> ماشینی
#
#
# stem-> علم
# lemma-> علم
#
#
# stem-> اس
# lemma-> #است
#
#
# stem-> که
# lemma-> که
#
#
# stem-> باعث
# lemma-> باعث
#
#
# stem-> می‌شود
# lemma-> شد#شو
#
#
# stem-> رایانه
# lemma-> رایانه
#
#
# stem-> بدون
# lemma-> بدون
#
#
# stem-> نیاز
# lemma-> نیاز
#
#
# stem-> به
# lemma-> به
#
#
# stem-> یک
# lemma-> یک
#
#
# stem-> برنامه
# lemma-> برنامه
#
#
# stem-> صریح
# lemma-> صریح
#
#
# stem-> در
# lemma-> در
#
#
# stem-> مورد
# lemma-> مورد
#
#
# stem-> یک
# lemma-> یک
#
#
# stem-> موضوع
# lemma-> موضوع
#
#
# stem-> خاص
# lemma-> خاص
#
#
# stem-> یاد
# lemma-> یاد
#
#
# stem-> بگیرند
# lemma-> گرفت#گیر
#
#
# stem-> .
# lemma-> .
#
#
# stem-> به
# lemma-> به
#
#
# stem-> عنو
# lemma-> عنوان
#
#
# stem-> زیر
# lemma-> زیر
#
#
# stem-> مجموعه
# lemma-> مجموعه
#
#
# stem-> از
# lemma-> از
#
#
# stem-> هو
# lemma-> هوش
#
#
# stem-> مصنوع
# lemma-> مصنوع
#
#
# stem-> ،
# lemma-> ،
#
#
# stem-> الگوریتم
# lemma-> الگوریتم
#
#
# stem-> یادگیر
# lemma-> یادگیری
#
#
# stem-> ماشین
# lemma-> ماشینی
#
#
# stem-> یک
# lemma-> یک
#
#
# stem-> مدل
# lemma-> مدل
#
#
# stem-> ریاض
# lemma-> ریاضی
#
#
# stem-> بر
# lemma-> بر
#
#
# stem-> اساس
# lemma-> اساس
#
#
# stem-> داده
# lemma-> داده
#
#
# stem-> نمونه
# lemma-> نمونه
#
#
# stem-> یا
# lemma-> یا
#
#
# stem-> "
# lemma-> "
#
#
# stem-> داده
# lemma-> داده
#
#
# stem-> آموز
# lemma-> آموزش
#
#
# stem-> "
# lemma-> "
#
#
# stem-> به
# lemma-> به
#
#
# stem-> منظور
# lemma-> منظور
#
#
# stem-> پیش‌بین
# lemma-> پیش‌بینی
#
#
# stem-> یا
# lemma-> یا
#
#
# stem-> تصمیم‌گیر
# lemma-> تصمیم‌گیری
#
#
# stem-> بدون
# lemma-> بدون
#
#
# stem-> برنامه‌ریز
# lemma-> برنامه‌ریزی
#
#
# stem-> آشکار
# lemma-> آشکار
#
#
# stem-> ،
# lemma-> ،
#
#
# stem-> ایجاد
# lemma-> ایجاد
#
#
# stem-> می‌کنند
# lemma-> کرد#کن
#
#
# stem-> .
# lemma-> .

# %%
import nltk
from nltk.corpus import stopwords

# %%
print(stopwords.fileids())
# Out:
# ['arabic', 'azerbaijani', 'bengali', 'danish', 'dutch', 'english', 'finnish', 'french', 'german', 'greek', 'hungarian', 'indonesian', 'italian', 'kazakh', 'nepali', 'norwegian', 'portuguese', 'romanian', 'russian', 'slovene', 'spanish', 'swedish', 'tajik', 'turkish']

# %%
corpus = []
for c in sample_persian:
    if (ord(c) >600) or (ord(c) == 32)  :
        corpus.append(c)

# %%
sample_persian
# Out:
# 'یادگیری ماشینی(ML)\xa0(به\xa0انگلیسی:\xa0Machine learning) مطالعه\u200cی علمی الگوریتم\u200cها و مدل\u200cهای آماری مورد استفاده\u200cی سیستم\u200cهای کامپیوتری است که به\u200cجای استفاده از دستورالعمل\u200cهای واضح، از الگوها و استنباط برای انجام وظایف سود می\u200cبرند.[۱]\xa0یادگیری ماشینی علمی است که باعث می\u200cشود رایانه\u200cها بدون نیاز به یک برنامه صریح در مورد یک موضوع خاص یاد بگیرند. به عنوان زیر مجموعه\u200cای از هوش مصنوعی، الگوریتم\u200cهای یادگیری ماشینی یک مدل ریاضی بر اساس داده\u200cهای نمونه یا "داده\u200cهای آموزش" به منظور پیش\u200cبینی یا تصمیم\u200cگیری بدون برنامه\u200cریزی آشکار، ایجاد می\u200cکنند.'

# %%
corpus
# Out:
# ['ی',
#  'ا',
#  'د',
#  'گ',
#  'ی',
#  'ر',
#  'ی',
#  ' ',
#  'م',
#  'ا',
#  'ش',
#  'ی',
#  'ن',
#  'ی',
#  'ب',
#  'ه',
#  'ا',
#  'ن',
#  'گ',
#  'ل',
#  'ی',
#  'س',
#  'ی',
#  ' ',
#  ' ',
#  'م',
#  'ط',
#  'ا',
#  'ل',
#  'ع',
#  'ه',
#  '\u200c',
#  'ی',
#  ' ',
#  'ع',
#  'ل',
#  'م',
#  'ی',
#  ' ',
#  'ا',
#  'ل',
#  'گ',
#  'و',
#  'ر',
#  'ی',
#  'ت',
#  'م',
#  '\u200c',
#  'ه',
#  'ا',
#  ' ',
#  'و',
#  ' ',
#  'م',
#  'د',
#  'ل',
#  '\u200c',
#  'ه',
#  'ا',
#  'ی',
#  ' ',
#  'آ',
#  'م',
#  'ا',
#  'ر',
#  'ی',
#  ' ',
#  'م',
#  'و',
#  'ر',
#  'د',
#  ' ',
#  'ا',
#  'س',
#  'ت',
#  'ف',
#  'ا',
#  'د',
#  'ه',
#  '\u200c',
#  'ی',
#  ' ',
#  'س',
#  'ی',
#  'س',
#  'ت',
#  'م',
#  '\u200c',
#  'ه',
#  'ا',
#  'ی',
#  ' ',
#  'ک',
#  'ا',
#  'م',
#  'پ',
#  'ی',
#  'و',
#  'ت',
#  'ر',
#  'ی',
#  ' ',
#  'ا',
#  'س',
#  'ت',
#  ' ',
#  'ک',
#  'ه',
#  ' ',
#  'ب',
#  'ه',
#  '\u200c',
#  'ج',
#  'ا',
#  'ی',
#  ' ',
#  'ا',
#  'س',
#  'ت',
#  'ف',
#  'ا',
#  'د',
#  'ه',
#  ' ',
#  'ا',
#  'ز',
#  ' ',
#  'د',
#  'س',
#  'ت',
#  'و',
#  'ر',
#  'ا',
#  'ل',
#  'ع',
#  'م',
#  'ل',
#  '\u200c',
#  'ه',
#  'ا',
#  'ی',
#  ' ',
#  'و',
#  'ا',
#  'ض',
#  'ح',
#  '،',
#  ' ',
#  'ا',
#  'ز',
#  ' ',
#  'ا',
#  'ل',
#  'گ',
#  'و',
#  'ه',
#  'ا',
#  ' ',
#  'و',
#  ' ',
#  'ا',
#  'س',
#  'ت',
#  'ن',
#  'ب',
#  'ا',
#  'ط',
#  ' ',
#  'ب',
#  'ر',
#  'ا',
#  'ی',
#  ' ',
#  'ا',
#  'ن',
#  'ج',
#  'ا',
#  'م',
#  ' ',
#  'و',
#  'ظ',
#  'ا',
#  'ی',
#  'ف',
#  ' ',
#  'س',
#  'و',
#  'د',
#  ' ',
#  'م',
#  'ی',
#  '\u200c',
#  'ب',
#  'ر',
#  'ن',
#  'د',
#  '۱',
#  'ی',
#  'ا',
#  'د',
#  'گ',
#  'ی',
#  'ر',
#  'ی',
#  ' ',
#  'م',
#  'ا',
#  'ش',
#  'ی',
#  'ن',
#  'ی',
#  ' ',
#  'ع',
#  'ل',
#  'م',
#  'ی',
#  ' ',
#  'ا',
#  'س',
#  'ت',
#  ' ',
#  'ک',
#  'ه',
#  ' ',
#  'ب',
#  'ا',
#  'ع',
#  'ث',
#  ' ',
#  'م',
#  'ی',
#  '\u200c',
#  'ش',
#  'و',
#  'د',
#  ' ',
#  'ر',
#  'ا',
#  'ی',
#  'ا',
#  'ن',
#  'ه',
#  '\u200c',
#  'ه',
#  'ا',
#  ' ',
#  'ب',
#  'د',
#  'و',
#  'ن',
#  ' ',
#  'ن',
#  'ی',
#  'ا',
#  'ز',
#  ' ',
#  'ب',
#  'ه',
#  ' ',
#  'ی',
#  'ک',
#  ' ',
#  'ب',
#  'ر',
#  'ن',
#  'ا',
#  'م',
#  'ه',
#  ' ',
#  'ص',
#  'ر',
#  'ی',
#  'ح',
#  ' ',
#  'د',
#  'ر',
#  ' ',
#  'م',
#  'و',
#  'ر',
#  'د',
#  ' ',
#  'ی',
#  'ک',
#  ' ',
#  'م',
#  'و',
#  'ض',
#  'و',
#  'ع',
#  ' ',
#  'خ',
#  'ا',
#  'ص',
#  ' ',
#  'ی',
#  'ا',
#  'د',
#  ' ',
#  'ب',
#  'گ',
#  'ی',
#  'ر',
#  'ن',
#  'د',
#  ' ',
#  'ب',
#  'ه',
#  ' ',
#  'ع',
#  'ن',
#  'و',
#  'ا',
#  'ن',
#  ' ',
#  'ز',
#  'ی',
#  'ر',
#  ' ',
#  'م',
#  'ج',
#  'م',
#  'و',
#  'ع',
#  'ه',
#  '\u200c',
#  'ا',
#  'ی',
#  ' ',
#  'ا',
#  'ز',
#  ' ',
#  'ه',
#  'و',
#  'ش',
#  ' ',
#  'م',
#  'ص',
#  'ن',
#  'و',
#  'ع',
#  'ی',
#  '،',
#  ' ',
#  'ا',
#  'ل',
#  'گ',
#  'و',
#  'ر',
#  'ی',
#  'ت',
#  'م',
#  '\u200c',
#  'ه',
#  'ا',
#  'ی',
#  ' ',
#  'ی',
#  'ا',
#  'د',
#  'گ',
#  'ی',
#  'ر',
#  'ی',
#  ' ',
#  'م',
#  'ا',
#  'ش',
#  'ی',
#  'ن',
#  'ی',
#  ' ',
#  'ی',
#  'ک',
#  ' ',
#  'م',
#  'د',
#  'ل',
#  ' ',
#  'ر',
#  'ی',
#  'ا',
#  'ض',
#  'ی',
#  ' ',
#  'ب',
#  'ر',
#  ' ',
#  'ا',
#  'س',
#  'ا',
#  'س',
#  ' ',
#  'د',
#  'ا',
#  'د',
#  'ه',
#  '\u200c',
#  'ه',
#  'ا',
#  'ی',
#  ' ',
#  'ن',
#  'م',
#  'و',
#  'ن',
#  'ه',
#  ' ',
#  'ی',
#  'ا',
#  ' ',
#  'د',
#  'ا',
#  'د',
#  'ه',
#  '\u200c',
#  'ه',
#  'ا',
#  'ی',
#  ' ',
#  'آ',
#  'م',
#  'و',
#  'ز',
#  'ش',
#  ' ',
#  'ب',
#  'ه',
#  ' ',
#  'م',
#  'ن',
#  'ظ',
#  'و',
#  'ر',
#  ' ',
#  'پ',
#  'ی',
#  'ش',
#  '\u200c',
#  'ب',
#  'ی',
#  'ن',
#  'ی',
#  ' ',
#  'ی',
#  'ا',
#  ' ',
#  'ت',
#  'ص',
#  'م',
#  'ی',
#  'م',
#  '\u200c',
#  'گ',
#  'ی',
#  'ر',
#  'ی',
#  ' ',
#  'ب',
#  'د',
#  'و',
#  'ن',
#  ' ',
#  'ب',
#  'ر',
#  'ن',
#  'ا',
#  'م',
#  'ه',
#  '\u200c',
#  'ر',
#  'ی',
#  'ز',
#  'ی',
#  ' ',
#  'آ',
#  'ش',
#  'ک',
#  'ا',
#  'ر',
#  '،',
#  ' ',
#  'ا',
#  'ی',
#  'ج',
#  'ا',
#  'د',
#  ' ',
#  'م',
#  'ی',
#  '\u200c',
#  'ک',
#  'ن',
#  'ن',
#  'د']
