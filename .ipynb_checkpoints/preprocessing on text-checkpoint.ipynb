# %% [markdown]
# <a href="https://colab.research.google.com/github/heidaralavi/working-with-persian-text/blob/main/preprocessing%20on%20text.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#%debug

# %%
#!pip install nltk

# %%
#!pip install hazm

# %%
import nltk
#nltk.download()

# %%
from __future__ import unicode_literals
from hazm import *

# %%
#%debug

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
#importing data from file
df=pd.read_excel('data.xlsx')

# %%
df.head()
# Out:
#    شماره درخواست کد ماشین  تاریخ خرابی        وضعیت نام ماشین نوع درخواست  \
# 0       93078329      NaN     14000608  درحال بررسي       NaN        عادي
# 1       93078330      NaN     14000608  درحال بررسي       NaN        عادي
# 2       93078331      NaN     14000608  درحال بررسي       NaN        عادي
# 3       93078474      NaN     14000612  درحال بررسي       NaN        عادي
# 4       93078633      NaN     14000616  درحال بررسي       NaN        عادي
#
#           ق.ص. درخواست علت خرابی  مدت انجام كار  \
# 0  هيدروليك و روانكاري       NaN              0
# 1  هيدروليك و روانكاري       NaN              0
# 2  هيدروليك و روانكاري       NaN              0
# 3  هيدروليك و روانكاري       NaN              0
# 4  هيدروليك و روانكاري       NaN              0
#
#                                             شرح مشكل  تاريخ شروع  \
# 0  سيستم گريس بالميل آلارم دارد و اسپري انجام نمي...           0
# 1                    سيستم گريس ديسك يك آلارم دارد .           0
# 2     نشتي روغن  از پمپ مسير شماره يك هيدروليك 610wb           0
# 3                   سيستم گريسكاري بالميل آلارم دارد           0
# 4  دماي بيرينگ سمت موتور 710fn4 بالاست و سطح روغن...           0
#
#   شرح_كد دوره توقف (واقعي ) 2 شرح_محل استقرار
# 0                      نامشخص     930BM1.xxxx
# 1                      نامشخص     610PE1.XXXX
# 2                      نامشخص          610BW8
# 3                      نامشخص     930BM1.xxxx
# 4                      نامشخص     710FN4.xxxx

# %%
cols=['وضعیت','نوع درخواست','ق.ص. درخواست','شرح مشكل','شرح_كد دوره توقف (واقعي ) 2']
for col in cols:
    x=[]
    for item in df[col].values:
        x.append(item.strip())
    df[col]=x

# %%
df
# Out:
#       شماره درخواست کد ماشین  تاریخ خرابی        وضعیت نام ماشین نوع درخواست  \
# 0          93078329      NaN     14000608  درحال بررسي       NaN        عادي
# 1          93078330      NaN     14000608  درحال بررسي       NaN        عادي
# 2          93078331      NaN     14000608  درحال بررسي       NaN        عادي
# 3          93078474      NaN     14000612  درحال بررسي       NaN        عادي
# 4          93078633      NaN     14000616  درحال بررسي       NaN        عادي
# ...             ...      ...          ...          ...       ...         ...
# 6145       93079110      NaN     14000630  درحال انجام       NaN        عادي
# 6146       93079611      NaN     14000715  پايان يافته       NaN        عادي
# 6147       93078715      NaN     14000618  پايان يافته       NaN        عادي
# 6148       93081354      NaN     14000908  پايان يافته       NaN        عادي
# 6149       93082290      NaN     14001008  پايان يافته       NaN        عادي
#
#              ق.ص. درخواست علت خرابی  مدت انجام كار  \
# 0     هيدروليك و روانكاري       NaN              0
# 1     هيدروليك و روانكاري       NaN              0
# 2     هيدروليك و روانكاري       NaN              0
# 3     هيدروليك و روانكاري       NaN              0
# 4     هيدروليك و روانكاري       NaN              0
# ...                   ...       ...            ...
# 6145            ابزاردقيق       NaN            120
# 6146  هيدروليك و روانكاري       NaN             60
# 6147  هيدروليك و روانكاري       NaN             60
# 6148  هيدروليك و روانكاري       NaN            120
# 6149  هيدروليك و روانكاري       NaN             60
#
#                                                شرح مشكل  تاريخ شروع  \
# 0     سيستم گريس بالميل آلارم دارد و اسپري انجام نمي...           0
# 1                       سيستم گريس ديسك يك آلارم دارد .           0
# 2        نشتي روغن  از پمپ مسير شماره يك هيدروليك 610wb           0
# 3                      سيستم گريسكاري بالميل آلارم دارد           0
# 4     دماي بيرينگ سمت موتور 710fn4 بالاست و سطح روغن...           0
# ...                                                 ...         ...
# 6145  سنسور نشان گر موقعيت WB بعضي مواقع گير ميكند و...           0
# 6146     لوله گريس پالت 15 از طوقه بيروني كنده شده است:           0
# 6147                  سيستم گريس چندين مرتبه تريپ خورد.           0
# 6148                 لوله گريس بيروني پالت 26 شكسته است           0
# 6149                       گريس دستي ديسك 4 جام ميباشد.           0
#
#      شرح_كد دوره توقف (واقعي ) 2 شرح_محل استقرار
# 0                         نامشخص     930BM1.xxxx
# 1                         نامشخص     610PE1.XXXX
# 2                         نامشخص          610BW8
# 3                         نامشخص     930BM1.xxxx
# 4                         نامشخص     710FN4.xxxx
# ...                          ...             ...
# 6145                توقف گرم 110     610WB1.xxxx
# 6146                      نامشخص     730AN1.XXXX
# 6147                      نامشخص     930BM1.xxxx
# 6148                      نامشخص     730AN1.XXXX
# 6149                      نامشخص     610PE4.XXXX
#
# [6150 rows x 13 columns]

# %% [markdown]
# توسط تابع نرمالایزر کلمات فارسی اگر حروف عربی بود تبدیل به حروف فارسی می شود

# %%
normalizer = Normalizer()

cols=['وضعیت','نوع درخواست','ق.ص. درخواست','شرح مشكل','شرح_كد دوره توقف (واقعي ) 2']
for col in cols:
    x=[]
    for item in df[col].values:
        x.append(normalizer.normalize(item))
    df[col]=x

# %%
df
# Out:
#       شماره درخواست کد ماشین  تاریخ خرابی        وضعیت نام ماشین نوع درخواست  \
# 0          93078329      NaN     14000608  درحال بررسی       NaN        عادی
# 1          93078330      NaN     14000608  درحال بررسی       NaN        عادی
# 2          93078331      NaN     14000608  درحال بررسی       NaN        عادی
# 3          93078474      NaN     14000612  درحال بررسی       NaN        عادی
# 4          93078633      NaN     14000616  درحال بررسی       NaN        عادی
# ...             ...      ...          ...          ...       ...         ...
# 6145       93079110      NaN     14000630  درحال انجام       NaN        عادی
# 6146       93079611      NaN     14000715  پایان یافته       NaN        عادی
# 6147       93078715      NaN     14000618  پایان یافته       NaN        عادی
# 6148       93081354      NaN     14000908  پایان یافته       NaN        عادی
# 6149       93082290      NaN     14001008  پایان یافته       NaN        عادی
#
#              ق.ص. درخواست علت خرابی  مدت انجام كار  \
# 0     هیدرولیک و روانکاری       NaN              0
# 1     هیدرولیک و روانکاری       NaN              0
# 2     هیدرولیک و روانکاری       NaN              0
# 3     هیدرولیک و روانکاری       NaN              0
# 4     هیدرولیک و روانکاری       NaN              0
# ...                   ...       ...            ...
# 6145            ابزاردقیق       NaN            120
# 6146  هیدرولیک و روانکاری       NaN             60
# 6147  هیدرولیک و روانکاری       NaN             60
# 6148  هیدرولیک و روانکاری       NaN            120
# 6149  هیدرولیک و روانکاری       NaN             60
#
#                                                شرح مشكل  تاريخ شروع  \
# 0     سیستم گریس بالمیل آلارم دارد و اسپری انجام نمی...           0
# 1                        سیستم گریس دیسک یک آلارم دارد.           0
# 2         نشتی روغن از پمپ مسیر شماره یک هیدرولیک ۶۱۰wb           0
# 3                      سیستم گریسکاری بالمیل آلارم دارد           0
# 4     دمای بیرینگ سمت موتور ۷۱۰fn۴ بالاست و سطح روغن...           0
# ...                                                 ...         ...
# 6145  سنسور نشان‌گر موقعیت WB بعضی مواقع گیر میکند و...           0
# 6146     لوله گریس پالت ۱۵ از طوقه بیرونی کنده شده است:           0
# 6147                  سیستم گریس چندین مرتبه تریپ خورد.           0
# 6148                 لوله گریس بیرونی پالت ۲۶ شکسته است           0
# 6149                       گریس دستی دیسک ۴ جام میباشد.           0
#
#      شرح_كد دوره توقف (واقعي ) 2 شرح_محل استقرار
# 0                         نامشخص     930BM1.xxxx
# 1                         نامشخص     610PE1.XXXX
# 2                         نامشخص          610BW8
# 3                         نامشخص     930BM1.xxxx
# 4                         نامشخص     710FN4.xxxx
# ...                          ...             ...
# 6145                توقف گرم ۱۱۰     610WB1.xxxx
# 6146                      نامشخص     730AN1.XXXX
# 6147                      نامشخص     930BM1.xxxx
# 6148                      نامشخص     730AN1.XXXX
# 6149                      نامشخص     610PE4.XXXX
#
# [6150 rows x 13 columns]

# %%
from nltk.corpus import stopwords
from nltk.tokenize import wordpunct_tokenize

#stop_words = set(stopwords.words('arabic'))

# %%
#making list of stopwords
df_stop_words=pd.read_csv('stopwords.dat',header=None, encoding='utf-8',)
stop_words=df_stop_words.iloc[:,0].tolist()
#stop_words.update(st_word)
stop_words
# Out:
# ['و',
#  'در',
#  'به',
#  'از',
#  'که',
#  'این',
#  'را',
#  'با',
#  'است',
#  'برای',
#  'آن',
#  'یک',
#  'خود',
#  'تا',
#  'کرد',
#  'بر',
#  'هم',
#  'نیز',
#  'گفت',
#  'می\u200cشود',
#  'وی',
#  'شد',
#  'دارد',
#  'ما',
#  'اما',
#  'یا',
#  'شده',
#  'باید',
#  'هر',
#  'آنها',
#  'بود',
#  'او',
#  'دیگر',
#  'دو',
#  'مورد',
#  'می\u200cکند',
#  'شود',
#  'کند',
#  'وجود',
#  'بین',
#  'پیش',
#  'شده_است',
#  'پس',
#  'نظر',
#  'اگر',
#  'همه',
#  'یکی',
#  'حال',
#  'هستند',
#  'من',
#  'کنند',
#  'نیست',
#  'باشد',
#  'چه',
#  'بی',
#  'می',
#  'بخش',
#  'می\u200cکنند',
#  'همین',
#  'افزود',
#  'هایی',
#  'دارند',
#  'راه',
#  'همچنین',
#  'روی',
#  'داد',
#  'بیشتر',
#  'بسیار',
#  'سه',
#  'داشت',
#  'چند',
#  'سوی',
#  'تنها',
#  'هیچ',
#  'میان',
#  'اینکه',
#  'شدن',
#  'بعد',
#  'جدید',
#  'ولی',
#  'حتی',
#  'کردن',
#  'برخی',
#  'کردند',
#  'می\u200cدهد',
#  'اول',
#  'نه',
#  'کرده_است',
#  'نسبت',
#  'بیش',
#  'شما',
#  'چنین',
#  'طور',
#  'افراد',
#  'تمام',
#  'درباره',
#  'بار',
#  'بسیاری',
#  'می\u200cتواند',
#  'کرده',
#  'چون',
#  'ندارد',
#  'دوم',
#  'بزرگ',
#  'طی',
#  'حدود',
#  'همان',
#  'بدون',
#  'البته',
#  'آنان',
#  'می\u200cگوید',
#  'دیگری',
#  'خواهد_شد',
#  'کنیم',
#  'قابل',
#  'یعنی',
#  'رشد',
#  'می\u200cتوان',
#  'وارد',
#  'کل',
#  'ویژه',
#  'قبل',
#  'براساس',
#  'نیاز',
#  'گذاری',
#  'هنوز',
#  'لازم',
#  'سازی',
#  'بوده_است',
#  'چرا',
#  'می\u200cشوند',
#  'وقتی',
#  'گرفت',
#  'کم',
#  'جای',
#  'حالی',
#  'تغییر',
#  'پیدا',
#  'اکنون',
#  'تحت',
#  'باعث',
#  'مدت',
#  'فقط',
#  'زیادی',
#  'تعداد',
#  'آیا',
#  'بیان',
#  'رو',
#  'شدند',
#  'عدم',
#  'کرده_اند',
#  'بودن',
#  'نوع',
#  'بلکه',
#  'جاری',
#  'دهد',
#  'برابر',
#  'مهم',
#  'بوده',
#  'اخیر',
#  'مربوط',
#  'امر',
#  'زیر',
#  'گیری',
#  'شاید',
#  'خصوص',
#  'آقای',
#  'اثر',
#  'کننده',
#  'بودند',
#  'فکر',
#  'کنار',
#  'اولین',
#  'سوم',
#  'سایر',
#  'کنید',
#  'ضمن',
#  'مانند',
#  'باز',
#  'می\u200cگیرد',
#  'ممکن',
#  'حل',
#  'دارای',
#  'پی',
#  'مثل',
#  'می\u200cرسد',
#  'اجرا',
#  'دور',
#  'منظور',
#  'کسی',
#  'موجب',
#  'طول',
#  'امکان',
#  'آنچه',
#  'تعیین',
#  'گفته',
#  'شوند',
#  'جمع',
#  'خیلی',
#  'علاوه',
#  'گونه',
#  'تاکنون',
#  'رسید',
#  'ساله',
#  'گرفته',
#  'شده_اند',
#  'علت',
#  'چهار',
#  'داشته_باشد',
#  'خواهد_بود',
#  'طرف',
#  'تهیه',
#  'تبدیل',
#  'مناسب',
#  'زیرا',
#  'مشخص',
#  'می\u200cتوانند',
#  'نزدیک',
#  'جریان',
#  'روند',
#  'بنابراین',
#  'می\u200cدهند',
#  'یافت',
#  'نخستین',
#  'بالا',
#  'پنج',
#  'ریزی',
#  'عالی',
#  'چیزی',
#  'نخست',
#  'بیشتری',
#  'ترتیب',
#  'شده_بود',
#  'خاص',
#  'خوبی',
#  'خوب',
#  'شروع',
#  'فرد',
#  'کامل',
#  'غیر',
#  'می\u200cرود',
#  'دهند',
#  'آخرین',
#  'دادن',
#  'جدی',
#  'بهترین',
#  'شامل',
#  'گیرد',
#  'بخشی',
#  'باشند',
#  'تمامی',
#  'بهتر',
#  'داده_است',
#  'حد',
#  'نبود',
#  'کسانی',
#  'می\u200cکرد',
#  'داریم',
#  'علیه',
#  'می\u200cباشد',
#  'دانست',
#  'ناشی',
#  'داشتند',
#  'دهه',
#  'می\u200cشد',
#  'ایشان',
#  'آنجا',
#  'گرفته_است',
#  'دچار',
#  'می\u200cآید',
#  'لحاظ',
#  'آنکه',
#  'داده',
#  'بعضی',
#  'هستیم',
#  'اند',
#  'برداری',
#  'نباید',
#  'می\u200cکنیم',
#  'نشست',
#  'سهم',
#  'همیشه',
#  'آمد',
#  'اش',
#  'وگو',
#  'می\u200cکنم',
#  'حداقل',
#  'طبق',
#  'جا',
#  'خواهد_کرد',
#  'نوعی',
#  'چگونه',
#  'رفت',
#  'هنگام',
#  'فوق',
#  'روش',
#  'ندارند',
#  'سعی',
#  'بندی',
#  'شمار',
#  'کلی',
#  'کافی',
#  'مواجه',
#  'همچنان',
#  'زیاد',
#  'سمت',
#  'کوچک',
#  'داشته_است',
#  'چیز',
#  'پشت',
#  'آورد',
#  'حالا',
#  'روبه',
#  'سال\u200cهای',
#  'دادند',
#  'می\u200cکردند',
#  'عهده',
#  'نیمه',
#  'جایی',
#  'دیگران',
#  'سی',
#  'بروز',
#  'یکدیگر',
#  'آمده_است',
#  'جز',
#  'کنم',
#  'سپس',
#  'کنندگان',
#  'خودش',
#  'همواره',
#  'یافته',
#  'شان',
#  'صرف',
#  'نمی\u200cشود',
#  'رسیدن',
#  'چهارم',
#  'یابد',
#  'متر',
#  'ساز',
#  'داشته',
#  'کرده_بود',
#  'باره',
#  'نحوه',
#  'کردم',
#  'تو',
#  'شخصی',
#  'داشته_باشند',
#  'محسوب',
#  'پخش',
#  'کمی',
#  'متفاوت',
#  'سراسر',
#  'کاملا',
#  'داشتن',
#  'نظیر',
#  'آمده',
#  'گروهی',
#  'فردی',
#  'ع',
#  'همچون',
#  'خطر',
#  'خویش',
#  'کدام',
#  'دسته',
#  'سبب',
#  'عین',
#  'آوری',
#  'متاسفانه',
#  'بیرون',
#  'دار',
#  'ابتدا',
#  'شش',
#  'افرادی',
#  'می\u200cگویند',
#  'سالهای',
#  'درون',
#  'نیستند',
#  'یافته_است',
#  'پر',
#  'خاطرنشان',
#  'گاه',
#  'جمعی',
#  'اغلب',
#  'دوباره',
#  'می\u200cیابد',
#  'لذا',
#  'زاده',
#  'گردد',
#  'اینجا']

# %%
#!pip install arabic_reshaper
#!pip install python-bidi

# %%
import arabic_reshaper
from bidi.algorithm import get_display
import re

# %%
#seperating sentence to word and removing non persian word by re moudul 
cols=['شرح مشكل']
for col in cols:
    x=[]
    for item in df[col].values:
        words=word_tokenize(item)
        w=[]
        for word in words:
                if re.search('[\u0600-\u06FF]',word):
                  w.append(word)
        x.append(w)
    df[col]=x

# %%
df
# Out:
#       شماره درخواست کد ماشین  تاریخ خرابی        وضعیت نام ماشین نوع درخواست  \
# 0          93078329      NaN     14000608  درحال بررسی       NaN        عادی
# 1          93078330      NaN     14000608  درحال بررسی       NaN        عادی
# 2          93078331      NaN     14000608  درحال بررسی       NaN        عادی
# 3          93078474      NaN     14000612  درحال بررسی       NaN        عادی
# 4          93078633      NaN     14000616  درحال بررسی       NaN        عادی
# ...             ...      ...          ...          ...       ...         ...
# 6145       93079110      NaN     14000630  درحال انجام       NaN        عادی
# 6146       93079611      NaN     14000715  پایان یافته       NaN        عادی
# 6147       93078715      NaN     14000618  پایان یافته       NaN        عادی
# 6148       93081354      NaN     14000908  پایان یافته       NaN        عادی
# 6149       93082290      NaN     14001008  پایان یافته       NaN        عادی
#
#              ق.ص. درخواست علت خرابی  مدت انجام كار  \
# 0     هیدرولیک و روانکاری       NaN              0
# 1     هیدرولیک و روانکاری       NaN              0
# 2     هیدرولیک و روانکاری       NaN              0
# 3     هیدرولیک و روانکاری       NaN              0
# 4     هیدرولیک و روانکاری       NaN              0
# ...                   ...       ...            ...
# 6145            ابزاردقیق       NaN            120
# 6146  هیدرولیک و روانکاری       NaN             60
# 6147  هیدرولیک و روانکاری       NaN             60
# 6148  هیدرولیک و روانکاری       NaN            120
# 6149  هیدرولیک و روانکاری       NaN             60
#
#                                                شرح مشكل  تاريخ شروع  \
# 0     [سیستم, گریس, بالمیل, آلارم, دارد, و, اسپری, ا...           0
# 1                  [سیستم, گریس, دیسک, یک, آلارم, دارد]           0
# 2     [نشتی, روغن, از, پمپ, مسیر, شماره, یک, هیدرولی...           0
# 3                [سیستم, گریسکاری, بالمیل, آلارم, دارد]           0
# 4     [دمای, بیرینگ, سمت, موتور, ۷۱۰, fn۴, بالاست, و...           0
# ...                                                 ...         ...
# 6145  [سنسور, نشان‌گر, موقعیت, بعضی, مواقع, گیر, میک...           0
# 6146  [لوله, گریس, پالت, ۱۵, از, طوقه, بیرونی, کنده,...           0
# 6147            [سیستم, گریس, چندین, مرتبه, تریپ, خورد]           0
# 6148          [لوله, گریس, بیرونی, پالت, ۲۶, شکسته_است]           0
# 6149                 [گریس, دستی, دیسک, ۴, جام, میباشد]           0
#
#      شرح_كد دوره توقف (واقعي ) 2 شرح_محل استقرار
# 0                         نامشخص     930BM1.xxxx
# 1                         نامشخص     610PE1.XXXX
# 2                         نامشخص          610BW8
# 3                         نامشخص     930BM1.xxxx
# 4                         نامشخص     710FN4.xxxx
# ...                          ...             ...
# 6145                توقف گرم ۱۱۰     610WB1.xxxx
# 6146                      نامشخص     730AN1.XXXX
# 6147                      نامشخص     930BM1.xxxx
# 6148                      نامشخص     730AN1.XXXX
# 6149                      نامشخص     610PE4.XXXX
#
# [6150 rows x 13 columns]

# %%
#removing stop words 

cols=['شرح مشكل']
for col in cols:
    y=[]
    for items in df[col].values:
        x=[]
        for item in items:
            if item not in stop_words:
                x.append(item)
        y.append(x)
        #print(y)
    df[col]=y
            
len(y)
# Out:
# 6150

# %%
df
# Out:
#       شماره درخواست کد ماشین  تاریخ خرابی        وضعیت نام ماشین نوع درخواست  \
# 0          93078329      NaN     14000608  درحال بررسی       NaN        عادی
# 1          93078330      NaN     14000608  درحال بررسی       NaN        عادی
# 2          93078331      NaN     14000608  درحال بررسی       NaN        عادی
# 3          93078474      NaN     14000612  درحال بررسی       NaN        عادی
# 4          93078633      NaN     14000616  درحال بررسی       NaN        عادی
# ...             ...      ...          ...          ...       ...         ...
# 6145       93079110      NaN     14000630  درحال انجام       NaN        عادی
# 6146       93079611      NaN     14000715  پایان یافته       NaN        عادی
# 6147       93078715      NaN     14000618  پایان یافته       NaN        عادی
# 6148       93081354      NaN     14000908  پایان یافته       NaN        عادی
# 6149       93082290      NaN     14001008  پایان یافته       NaN        عادی
#
#              ق.ص. درخواست علت خرابی  مدت انجام كار  \
# 0     هیدرولیک و روانکاری       NaN              0
# 1     هیدرولیک و روانکاری       NaN              0
# 2     هیدرولیک و روانکاری       NaN              0
# 3     هیدرولیک و روانکاری       NaN              0
# 4     هیدرولیک و روانکاری       NaN              0
# ...                   ...       ...            ...
# 6145            ابزاردقیق       NaN            120
# 6146  هیدرولیک و روانکاری       NaN             60
# 6147  هیدرولیک و روانکاری       NaN             60
# 6148  هیدرولیک و روانکاری       NaN            120
# 6149  هیدرولیک و روانکاری       NaN             60
#
#                                                شرح مشكل  تاريخ شروع  \
# 0     [سیستم, گریس, بالمیل, آلارم, اسپری, انجام, نمی...           0
# 1                            [سیستم, گریس, دیسک, آلارم]           0
# 2         [نشتی, روغن, پمپ, مسیر, شماره, هیدرولیک, ۶۱۰]           0
# 3                      [سیستم, گریسکاری, بالمیل, آلارم]           0
# 4     [دمای, بیرینگ, موتور, ۷۱۰, fn۴, بالاست, سطح, ر...           0
# ...                                                 ...         ...
# 6145  [سنسور, نشان‌گر, موقعیت, مواقع, گیر, میکند, ان...           0
# 6146         [لوله, گریس, پالت, ۱۵, طوقه, بیرونی, کنده]           0
# 6147            [سیستم, گریس, چندین, مرتبه, تریپ, خورد]           0
# 6148          [لوله, گریس, بیرونی, پالت, ۲۶, شکسته_است]           0
# 6149                 [گریس, دستی, دیسک, ۴, جام, میباشد]           0
#
#      شرح_كد دوره توقف (واقعي ) 2 شرح_محل استقرار
# 0                         نامشخص     930BM1.xxxx
# 1                         نامشخص     610PE1.XXXX
# 2                         نامشخص          610BW8
# 3                         نامشخص     930BM1.xxxx
# 4                         نامشخص     710FN4.xxxx
# ...                          ...             ...
# 6145                توقف گرم ۱۱۰     610WB1.xxxx
# 6146                      نامشخص     730AN1.XXXX
# 6147                      نامشخص     930BM1.xxxx
# 6148                      نامشخص     730AN1.XXXX
# 6149                      نامشخص     610PE4.XXXX
#
# [6150 rows x 13 columns]

# %%
#grouping by asset name
df2=df.groupby(['شرح_محل استقرار'], as_index = True).agg({'شرح مشكل': list})

# %%
df2
# Out:
#                                                                شرح مشكل
# شرح_محل استقرار
# 0                                           [[ماشین, مزدا, خراب, روشن]]
# 1010CA01.XXXX         [[خرابی, شیار, جرثقیل, بال, میل], [خرابی, دفور...
# 1010CA02.XXXX         [[جهت, نصب, هورن, فلاشر, جرثقیل‌های, سایت, متر...
# 1010CA03.XXXX         [[جهت, هشدار, حرکت, جرثقیل, ۱۲, تن, ساختمان, ب...
# 1010CA04.XXXX         [[طراحی, نصب, ایستگاه, محل, دسترسی, جرثقیل, سق...
# ...                                                                 ...
# INTERCOMSTATION       [[جوشکاری, ساپورت, پیجر, شمال, کوره, ساپورت, س...
# WORKSHOP.LI01         [[۲عدد, شلنگ, سرویس, بهداشتی, ساختمان, تعمیرات...
# |ER04.XXXX            [[جهت, محافظت, برق, گرفتگی, نصب, محافظ, جان, س...
# ساختمانهاي ناحيه 830  [[مرمت, کاشی, ورودی, روشوئی], [شیر, آب, ظرفشوی...
# نامشخص                [[تعویض, قفل, دستگیره, اتاق, مدیر], [درب, سروی...
#
# [905 rows x 1 columns]

# %%
#converting list in list to list
cols=['شرح مشكل']
for col in cols:
    y=[]
    for items in df2[col].values:
        y.append(sum(items,[]))
    df2[col]=y

# %%
df2
# Out:
#                                                                شرح مشكل
# شرح_محل استقرار
# 0                                             [ماشین, مزدا, خراب, روشن]
# 1010CA01.XXXX         [خرابی, شیار, جرثقیل, بال, میل, خرابی, دفورمه,...
# 1010CA02.XXXX         [جهت, نصب, هورن, فلاشر, جرثقیل‌های, سایت, متری...
# 1010CA03.XXXX         [جهت, هشدار, حرکت, جرثقیل, ۱۲, تن, ساختمان, با...
# 1010CA04.XXXX         [طراحی, نصب, ایستگاه, محل, دسترسی, جرثقیل, سقف...
# ...                                                                 ...
# INTERCOMSTATION       [جوشکاری, ساپورت, پیجر, شمال, کوره, ساپورت, سو...
# WORKSHOP.LI01         [۲عدد, شلنگ, سرویس, بهداشتی, ساختمان, تعمیرات,...
# |ER04.XXXX            [جهت, محافظت, برق, گرفتگی, نصب, محافظ, جان, سو...
# ساختمانهاي ناحيه 830  [مرمت, کاشی, ورودی, روشوئی, شیر, آب, ظرفشویی, ...
# نامشخص                [تعویض, قفل, دستگیره, اتاق, مدیر, درب, سرویس, ...
#
# [905 rows x 1 columns]

# %%
#removing dublicat words in list when we change list to dictunary 
cols=['شرح مشكل']
for col in cols:
    y=[]
    for items in df2[col].values:
        y.append(list(dict.fromkeys(items)))
    df2[col]=y

# %%
df2
# Out:
#                                                                شرح مشكل
# شرح_محل استقرار
# 0                                             [ماشین, مزدا, خراب, روشن]
# 1010CA01.XXXX         [خرابی, شیار, جرثقیل, بال, میل, دفورمه, ورقهای...
# 1010CA02.XXXX         [جهت, نصب, هورن, فلاشر, جرثقیل‌های, سایت, متری...
# 1010CA03.XXXX         [جهت, هشدار, حرکت, جرثقیل, ۱۲, تن, ساختمان, با...
# 1010CA04.XXXX         [طراحی, نصب, ایستگاه, محل, دسترسی, جرثقیل, سقف...
# ...                                                                 ...
# INTERCOMSTATION       [جوشکاری, ساپورت, پیجر, شمال, کوره, سوکت, فاز,...
# WORKSHOP.LI01         [۲عدد, شلنگ, سرویس, بهداشتی, ساختمان, تعمیرات,...
# |ER04.XXXX            [جهت, محافظت, برق, گرفتگی, نصب, محافظ, جان, سو...
# ساختمانهاي ناحيه 830  [مرمت, کاشی, ورودی, روشوئی, شیر, آب, ظرفشویی, ...
# نامشخص                [تعویض, قفل, دستگیره, اتاق, مدیر, درب, سرویس, ...
#
# [905 rows x 1 columns]

# %%
#translate to english

# %%
import requests
from bs4 import BeautifulSoup
from time import sleep

# %%
def abadis(word):
    try:
        url='https://abadis.ir/fatoen/'+word+'/'
        page = requests.get(url)
        soup = BeautifulSoup(page.text,'html.parser')
        resoults=soup.find_all("l",)[0].contents
        return resoults
    except:
        return ['نتیجه نداشت']

# %%
df2['شرح مشكل'].values[0:3]
# Out:
# array([list(['ماشین', 'مزدا', 'خراب', 'روشن']),
#        list(['خرابی', 'شیار', 'جرثقیل', 'بال', 'میل', 'دفورمه', 'ورقهای', 'درام', 'دفرمه', 'PLATE\u200cهای', 'تعویض', 'قرقره', 'کابل', 'دلیل', 'سایش']),
#        list(['جهت', 'نصب', 'هورن', 'فلاشر', 'جرثقیل\u200cهای', 'سایت', 'متریال', 'میباشد', 'هشدار', 'حرکت', 'جرثقیل', '۳۰', 'تن', 'ساختمان', 'بالینگ', 'داربست', 'مخزن', 'آب', 'اتاق', 'کنترل', 'تعمیر', 'سیم', 'بکسل', 'خراب', 'ونیاز', 'تعویض', 'بستن', 'اسکافلد', 'پل', 'دسترسی', 'سیستم', 'برق', 'ورودی', 'رفع', 'عیب', 'کابل', 'تابلو', 'اسکافولد', 'عملکرد\u200cهای'])],
#       dtype=object)

# %%
cols=['شرح مشكل']
for col in cols:
    y=[]
    for items in df2[col].values[0:2]:
        print(items)
        z={}
        for item in items:
            print(item)
            z[item]= abadis(item)[0]
            sleep(1)
            print(z)
        y.append(z)
    print('y=',y)
# Out:
# ['ماشین', 'مزدا', 'خراب', 'روشن']
# ماشین
# {'ماشین': 'contraption'}
# مزدا
# {'ماشین': 'contraption', 'مزدا': 'نتیجه نداشت'}
# خراب
# {'ماشین': 'contraption', 'مزدا': 'نتیجه نداشت', 'خراب': 'foul'}
# روشن
# {'ماشین': 'contraption', 'مزدا': 'نتیجه نداشت', 'خراب': 'foul', 'روشن': 'well-defined'}
# ['خرابی', 'شیار', 'جرثقیل', 'بال', 'میل', 'دفورمه', 'ورقهای', 'درام', 'دفرمه', 'PLATE\u200cهای', 'تعویض', 'قرقره', 'کابل', 'دلیل', 'سایش']
# خرابی
# {'خرابی': 'ruined condition'}
# شیار
# {'خرابی': 'ruined condition', 'شیار': 'corrugation'}
# جرثقیل
# {'خرابی': 'ruined condition', 'شیار': 'corrugation', 'جرثقیل': 'crane'}
# بال
# {'خرابی': 'ruined condition', 'شیار': 'corrugation', 'جرثقیل': 'crane', 'بال': 'wing'}
# میل
# {'خرابی': 'ruined condition', 'شیار': 'corrugation', 'جرثقیل': 'crane', 'بال': 'wing', 'میل': 'rob'}
# دفورمه
# {'خرابی': 'ruined condition', 'شیار': 'corrugation', 'جرثقیل': 'crane', 'بال': 'wing', 'میل': 'rob', 'دفورمه': 'نتیجه نداشت'}
# ورقهای
# {'خرابی': 'ruined condition', 'شیار': 'corrugation', 'جرثقیل': 'crane', 'بال': 'wing', 'میل': 'rob', 'دفورمه': 'نتیجه نداشت', 'ورقهای': 'نتیجه نداشت'}
# درام
# {'خرابی': 'ruined condition', 'شیار': 'corrugation', 'جرثقیل': 'crane', 'بال': 'wing', 'میل': 'rob', 'دفورمه': 'نتیجه نداشت', 'ورقهای': 'نتیجه نداشت', 'درام': 'drama'}
# دفرمه
# {'خرابی': 'ruined condition', 'شیار': 'corrugation', 'جرثقیل': 'crane', 'بال': 'wing', 'میل': 'rob', 'دفورمه': 'نتیجه نداشت', 'ورقهای': 'نتیجه نداشت', 'درام': 'drama', 'دفرمه': 'نتیجه نداشت'}
# PLATE‌های
# {'خرابی': 'ruined condition', 'شیار': 'corrugation', 'جرثقیل': 'crane', 'بال': 'wing', 'میل': 'rob', 'دفورمه': 'نتیجه نداشت', 'ورقهای': 'نتیجه نداشت', 'درام': 'drama', 'دفرمه': 'نتیجه نداشت', 'PLATE\u200cهای': 'نتیجه نداشت'}
# تعویض
# {'خرابی': 'ruined condition', 'شیار': 'corrugation', 'جرثقیل': 'crane', 'بال': 'wing', 'میل': 'rob', 'دفورمه': 'نتیجه نداشت', 'ورقهای': 'نتیجه نداشت', 'درام': 'drama', 'دفرمه': 'نتیجه نداشت', 'PLATE\u200cهای': 'نتیجه نداشت', 'تعویض': 'alteration'}
# قرقره
# {'خرابی': 'ruined condition', 'شیار': 'corrugation', 'جرثقیل': 'crane', 'بال': 'wing', 'میل': 'rob', 'دفورمه': 'نتیجه نداشت', 'ورقهای': 'نتیجه نداشت', 'درام': 'drama', 'دفرمه': 'نتیجه نداشت', 'PLATE\u200cهای': 'نتیجه نداشت', 'تعویض': 'alteration', 'قرقره': 'spool'}
# کابل
# {'خرابی': 'ruined condition', 'شیار': 'corrugation', 'جرثقیل': 'crane', 'بال': 'wing', 'میل': 'rob', 'دفورمه': 'نتیجه نداشت', 'ورقهای': 'نتیجه نداشت', 'درام': 'drama', 'دفرمه': 'نتیجه نداشت', 'PLATE\u200cهای': 'نتیجه نداشت', 'تعویض': 'alteration', 'قرقره': 'spool', 'کابل': 'kabul'}
# دلیل
# {'خرابی': 'ruined condition', 'شیار': 'corrugation', 'جرثقیل': 'crane', 'بال': 'wing', 'میل': 'rob', 'دفورمه': 'نتیجه نداشت', 'ورقهای': 'نتیجه نداشت', 'درام': 'drama', 'دفرمه': 'نتیجه نداشت', 'PLATE\u200cهای': 'نتیجه نداشت', 'تعویض': 'alteration', 'قرقره': 'spool', 'کابل': 'kabul', 'دلیل': 'account'}
# سایش
# {'خرابی': 'ruined condition', 'شیار': 'corrugation', 'جرثقیل': 'crane', 'بال': 'wing', 'میل': 'rob', 'دفورمه': 'نتیجه نداشت', 'ورقهای': 'نتیجه نداشت', 'درام': 'drama', 'دفرمه': 'نتیجه نداشت', 'PLATE\u200cهای': 'نتیجه نداشت', 'تعویض': 'alteration', 'قرقره': 'spool', 'کابل': 'kabul', 'دلیل': 'account', 'سایش': 'abrasion'}
# y= [{'ماشین': 'contraption', 'مزدا': 'نتیجه نداشت', 'خراب': 'foul', 'روشن': 'well-defined'}, {'خرابی': 'ruined condition', 'شیار': 'corrugation', 'جرثقیل': 'crane', 'بال': 'wing', 'میل': 'rob', 'دفورمه': 'نتیجه نداشت', 'ورقهای': 'نتیجه نداشت', 'درام': 'drama', 'دفرمه': 'نتیجه نداشت', 'PLATE\u200cهای': 'نتیجه نداشت', 'تعویض': 'alteration', 'قرقره': 'spool', 'کابل': 'kabul', 'دلیل': 'account', 'سایش': 'abrasion'}]

# %%
len(y)
# Out:
# 2

# %%
stemmer = Stemmer()
lemmatizer = Lemmatizer()
normalizer = Normalizer()

# %%
for token in df3.iloc[:,1]:
    #token = normalizer.normalize(token)
    print("stem" + "-> "+ stemmer.stem(token))
    print("lemma" + "-> "+lemmatizer.lemmatize(token))
    print("\n")
