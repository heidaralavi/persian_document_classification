# %%
import nltk
#nltk.download()
from __future__ import unicode_literals
from hazm import *
import re

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
#importing data from file
df=pd.read_excel('failure_description.xlsx')

# %%
df.iloc[:,1][0]
# Out:
# 'بازوهای بیرونی شماره21و6 گریسکاری نمیشود'

# %%
def remove_eng(x):
    return re.sub('[0-9a-zA-Z]',' ',x)

# %%
df['Problem_Description'] = df.iloc[:,1].map(lambda x: remove_eng(x))

# %%
df
# Out:
#       Cause_of_failure                                Problem_Description
# 0                  NaN           بازوهای بیرونی شماره  و  گریسکاری نمیشود
# 1                  NaN                    نازل های اب روی تجهیز گرفته است
# 2                  NaN                                تجهیز الارم    دارد
# 3                  NaN  دستگاه گلس بید یکی از عملکرد های ان در هنگام ک...
# 4                  NaN                    دستگاه گلاس بید  استارت نمیشود.
# ...                ...                                                ...
# 59388              NaN              بالا رفتن دمای یاتاقان پنیون بال میل.
# 59389              NaN          نیاز به نصب داربست در اطراف بدنه بال میل.
# 59390             سایش                                     شل بودن وی بلت
# 59391              NaN  درخواست ساخت و تعویض داکت های ماقبل و بعد از ن...
# 59392              NaN  دیسکانکت وکانکت سنسور هیدروکوپلینگ در اولین شا...
#
# [59393 rows x 2 columns]

# %%
normalizer = Normalizer(token_based=True)
def norm(x):
    return normalizer.normalize(x)

# %%
norm(df.iloc[:,1][0])
# Out:
# 'بازوهای بیرونی شماره و گریسکاری نمیشود'

# %%
df['Normalized_description'] = df.iloc[:,1].map(lambda x: norm(x))

# %%
df
# Out:
#       Cause_of_failure                                Problem_Description  \
# 0                  NaN           بازوهای بیرونی شماره  و  گریسکاری نمیشود
# 1                  NaN                    نازل های اب روی تجهیز گرفته است
# 2                  NaN                                تجهیز الارم    دارد
# 3                  NaN  دستگاه گلس بید یکی از عملکرد های ان در هنگام ک...
# 4                  NaN                    دستگاه گلاس بید  استارت نمیشود.
# ...                ...                                                ...
# 59388              NaN              بالا رفتن دمای یاتاقان پنیون بال میل.
# 59389              NaN          نیاز به نصب داربست در اطراف بدنه بال میل.
# 59390             سایش                                     شل بودن وی بلت
# 59391              NaN  درخواست ساخت و تعویض داکت های ماقبل و بعد از ن...
# 59392              NaN  دیسکانکت وکانکت سنسور هیدروکوپلینگ در اولین شا...
#
#                                   Normalized_description
# 0                 بازوهای بیرونی شماره و گریسکاری نمیشود
# 1                        نازل‌های اب روی تجهیز گرفته است
# 2                                       تجهیز الارم دارد
# 3      دستگاه گلس بید یکی از عملکرد‌های ان در هنگام ک...
# 4                         دستگاه گلاس بید استارت نمیشود.
# ...                                                  ...
# 59388              بالا رفتن دمای یاتاقان پنیون بال میل.
# 59389          نیاز به نصب داربست در اطراف بدنه بال میل.
# 59390                                     شل بودن وی بلت
# 59391  درخواست ساخت و تعویض داکت‌های ماقبل و بعد از ن...
# 59392  دیسکانکت وکانکت سنسور هیدروکوپلینگ در اولین شا...
#
# [59393 rows x 3 columns]

# %%
def word_tok(x):
    return word_tokenize(x)
df['word_tokenize'] = df.iloc[:,2].map(lambda x: word_tok(x))

# %%
df.iloc[:,3][0]
# Out:
# ['بازوهای', 'بیرونی', 'شماره', 'و', 'گریسکاری', 'نمیشود']

# %%
def remove_space(x):
    remove_space = [item.strip() for item in x]
    delete_empty = [item for item in remove_space if item.strip()]
    return delete_empty
    
df['removed_space'] = df.iloc[:,3].map(lambda x: remove_space(x))

# %%
a=[' یتبنیمشس سینش  ','','نسشیت    ']
print(a)
remove_space(a)
# Out:
# [' یتبنیمشس سینش  ', '', 'نسشیت    ']
# ['یتبنیمشس سینش', 'نسشیت']

# %%
stop_words_df=pd.read_excel('stop_words.xlsx')
stop_words = stop_words_df.iloc[:,0].to_list()
def remove_stopwords(x):
    output=[]
    for item in x:
        if item not in stop_words:
            output.append(item)
    return output

# %%
df['removed_stopwords'] = df.iloc[:,4].map(lambda x: remove_stopwords(x))

# %%
df.head(50)
# Out:
#    Cause_of_failure                                Problem_Description  \
# 0               NaN           بازوهای بیرونی شماره  و  گریسکاری نمیشود
# 1               NaN                    نازل های اب روی تجهیز گرفته است
# 2               NaN                                تجهیز الارم    دارد
# 3               NaN  دستگاه گلس بید یکی از عملکرد های ان در هنگام ک...
# 4               NaN                    دستگاه گلاس بید  استارت نمیشود.
# 5            شکستگی          یکی از شفتهای برگشتی پشت ستون   شکسته است
# 6               NaN  صدایی غیر عادی از موقعیت تانژانت و پینیون کوره...
# 7               NaN  پیچ های ریل داخلی کولینگ حدفاصل   و   و   و شل...
# 8               NaN                     زانویی خروجی پمپ سوراخ شده است
# 9               NaN                    برزنت متصل به استک پاره می باشد
# 10              NaN                   پله مربوط به بازدید مش شکسته است
# 11              NaN  ورقی که زیر گریتینگ انتهای بلت جهت جلوگیری از ...
# 12              NaN                            جک بالایی نشتی باد دارد
# 13        عدم تنظیم                تعمیر     ,  ,  , سمت جنوب انجام شد
# 14              NaN                         نیاز به تاب گیری مجدد دارد
# 15              NaN                        نازل های واش باکس گرفته است
# 16              NaN                        نازل های واش باکس گرفته است
# 17              NaN                                      الارم کاذب
# 18              NaN                      افزایش ناگهانی ویبره(بارندگی)
# 19           انحراف                         رفع انحراف نوار.(انجام شد)
# 20              NaN  با توجه به سایش زیاد ورق نصب شده بر روی مش اول...
# 21              NaN  نصف کردن   عدد از مش های سایز   میلیمتر اسکرین...
# 22              NaN                                        الارم  دارد
# 23              NaN                        نازل های واش باکس گرفته است
# 24    عیب هیدرولیکی  الارم تجهیز به دلیل کاهش فشار پمپ گریس اتفاق ا...
# 25              NaN                     بیرینگ سمت خلاف موتور خراب است
# 26              NaN  برشکاری و ساخت محفظه  جهت نصب               در...
# 27              NaN                             سایش شفت درام تیل ائند
# 28              NaN                          تخته کلمپ موتور شکسته است
# 29              NaN  نشتی روغن پرشر پلیت بر روی شفت شماره    شمال ا...
# 30              NaN  ترمینال روغن روی ستون   جنوب و مابین شافت    و...
# 31              NaN                            دوربین کوره تصویر ندارد
# 32              NaN          ریترن سلف الایمنت کنار بین یک سایدگی دارد
# 33           شکستگی        یکی از پایپهای سمت جنوب چکش ثابت افتاده است
# 34              NaN                         سیم بکسل جرثقیل مشکل دارد.
# 35           انحراف                         رفع انحراف نوار.(انجام شد)
# 36              NaN                          دمپر دچار خوردگی شده است.
# 37              NaN                          میزان اب غبار گیر کم است.
# 38              NaN  دیسکانکشن و کانکشن مجدد        جهت بازدید از ا...
# 39              NaN                    موتور تجهیز مرتب          میشود
# 40              NaN            پارگی زنجیر اسپراکت مربوط به نوار خوراک
# 41              NaN                 اتصالات گریس رول   و   باز می باشد
# 42              NaN          جک ایرلاک فیدر بالایی مجددا نشتی هوا دارد
# 43              NaN           شارژ روغن کاور زنجیر سمت شمال.(انجام شد)
# 44              NaN                ولو اب مربوط به شستشوی مش نشتی دارد
# 45              NaN                        دمای روغن بالا است(   درجه)
# 46              NaN  تعویض شیر گازی مربوط به اب کولر اتاق دیزل به د...
# 47              NaN  جهت نصب پمپ تقویت فشار اب، مربوط به سیل واتر ف...
# 48              NaN                   کلیه نازلهای سر دیسکها گرفته است
# 49              NaN                            نازل واش باکس گرفته است
#
#                                Normalized_description  \
# 0              بازوهای بیرونی شماره و گریسکاری نمیشود
# 1                     نازل‌های اب روی تجهیز گرفته است
# 2                                    تجهیز الارم دارد
# 3   دستگاه گلس بید یکی از عملکرد‌های ان در هنگام ک...
# 4                      دستگاه گلاس بید استارت نمیشود.
# 5             یکی از شفتهای برگشتی پشت ستون شکسته است
# 6   صدایی غیر عادی از موقعیت تانژانت و پینیون کوره...
# 7    پیچ‌های ریل داخلی کولینگ حدفاصل و و و شل شده است
# 8                      زانویی خروجی پمپ سوراخ شده است
# 9                     برزنت متصل به استک پاره می‌باشد
# 10                   پله مربوط به بازدید مش شکسته است
# 11  ورقی که زیر گریتینگ انتهای بلت جهت جلوگیری از ...
# 12                            جک بالایی نشتی باد دارد
# 13                      تعمیر , , , سمت جنوب انجام شد
# 14                         نیاز به تاب گیری مجدد دارد
# 15                        نازل‌های واش باکس گرفته است
# 16                        نازل‌های واش باکس گرفته است
# 17                                         الارم کاذب
# 18                     افزایش ناگهانی ویبره (بارندگی)
# 19                        رفع انحراف نوار. (انجام شد)
# 20  با توجه به سایش زیاد ورق نصب‌شده بر روی مش اول...
# 21  نصف کردن عدد از مش‌های سایز میلیمتر اسکرین و ن...
# 22                                         الارم دارد
# 23                        نازل‌های واش باکس گرفته است
# 24  الارم تجهیز به دلیل کاهش فشار پمپ گریس اتفاق ا...
# 25                     بیرینگ سمت خلاف موتور خراب است
# 26  برشکاری و ساخت محفظه جهت نصب در موقعیت جدید (ه...
# 27                             سایش شفت درام تیل ائند
# 28                          تخته کلمپ موتور شکسته است
# 29  نشتی روغن پرشر پلیت بر روی شفت شماره شمال از ط...
# 30  ترمینال روغن روی ستون جنوب و مابین شافت و نشتی...
# 31                            دوربین کوره تصویر ندارد
# 32          ریترن سلف الایمنت کنار بین یک سایدگی دارد
# 33        یکی از پایپهای سمت جنوب چکش ثابت افتاده است
# 34                         سیم‌بکسل جرثقیل مشکل دارد.
# 35                        رفع انحراف نوار. (انجام شد)
# 36                          دمپر دچار خوردگی شده است.
# 37                          میزان اب غبار گیر کم است.
# 38  دیسکانکشن و کانکشن مجدد جهت بازدید از ایمپلر ت...
# 39                             موتور تجهیز مرتب میشود
# 40            پارگی زنجیر اسپراکت مربوط به نوار خوراک
# 41                     اتصالات گریس رول و باز می‌باشد
# 42          جک ایرلاک فیدر بالایی مجددا نشتی هوا دارد
# 43          شارژ روغن کاور زنجیر سمت شمال. (انجام شد)
# 44                ولو اب مربوط به شستشوی مش نشتی دارد
# 45                          دمای روغن بالا است (درجه)
# 46  تعویض شیر گازی مربوط به اب کولر اتاق دیزل به د...
# 47  جهت نصب پمپ تقویت فشار اب، مربوط به سیل واتر ف...
# 48                   کلیه نازلهای سر دیسکها گرفته است
# 49                            نازل واش باکس گرفته است
#
#                                         word_tokenize  \
# 0       [بازوهای, بیرونی, شماره, و, گریسکاری, نمیشود]
# 1               [نازل‌های, اب, روی, تجهیز, گرفته_است]
# 2                                [تجهیز, الارم, دارد]
# 3   [دستگاه, گلس, بید, یکی, از, عملکرد‌های, ان, در...
# 4              [دستگاه, گلاس, بید, استارت, نمیشود, .]
# 5     [یکی, از, شفتهای, برگشتی, پشت, ستون, شکسته_است]
# 6   [صدایی, غیر, عادی, از, موقعیت, تانژانت, و, پین...
# 7   [پیچ‌های, ریل, داخلی, کولینگ, حدفاصل, و, و, و,...
# 8                [زانویی, خروجی, پمپ, سوراخ, شده_است]
# 9              [برزنت, متصل, به, استک, پاره, می‌باشد]
# 10            [پله, مربوط, به, بازدید, مش, شکسته_است]
# 11  [ورقی, که, زیر, گریتینگ, انتهای, بلت, جهت, جلو...
# 12                      [جک, بالایی, نشتی, باد, دارد]
# 13             [تعمیر, ,, ,, ,, سمت, جنوب, انجام, شد]
# 14                  [نیاز, به, تاب, گیری, مجدد, دارد]
# 15                   [نازل‌های, واش, باکس, گرفته_است]
# 16                   [نازل‌های, واش, باکس, گرفته_است]
# 17                                      [الارم, کاذب]
# 18            [افزایش, ناگهانی, ویبره, (, بارندگی, )]
# 19            [رفع, انحراف, نوار, ., (, انجام, شد, )]
# 20  [با, توجه, به, سایش, زیاد, ورق, نصب‌شده, بر, ر...
# 21  [نصف, کردن, عدد, از, مش‌های, سایز, میلیمتر, اس...
# 22                                      [الارم, دارد]
# 23                   [نازل‌های, واش, باکس, گرفته_است]
# 24  [الارم, تجهیز, به, دلیل, کاهش, فشار, پمپ, گریس...
# 25              [بیرینگ, سمت, خلاف, موتور, خراب, است]
# 26  [برشکاری, و, ساخت, محفظه, جهت, نصب, در, موقعیت...
# 27                       [سایش, شفت, درام, تیل, ائند]
# 28                     [تخته, کلمپ, موتور, شکسته_است]
# 29  [نشتی, روغن, پرشر, پلیت, بر, روی, شفت, شماره, ...
# 30  [ترمینال, روغن, روی, ستون, جنوب, و, مابین, شاف...
# 31                       [دوربین, کوره, تصویر, ندارد]
# 32  [ریترن, سلف, الایمنت, کنار, بین, یک, سایدگی, د...
# 33  [یکی, از, پایپهای, سمت, جنوب, چکش, ثابت, افتاد...
# 34                  [سیم‌بکسل, جرثقیل, مشکل, دارد, .]
# 35            [رفع, انحراف, نوار, ., (, انجام, شد, )]
# 36                   [دمپر, دچار, خوردگی, شده_است, .]
# 37                 [میزان, اب, غبار, گیر, کم, است, .]
# 38  [دیسکانکشن, و, کانکشن, مجدد, جهت, بازدید, از, ...
# 39                        [موتور, تجهیز, مرتب, میشود]
# 40    [پارگی, زنجیر, اسپراکت, مربوط, به, نوار, خوراک]
# 41              [اتصالات, گریس, رول, و, باز, می‌باشد]
# 42  [جک, ایرلاک, فیدر, بالایی, مجددا, نشتی, هوا, د...
# 43  [شارژ, روغن, کاور, زنجیر, سمت, شمال, ., (, انج...
# 44       [ولو, اب, مربوط, به, شستشوی, مش, نشتی, دارد]
# 45                [دمای, روغن, بالا, است, (, درجه, )]
# 46  [تعویض, شیر, گازی, مربوط, به, اب, کولر, اتاق, ...
# 47  [جهت, نصب, پمپ, تقویت, فشار, اب, ،, مربوط, به,...
# 48             [کلیه, نازلهای, سر, دیسکها, گرفته_است]
# 49                       [نازل, واش, باکس, گرفته_است]
#
#                                         removed_space  \
# 0       [بازوهای, بیرونی, شماره, و, گریسکاری, نمیشود]
# 1               [نازل‌های, اب, روی, تجهیز, گرفته_است]
# 2                                [تجهیز, الارم, دارد]
# 3   [دستگاه, گلس, بید, یکی, از, عملکرد‌های, ان, در...
# 4              [دستگاه, گلاس, بید, استارت, نمیشود, .]
# 5     [یکی, از, شفتهای, برگشتی, پشت, ستون, شکسته_است]
# 6   [صدایی, غیر, عادی, از, موقعیت, تانژانت, و, پین...
# 7   [پیچ‌های, ریل, داخلی, کولینگ, حدفاصل, و, و, و,...
# 8                [زانویی, خروجی, پمپ, سوراخ, شده_است]
# 9              [برزنت, متصل, به, استک, پاره, می‌باشد]
# 10            [پله, مربوط, به, بازدید, مش, شکسته_است]
# 11  [ورقی, که, زیر, گریتینگ, انتهای, بلت, جهت, جلو...
# 12                      [جک, بالایی, نشتی, باد, دارد]
# 13             [تعمیر, ,, ,, ,, سمت, جنوب, انجام, شد]
# 14                  [نیاز, به, تاب, گیری, مجدد, دارد]
# 15                   [نازل‌های, واش, باکس, گرفته_است]
# 16                   [نازل‌های, واش, باکس, گرفته_است]
# 17                                      [الارم, کاذب]
# 18            [افزایش, ناگهانی, ویبره, (, بارندگی, )]
# 19            [رفع, انحراف, نوار, ., (, انجام, شد, )]
# 20  [با, توجه, به, سایش, زیاد, ورق, نصب‌شده, بر, ر...
# 21  [نصف, کردن, عدد, از, مش‌های, سایز, میلیمتر, اس...
# 22                                      [الارم, دارد]
# 23                   [نازل‌های, واش, باکس, گرفته_است]
# 24  [الارم, تجهیز, به, دلیل, کاهش, فشار, پمپ, گریس...
# 25              [بیرینگ, سمت, خلاف, موتور, خراب, است]
# 26  [برشکاری, و, ساخت, محفظه, جهت, نصب, در, موقعیت...
# 27                       [سایش, شفت, درام, تیل, ائند]
# 28                     [تخته, کلمپ, موتور, شکسته_است]
# 29  [نشتی, روغن, پرشر, پلیت, بر, روی, شفت, شماره, ...
# 30  [ترمینال, روغن, روی, ستون, جنوب, و, مابین, شاف...
# 31                       [دوربین, کوره, تصویر, ندارد]
# 32  [ریترن, سلف, الایمنت, کنار, بین, یک, سایدگی, د...
# 33  [یکی, از, پایپهای, سمت, جنوب, چکش, ثابت, افتاد...
# 34                  [سیم‌بکسل, جرثقیل, مشکل, دارد, .]
# 35            [رفع, انحراف, نوار, ., (, انجام, شد, )]
# 36                   [دمپر, دچار, خوردگی, شده_است, .]
# 37                 [میزان, اب, غبار, گیر, کم, است, .]
# 38  [دیسکانکشن, و, کانکشن, مجدد, جهت, بازدید, از, ...
# 39                        [موتور, تجهیز, مرتب, میشود]
# 40    [پارگی, زنجیر, اسپراکت, مربوط, به, نوار, خوراک]
# 41              [اتصالات, گریس, رول, و, باز, می‌باشد]
# 42  [جک, ایرلاک, فیدر, بالایی, مجددا, نشتی, هوا, د...
# 43  [شارژ, روغن, کاور, زنجیر, سمت, شمال, ., (, انج...
# 44       [ولو, اب, مربوط, به, شستشوی, مش, نشتی, دارد]
# 45                [دمای, روغن, بالا, است, (, درجه, )]
# 46  [تعویض, شیر, گازی, مربوط, به, اب, کولر, اتاق, ...
# 47  [جهت, نصب, پمپ, تقویت, فشار, اب, ،, مربوط, به,...
# 48             [کلیه, نازلهای, سر, دیسکها, گرفته_است]
# 49                       [نازل, واش, باکس, گرفته_است]
#
#                                     removed_stopwords
# 0          [بازوهای, بیرونی, شماره, گریسکاری, نمیشود]
# 1                               [نازل‌های, اب, تجهیز]
# 2                                      [تجهیز, الارم]
# 3           [دستگاه, گلس, بید, عملکرد‌های, کار, فعال]
# 4                 [دستگاه, گلاس, بید, استارت, نمیشود]
# 5                   [شفتهای, برگشتی, ستون, شکسته_است]
# 6   [صدایی, عادی, موقعیت, تانژانت, پینیون, کوره, م...
# 7           [پیچ‌های, ریل, داخلی, کولینگ, حدفاصل, شل]
# 8                         [زانویی, خروجی, پمپ, سوراخ]
# 9                           [برزنت, متصل, استک, پاره]
# 10                       [پله, بازدید, مش, شکسته_است]
# 11  [ورقی, گریتینگ, انتهای, بلت, جهت, جلوگیری, ریز...
# 12                            [جک, بالایی, نشتی, باد]
# 13                               [تعمیر, جنوب, انجام]
# 14                                        [تاب, مجدد]
# 15                              [نازل‌های, واش, باکس]
# 16                              [نازل‌های, واش, باکس]
# 17                                      [الارم, کاذب]
# 18                  [افزایش, ناگهانی, ویبره, بارندگی]
# 19                         [رفع, انحراف, نوار, انجام]
# 20  [توجه, سایش, ورق, نصب‌شده, مش, اولی, اماده, مت...
# 21  [نصف, عدد, مش‌های, سایز, میلیمتر, اسکرین, نصب,...
# 22                                            [الارم]
# 23                              [نازل‌های, واش, باکس]
# 24  [الارم, تجهیز, دلیل, کاهش, فشار, پمپ, گریس, ات...
# 25                        [بیرینگ, خلاف, موتور, خراب]
# 26  [برشکاری, ساخت, محفظه, جهت, نصب, موقعیت, هماهن...
# 27                       [سایش, شفت, درام, تیل, ائند]
# 28                     [تخته, کلمپ, موتور, شکسته_است]
# 29  [نشتی, روغن, پرشر, پلیت, شفت, شماره, شمال, بال...
# 30  [ترمینال, روغن, ستون, جنوب, مابین, شافت, نشتی,...
# 31                              [دوربین, کوره, تصویر]
# 32                      [ریترن, سلف, الایمنت, سایدگی]
# 33             [پایپهای, جنوب, چکش, ثابت, افتاده_است]
# 34                           [سیم‌بکسل, جرثقیل, مشکل]
# 35                         [رفع, انحراف, نوار, انجام]
# 36                                     [دمپر, خوردگی]
# 37                             [میزان, اب, غبار, گیر]
# 38  [دیسکانکشن, کانکشن, مجدد, جهت, بازدید, ایمپلر,...
# 39                        [موتور, تجهیز, مرتب, میشود]
# 40               [پارگی, زنجیر, اسپراکت, نوار, خوراک]
# 41                               [اتصالات, گریس, رول]
# 42       [جک, ایرلاک, فیدر, بالایی, مجددا, نشتی, هوا]
# 43             [شارژ, روغن, کاور, زنجیر, شمال, انجام]
# 44                        [ولو, اب, شستشوی, مش, نشتی]
# 45                                 [دمای, روغن, درجه]
# 46  [تعویض, شیر, گازی, اب, کولر, اتاق, دیزل, دلیل,...
# 47  [جهت, نصب, پمپ, تقویت, فشار, اب, سیل, واتر, فی...
# 48                        [کلیه, نازلهای, سر, دیسکها]
# 49                                  [نازل, واش, باکس]

# %%
stemmer = Stemmer()
def stem(x):
    output=[]
    for item in x:
        output.append(stemmer.stem(item))
    return output

# %%
df['stem'] = df.iloc[:,5].map(lambda x: stem(x))

# %%
df.head(50)
# Out:
#    Cause_of_failure                                Problem_Description  \
# 0               NaN           بازوهای بیرونی شماره  و  گریسکاری نمیشود
# 1               NaN                    نازل های اب روی تجهیز گرفته است
# 2               NaN                                تجهیز الارم    دارد
# 3               NaN  دستگاه گلس بید یکی از عملکرد های ان در هنگام ک...
# 4               NaN                    دستگاه گلاس بید  استارت نمیشود.
# 5            شکستگی          یکی از شفتهای برگشتی پشت ستون   شکسته است
# 6               NaN  صدایی غیر عادی از موقعیت تانژانت و پینیون کوره...
# 7               NaN  پیچ های ریل داخلی کولینگ حدفاصل   و   و   و شل...
# 8               NaN                     زانویی خروجی پمپ سوراخ شده است
# 9               NaN                    برزنت متصل به استک پاره می باشد
# 10              NaN                   پله مربوط به بازدید مش شکسته است
# 11              NaN  ورقی که زیر گریتینگ انتهای بلت جهت جلوگیری از ...
# 12              NaN                            جک بالایی نشتی باد دارد
# 13        عدم تنظیم                تعمیر     ,  ,  , سمت جنوب انجام شد
# 14              NaN                         نیاز به تاب گیری مجدد دارد
# 15              NaN                        نازل های واش باکس گرفته است
# 16              NaN                        نازل های واش باکس گرفته است
# 17              NaN                                      الارم کاذب
# 18              NaN                      افزایش ناگهانی ویبره(بارندگی)
# 19           انحراف                         رفع انحراف نوار.(انجام شد)
# 20              NaN  با توجه به سایش زیاد ورق نصب شده بر روی مش اول...
# 21              NaN  نصف کردن   عدد از مش های سایز   میلیمتر اسکرین...
# 22              NaN                                        الارم  دارد
# 23              NaN                        نازل های واش باکس گرفته است
# 24    عیب هیدرولیکی  الارم تجهیز به دلیل کاهش فشار پمپ گریس اتفاق ا...
# 25              NaN                     بیرینگ سمت خلاف موتور خراب است
# 26              NaN  برشکاری و ساخت محفظه  جهت نصب               در...
# 27              NaN                             سایش شفت درام تیل ائند
# 28              NaN                          تخته کلمپ موتور شکسته است
# 29              NaN  نشتی روغن پرشر پلیت بر روی شفت شماره    شمال ا...
# 30              NaN  ترمینال روغن روی ستون   جنوب و مابین شافت    و...
# 31              NaN                            دوربین کوره تصویر ندارد
# 32              NaN          ریترن سلف الایمنت کنار بین یک سایدگی دارد
# 33           شکستگی        یکی از پایپهای سمت جنوب چکش ثابت افتاده است
# 34              NaN                         سیم بکسل جرثقیل مشکل دارد.
# 35           انحراف                         رفع انحراف نوار.(انجام شد)
# 36              NaN                          دمپر دچار خوردگی شده است.
# 37              NaN                          میزان اب غبار گیر کم است.
# 38              NaN  دیسکانکشن و کانکشن مجدد        جهت بازدید از ا...
# 39              NaN                    موتور تجهیز مرتب          میشود
# 40              NaN            پارگی زنجیر اسپراکت مربوط به نوار خوراک
# 41              NaN                 اتصالات گریس رول   و   باز می باشد
# 42              NaN          جک ایرلاک فیدر بالایی مجددا نشتی هوا دارد
# 43              NaN           شارژ روغن کاور زنجیر سمت شمال.(انجام شد)
# 44              NaN                ولو اب مربوط به شستشوی مش نشتی دارد
# 45              NaN                        دمای روغن بالا است(   درجه)
# 46              NaN  تعویض شیر گازی مربوط به اب کولر اتاق دیزل به د...
# 47              NaN  جهت نصب پمپ تقویت فشار اب، مربوط به سیل واتر ف...
# 48              NaN                   کلیه نازلهای سر دیسکها گرفته است
# 49              NaN                            نازل واش باکس گرفته است
#
#                                Normalized_description  \
# 0              بازوهای بیرونی شماره و گریسکاری نمیشود
# 1                     نازل‌های اب روی تجهیز گرفته است
# 2                                    تجهیز الارم دارد
# 3   دستگاه گلس بید یکی از عملکرد‌های ان در هنگام ک...
# 4                      دستگاه گلاس بید استارت نمیشود.
# 5             یکی از شفتهای برگشتی پشت ستون شکسته است
# 6   صدایی غیر عادی از موقعیت تانژانت و پینیون کوره...
# 7    پیچ‌های ریل داخلی کولینگ حدفاصل و و و شل شده است
# 8                      زانویی خروجی پمپ سوراخ شده است
# 9                     برزنت متصل به استک پاره می‌باشد
# 10                   پله مربوط به بازدید مش شکسته است
# 11  ورقی که زیر گریتینگ انتهای بلت جهت جلوگیری از ...
# 12                            جک بالایی نشتی باد دارد
# 13                      تعمیر , , , سمت جنوب انجام شد
# 14                         نیاز به تاب گیری مجدد دارد
# 15                        نازل‌های واش باکس گرفته است
# 16                        نازل‌های واش باکس گرفته است
# 17                                         الارم کاذب
# 18                     افزایش ناگهانی ویبره (بارندگی)
# 19                        رفع انحراف نوار. (انجام شد)
# 20  با توجه به سایش زیاد ورق نصب‌شده بر روی مش اول...
# 21  نصف کردن عدد از مش‌های سایز میلیمتر اسکرین و ن...
# 22                                         الارم دارد
# 23                        نازل‌های واش باکس گرفته است
# 24  الارم تجهیز به دلیل کاهش فشار پمپ گریس اتفاق ا...
# 25                     بیرینگ سمت خلاف موتور خراب است
# 26  برشکاری و ساخت محفظه جهت نصب در موقعیت جدید (ه...
# 27                             سایش شفت درام تیل ائند
# 28                          تخته کلمپ موتور شکسته است
# 29  نشتی روغن پرشر پلیت بر روی شفت شماره شمال از ط...
# 30  ترمینال روغن روی ستون جنوب و مابین شافت و نشتی...
# 31                            دوربین کوره تصویر ندارد
# 32          ریترن سلف الایمنت کنار بین یک سایدگی دارد
# 33        یکی از پایپهای سمت جنوب چکش ثابت افتاده است
# 34                         سیم‌بکسل جرثقیل مشکل دارد.
# 35                        رفع انحراف نوار. (انجام شد)
# 36                          دمپر دچار خوردگی شده است.
# 37                          میزان اب غبار گیر کم است.
# 38  دیسکانکشن و کانکشن مجدد جهت بازدید از ایمپلر ت...
# 39                             موتور تجهیز مرتب میشود
# 40            پارگی زنجیر اسپراکت مربوط به نوار خوراک
# 41                     اتصالات گریس رول و باز می‌باشد
# 42          جک ایرلاک فیدر بالایی مجددا نشتی هوا دارد
# 43          شارژ روغن کاور زنجیر سمت شمال. (انجام شد)
# 44                ولو اب مربوط به شستشوی مش نشتی دارد
# 45                          دمای روغن بالا است (درجه)
# 46  تعویض شیر گازی مربوط به اب کولر اتاق دیزل به د...
# 47  جهت نصب پمپ تقویت فشار اب، مربوط به سیل واتر ف...
# 48                   کلیه نازلهای سر دیسکها گرفته است
# 49                            نازل واش باکس گرفته است
#
#                                         word_tokenize  \
# 0       [بازوهای, بیرونی, شماره, و, گریسکاری, نمیشود]
# 1               [نازل‌های, اب, روی, تجهیز, گرفته_است]
# 2                                [تجهیز, الارم, دارد]
# 3   [دستگاه, گلس, بید, یکی, از, عملکرد‌های, ان, در...
# 4              [دستگاه, گلاس, بید, استارت, نمیشود, .]
# 5     [یکی, از, شفتهای, برگشتی, پشت, ستون, شکسته_است]
# 6   [صدایی, غیر, عادی, از, موقعیت, تانژانت, و, پین...
# 7   [پیچ‌های, ریل, داخلی, کولینگ, حدفاصل, و, و, و,...
# 8                [زانویی, خروجی, پمپ, سوراخ, شده_است]
# 9              [برزنت, متصل, به, استک, پاره, می‌باشد]
# 10            [پله, مربوط, به, بازدید, مش, شکسته_است]
# 11  [ورقی, که, زیر, گریتینگ, انتهای, بلت, جهت, جلو...
# 12                      [جک, بالایی, نشتی, باد, دارد]
# 13             [تعمیر, ,, ,, ,, سمت, جنوب, انجام, شد]
# 14                  [نیاز, به, تاب, گیری, مجدد, دارد]
# 15                   [نازل‌های, واش, باکس, گرفته_است]
# 16                   [نازل‌های, واش, باکس, گرفته_است]
# 17                                      [الارم, کاذب]
# 18            [افزایش, ناگهانی, ویبره, (, بارندگی, )]
# 19            [رفع, انحراف, نوار, ., (, انجام, شد, )]
# 20  [با, توجه, به, سایش, زیاد, ورق, نصب‌شده, بر, ر...
# 21  [نصف, کردن, عدد, از, مش‌های, سایز, میلیمتر, اس...
# 22                                      [الارم, دارد]
# 23                   [نازل‌های, واش, باکس, گرفته_است]
# 24  [الارم, تجهیز, به, دلیل, کاهش, فشار, پمپ, گریس...
# 25              [بیرینگ, سمت, خلاف, موتور, خراب, است]
# 26  [برشکاری, و, ساخت, محفظه, جهت, نصب, در, موقعیت...
# 27                       [سایش, شفت, درام, تیل, ائند]
# 28                     [تخته, کلمپ, موتور, شکسته_است]
# 29  [نشتی, روغن, پرشر, پلیت, بر, روی, شفت, شماره, ...
# 30  [ترمینال, روغن, روی, ستون, جنوب, و, مابین, شاف...
# 31                       [دوربین, کوره, تصویر, ندارد]
# 32  [ریترن, سلف, الایمنت, کنار, بین, یک, سایدگی, د...
# 33  [یکی, از, پایپهای, سمت, جنوب, چکش, ثابت, افتاد...
# 34                  [سیم‌بکسل, جرثقیل, مشکل, دارد, .]
# 35            [رفع, انحراف, نوار, ., (, انجام, شد, )]
# 36                   [دمپر, دچار, خوردگی, شده_است, .]
# 37                 [میزان, اب, غبار, گیر, کم, است, .]
# 38  [دیسکانکشن, و, کانکشن, مجدد, جهت, بازدید, از, ...
# 39                        [موتور, تجهیز, مرتب, میشود]
# 40    [پارگی, زنجیر, اسپراکت, مربوط, به, نوار, خوراک]
# 41              [اتصالات, گریس, رول, و, باز, می‌باشد]
# 42  [جک, ایرلاک, فیدر, بالایی, مجددا, نشتی, هوا, د...
# 43  [شارژ, روغن, کاور, زنجیر, سمت, شمال, ., (, انج...
# 44       [ولو, اب, مربوط, به, شستشوی, مش, نشتی, دارد]
# 45                [دمای, روغن, بالا, است, (, درجه, )]
# 46  [تعویض, شیر, گازی, مربوط, به, اب, کولر, اتاق, ...
# 47  [جهت, نصب, پمپ, تقویت, فشار, اب, ،, مربوط, به,...
# 48             [کلیه, نازلهای, سر, دیسکها, گرفته_است]
# 49                       [نازل, واش, باکس, گرفته_است]
#
#                                         removed_space  \
# 0       [بازوهای, بیرونی, شماره, و, گریسکاری, نمیشود]
# 1               [نازل‌های, اب, روی, تجهیز, گرفته_است]
# 2                                [تجهیز, الارم, دارد]
# 3   [دستگاه, گلس, بید, یکی, از, عملکرد‌های, ان, در...
# 4              [دستگاه, گلاس, بید, استارت, نمیشود, .]
# 5     [یکی, از, شفتهای, برگشتی, پشت, ستون, شکسته_است]
# 6   [صدایی, غیر, عادی, از, موقعیت, تانژانت, و, پین...
# 7   [پیچ‌های, ریل, داخلی, کولینگ, حدفاصل, و, و, و,...
# 8                [زانویی, خروجی, پمپ, سوراخ, شده_است]
# 9              [برزنت, متصل, به, استک, پاره, می‌باشد]
# 10            [پله, مربوط, به, بازدید, مش, شکسته_است]
# 11  [ورقی, که, زیر, گریتینگ, انتهای, بلت, جهت, جلو...
# 12                      [جک, بالایی, نشتی, باد, دارد]
# 13             [تعمیر, ,, ,, ,, سمت, جنوب, انجام, شد]
# 14                  [نیاز, به, تاب, گیری, مجدد, دارد]
# 15                   [نازل‌های, واش, باکس, گرفته_است]
# 16                   [نازل‌های, واش, باکس, گرفته_است]
# 17                                      [الارم, کاذب]
# 18            [افزایش, ناگهانی, ویبره, (, بارندگی, )]
# 19            [رفع, انحراف, نوار, ., (, انجام, شد, )]
# 20  [با, توجه, به, سایش, زیاد, ورق, نصب‌شده, بر, ر...
# 21  [نصف, کردن, عدد, از, مش‌های, سایز, میلیمتر, اس...
# 22                                      [الارم, دارد]
# 23                   [نازل‌های, واش, باکس, گرفته_است]
# 24  [الارم, تجهیز, به, دلیل, کاهش, فشار, پمپ, گریس...
# 25              [بیرینگ, سمت, خلاف, موتور, خراب, است]
# 26  [برشکاری, و, ساخت, محفظه, جهت, نصب, در, موقعیت...
# 27                       [سایش, شفت, درام, تیل, ائند]
# 28                     [تخته, کلمپ, موتور, شکسته_است]
# 29  [نشتی, روغن, پرشر, پلیت, بر, روی, شفت, شماره, ...
# 30  [ترمینال, روغن, روی, ستون, جنوب, و, مابین, شاف...
# 31                       [دوربین, کوره, تصویر, ندارد]
# 32  [ریترن, سلف, الایمنت, کنار, بین, یک, سایدگی, د...
# 33  [یکی, از, پایپهای, سمت, جنوب, چکش, ثابت, افتاد...
# 34                  [سیم‌بکسل, جرثقیل, مشکل, دارد, .]
# 35            [رفع, انحراف, نوار, ., (, انجام, شد, )]
# 36                   [دمپر, دچار, خوردگی, شده_است, .]
# 37                 [میزان, اب, غبار, گیر, کم, است, .]
# 38  [دیسکانکشن, و, کانکشن, مجدد, جهت, بازدید, از, ...
# 39                        [موتور, تجهیز, مرتب, میشود]
# 40    [پارگی, زنجیر, اسپراکت, مربوط, به, نوار, خوراک]
# 41              [اتصالات, گریس, رول, و, باز, می‌باشد]
# 42  [جک, ایرلاک, فیدر, بالایی, مجددا, نشتی, هوا, د...
# 43  [شارژ, روغن, کاور, زنجیر, سمت, شمال, ., (, انج...
# 44       [ولو, اب, مربوط, به, شستشوی, مش, نشتی, دارد]
# 45                [دمای, روغن, بالا, است, (, درجه, )]
# 46  [تعویض, شیر, گازی, مربوط, به, اب, کولر, اتاق, ...
# 47  [جهت, نصب, پمپ, تقویت, فشار, اب, ،, مربوط, به,...
# 48             [کلیه, نازلهای, سر, دیسکها, گرفته_است]
# 49                       [نازل, واش, باکس, گرفته_است]
#
#                                     removed_stopwords  \
# 0          [بازوهای, بیرونی, شماره, گریسکاری, نمیشود]
# 1                               [نازل‌های, اب, تجهیز]
# 2                                      [تجهیز, الارم]
# 3           [دستگاه, گلس, بید, عملکرد‌های, کار, فعال]
# 4                 [دستگاه, گلاس, بید, استارت, نمیشود]
# 5                   [شفتهای, برگشتی, ستون, شکسته_است]
# 6   [صدایی, عادی, موقعیت, تانژانت, پینیون, کوره, م...
# 7           [پیچ‌های, ریل, داخلی, کولینگ, حدفاصل, شل]
# 8                         [زانویی, خروجی, پمپ, سوراخ]
# 9                           [برزنت, متصل, استک, پاره]
# 10                       [پله, بازدید, مش, شکسته_است]
# 11  [ورقی, گریتینگ, انتهای, بلت, جهت, جلوگیری, ریز...
# 12                            [جک, بالایی, نشتی, باد]
# 13                               [تعمیر, جنوب, انجام]
# 14                                        [تاب, مجدد]
# 15                              [نازل‌های, واش, باکس]
# 16                              [نازل‌های, واش, باکس]
# 17                                      [الارم, کاذب]
# 18                  [افزایش, ناگهانی, ویبره, بارندگی]
# 19                         [رفع, انحراف, نوار, انجام]
# 20  [توجه, سایش, ورق, نصب‌شده, مش, اولی, اماده, مت...
# 21  [نصف, عدد, مش‌های, سایز, میلیمتر, اسکرین, نصب,...
# 22                                            [الارم]
# 23                              [نازل‌های, واش, باکس]
# 24  [الارم, تجهیز, دلیل, کاهش, فشار, پمپ, گریس, ات...
# 25                        [بیرینگ, خلاف, موتور, خراب]
# 26  [برشکاری, ساخت, محفظه, جهت, نصب, موقعیت, هماهن...
# 27                       [سایش, شفت, درام, تیل, ائند]
# 28                     [تخته, کلمپ, موتور, شکسته_است]
# 29  [نشتی, روغن, پرشر, پلیت, شفت, شماره, شمال, بال...
# 30  [ترمینال, روغن, ستون, جنوب, مابین, شافت, نشتی,...
# 31                              [دوربین, کوره, تصویر]
# 32                      [ریترن, سلف, الایمنت, سایدگی]
# 33             [پایپهای, جنوب, چکش, ثابت, افتاده_است]
# 34                           [سیم‌بکسل, جرثقیل, مشکل]
# 35                         [رفع, انحراف, نوار, انجام]
# 36                                     [دمپر, خوردگی]
# 37                             [میزان, اب, غبار, گیر]
# 38  [دیسکانکشن, کانکشن, مجدد, جهت, بازدید, ایمپلر,...
# 39                        [موتور, تجهیز, مرتب, میشود]
# 40               [پارگی, زنجیر, اسپراکت, نوار, خوراک]
# 41                               [اتصالات, گریس, رول]
# 42       [جک, ایرلاک, فیدر, بالایی, مجددا, نشتی, هوا]
# 43             [شارژ, روغن, کاور, زنجیر, شمال, انجام]
# 44                        [ولو, اب, شستشوی, مش, نشتی]
# 45                                 [دمای, روغن, درجه]
# 46  [تعویض, شیر, گازی, اب, کولر, اتاق, دیزل, دلیل,...
# 47  [جهت, نصب, پمپ, تقویت, فشار, اب, سیل, واتر, فی...
# 48                        [کلیه, نازلهای, سر, دیسکها]
# 49                                  [نازل, واش, باکس]
#
#                                                  stem
# 0               [بازو, بیرون, شماره, گریسکار, نمیشود]
# 1                                   [نازل, اب, تجهیز]
# 2                                       [تجهیز, الار]
# 3               [دستگاه, گلس, بید, عملکرد, کار, فعال]
# 4                  [دستگاه, گلاس, بید, استار, نمیشود]
# 5                        [شفت, برگشت, ستون, شکسته_اس]
# 6   [صدا, عاد, موقع, تانژان, پینیون, کوره, مواقع, ...
# 7                [پیچ, ریل, داخل, کولینگ, حدفاصل, شل]
# 8                            [زانو, خروج, پمپ, سوراخ]
# 9                            [برزن, متصل, استک, پاره]
# 10                         [پله, بازدید, م, شکسته_اس]
# 11  [ورق, گریتینگ, انت, بل, جه, جلوگیر, ریز, مواد,...
# 12                               [جک, بالا, نشت, باد]
# 13                                [تعمیر, جنوب, انجا]
# 14                                        [تاب, مجدد]
# 15                                   [نازل, وا, باکس]
# 16                                   [نازل, وا, باکس]
# 17                                       [الار, کاذب]
# 18                      [افزا, ناگهان, ویبره, بارندگ]
# 19                          [رفع, انحراف, نوار, انجا]
# 20  [توجه, سا, ورق, نصب‌شده, م, اول, اماده, متریال...
# 21   [نصف, عدد, مش, سایز, میل, اسکرین, نصب, تسمه, ان]
# 22                                             [الار]
# 23                                   [نازل, وا, باکس]
# 24  [الار, تجهیز, دلیل, کاه, فشار, پمپ, گریس, اتفا...
# 25                        [بیرینگ, خلاف, موتور, خراب]
# 26  [برشکار, ساخ, محفظه, جه, نصب, موقع, هماهنگ, دف...
# 27                           [سا, شف, درا, تیل, ائند]
# 28                      [تخته, کلمپ, موتور, شکسته_اس]
# 29     [نشت, روغن, پرشر, پل, شف, شماره, شمال, بالینگ]
# 30  [ترمینال, روغن, ستون, جنوب, مابین, شاف, نشت, ر...
# 31                              [دوربین, کوره, تصویر]
# 32                        [ریترن, سلف, الایمن, سایدگ]
# 33                   [پایپ, جنوب, چک, ثاب, افتاده_اس]
# 34                           [سیم‌بکسل, جرثقیل, مشکل]
# 35                          [رفع, انحراف, نوار, انجا]
# 36                                      [دمپر, خوردگ]
# 37                               [میز, اب, غبار, گیر]
# 38  [دیسکانکشن, کانکشن, مجدد, جه, بازدید, ایمپلر, ...
# 39                        [موتور, تجهیز, مرتب, میشود]
# 40                 [پارگ, زنجیر, اسپراک, نوار, خوراک]
# 41                                 [اتصال, گریس, رول]
# 42          [جک, ایرلاک, فیدر, بالا, مجددا, نشت, هوا]
# 43              [شارژ, روغن, کاور, زنجیر, شمال, انجا]
# 44                           [ولو, اب, شستشو, م, نشت]
# 45                                  [دما, روغن, درجه]
# 46  [تعویض, شیر, گاز, اب, کولر, اتاق, دیزل, دلیل, ...
# 47  [جه, نصب, پمپ, تقو, فشار, اب, سیل, وا, فیل, دی...
# 48                             [کلیه, نازل, سر, دیسک]
# 49                                   [نازل, وا, باکس]

# %%
df[df.iloc[:,0]=='شکستگی']
# Out:
#       Cause_of_failure                                Problem_Description  \
# 5               شکستگی          یکی از شفتهای برگشتی پشت ستون   شکسته است
# 33              شکستگی        یکی از پایپهای سمت جنوب چکش ثابت افتاده است
# 160             شکستگی  سمت شمال یک عدد از ساید پلیت ها گوشه ان شکسته است
# 163             شکستگی  سمت شمال   عدد وسمت جنوب  عدد از پیچهای ویر پل...
# 236             شکستگی          شکستگی رول    که در حین تولید جوشکاری شد.
# ...                ...                                                ...
# 59030           شکستگی  ساخت   عدد پیچ مربوط به کلمپ دستگاه دیسک میل (...
# 59044           شکستگی         بریده شدن یکی از پیچ های رول متحرک پلت فرم
# 59165           شکستگی                           نیاز به ترمیم سوپر اسکرو
# 59205           شکستگی                کاور  زنجیر سمت پایین شکسته شده است
# 59247           شکستگی                     شکستگی شافت درام ابتدای خط بوم
#
#                                   Normalized_description  \
# 5                یکی از شفتهای برگشتی پشت ستون شکسته است
# 33           یکی از پایپهای سمت جنوب چکش ثابت افتاده است
# 160    سمت شمال یک عدد از ساید پلیت‌ها گوشه ان شکسته است
# 163    سمت شمال عدد وسمت جنوب عدد از پیچهای ویر پلیت ...
# 236               شکستگی رول که در حین تولید جوشکاری شد.
# ...                                                  ...
# 59030  ساخت عدد پیچ مربوط به کلمپ دستگاه دیسک میل (مط...
# 59044         بریده شدن یکی از پیچ‌های رول متحرک پلت فرم
# 59165                           نیاز به ترمیم سوپر اسکرو
# 59205                 کاور زنجیر سمت پایین شکسته شده است
# 59247                     شکستگی شافت درام ابتدای خط بوم
#
#                                            word_tokenize  \
# 5        [یکی, از, شفتهای, برگشتی, پشت, ستون, شکسته_است]
# 33     [یکی, از, پایپهای, سمت, جنوب, چکش, ثابت, افتاد...
# 160    [سمت, شمال, یک, عدد, از, ساید, پلیت‌ها, گوشه, ...
# 163    [سمت, شمال, عدد, وسمت, جنوب, عدد, از, پیچهای, ...
# 236    [شکستگی, رول, که, در, حین, تولید, جوشکاری, شد, .]
# ...                                                  ...
# 59030  [ساخت, عدد, پیچ, مربوط, به, کلمپ, دستگاه, دیسک...
# 59044  [بریده, شدن, یکی, از, پیچ‌های, رول, متحرک, پلت...
# 59165                     [نیاز, به, ترمیم, سوپر, اسکرو]
# 59205           [کاور, زنجیر, سمت, پایین, شکسته_شده_است]
# 59247              [شکستگی, شافت, درام, ابتدای, خط, بوم]
#
#                                            removed_space  \
# 5        [یکی, از, شفتهای, برگشتی, پشت, ستون, شکسته_است]
# 33     [یکی, از, پایپهای, سمت, جنوب, چکش, ثابت, افتاد...
# 160    [سمت, شمال, یک, عدد, از, ساید, پلیت‌ها, گوشه, ...
# 163    [سمت, شمال, عدد, وسمت, جنوب, عدد, از, پیچهای, ...
# 236    [شکستگی, رول, که, در, حین, تولید, جوشکاری, شد, .]
# ...                                                  ...
# 59030  [ساخت, عدد, پیچ, مربوط, به, کلمپ, دستگاه, دیسک...
# 59044  [بریده, شدن, یکی, از, پیچ‌های, رول, متحرک, پلت...
# 59165                     [نیاز, به, ترمیم, سوپر, اسکرو]
# 59205           [کاور, زنجیر, سمت, پایین, شکسته_شده_است]
# 59247              [شکستگی, شافت, درام, ابتدای, خط, بوم]
#
#                                        removed_stopwords  \
# 5                      [شفتهای, برگشتی, ستون, شکسته_است]
# 33                [پایپهای, جنوب, چکش, ثابت, افتاده_است]
# 160          [شمال, عدد, ساید, پلیت‌ها, گوشه, شکسته_است]
# 163    [شمال, عدد, وسمت, جنوب, عدد, پیچهای, ویر, پلیت...
# 236                   [شکستگی, رول, حین, تولید, جوشکاری]
# ...                                                  ...
# 59030  [ساخت, عدد, پیچ, کلمپ, دستگاه, دیسک, میل, مطاب...
# 59044             [بریده, پیچ‌های, رول, متحرک, پلت, فرم]
# 59165                               [ترمیم, سوپر, اسکرو]
# 59205                [کاور, زنجیر, پایین, شکسته_شده_است]
# 59247              [شکستگی, شافت, درام, ابتدای, خط, بوم]
#
#                                                     stem
# 5                           [شفت, برگشت, ستون, شکسته_اس]
# 33                      [پایپ, جنوب, چک, ثاب, افتاده_اس]
# 160              [شمال, عدد, ساید, پلیت, گوشه, شکسته_اس]
# 163    [شمال, عدد, وسم, جنوب, عدد, پیچ, ویر, پل, افتا...
# 236                     [شکستگ, رول, حین, تولید, جوشکار]
# ...                                                  ...
# 59030  [ساخ, عدد, پیچ, کلمپ, دستگاه, دیسک, میل, مطابق...
# 59044                   [بریده, پیچ, رول, متحرک, پل, فر]
# 59165                                 [ترم, سوپر, اسکرو]
# 59205                 [کاور, زنجیر, پایین, شکسته_شده_اس]
# 59247                   [شکستگ, شاف, درا, ابتدا, خط, بو]
#
# [467 rows x 7 columns]
